# %%
import joblib
outs = joblib.load("outputs/artifacts/algo1_outs_2025-05-22_1min_agreg.pkl")
# Out:
# /opt/anaconda3/envs/csiro_stem/lib/python3.12/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator PCA from version 1.6.1 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(
# /opt/anaconda3/envs/csiro_stem/lib/python3.12/site-packages/sklearn/base.py:442: InconsistentVersionWarning: Trying to unpickle estimator StandardScaler from version 1.6.1 when using version 1.7.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
from neural_sde.loss import likelihood_training
train_losses, test_losses, model, X_train = likelihood_training(
    outs,
    n_epochs=1000,
    batch_size=256,
    lr=1e-4,
    data='xi',
    zero_drift=False
)

import matplotlib.pyplot as plt
plt.figure()
plt.plot(train_losses, label="Train NLL")
plt.plot(test_losses, label="Test NLL")
plt.title("One-Step Euler–Maruyama Negative Log-Likelihood")
plt.xlabel("Epoch")
plt.ylabel("NLL")
plt.legend()
plt.show()
# Out:
# Epoch 1/1000  Train NLL: 6.1575e+00  Test NLL: 3.3948e+00
# Epoch 2/1000  Train NLL: 5.9438e+00  Test NLL: 3.2128e+00
# Epoch 3/1000  Train NLL: 5.7697e+00  Test NLL: 3.0618e+00
# Epoch 4/1000  Train NLL: 5.6194e+00  Test NLL: 2.9322e+00
# Epoch 5/1000  Train NLL: 5.4897e+00  Test NLL: 2.8230e+00
# Epoch 6/1000  Train NLL: 5.3792e+00  Test NLL: 2.7326e+00
# Epoch 7/1000  Train NLL: 5.2819e+00  Test NLL: 2.6579e+00
# Epoch 8/1000  Train NLL: 5.1960e+00  Test NLL: 2.5948e+00
# Epoch 9/1000  Train NLL: 5.1202e+00  Test NLL: 2.5459e+00
# Epoch 10/1000  Train NLL: 5.0553e+00  Test NLL: 2.5102e+00
# Epoch 11/1000  Train NLL: 5.0019e+00  Test NLL: 2.4859e+00
# Epoch 12/1000  Train NLL: 4.9564e+00  Test NLL: 2.4654e+00
# Epoch 13/1000  Train NLL: 4.9116e+00  Test NLL: 2.4425e+00
# Epoch 14/1000  Train NLL: 4.8648e+00  Test NLL: 2.4173e+00
# Epoch 15/1000  Train NLL: 4.8182e+00  Test NLL: 2.3946e+00
# Epoch 16/1000  Train NLL: 4.7732e+00  Test NLL: 2.3724e+00
# Epoch 17/1000  Train NLL: 4.7288e+00  Test NLL: 2.3503e+00
# Epoch 18/1000  Train NLL: 4.6846e+00  Test NLL: 2.3283e+00
# Epoch 19/1000  Train NLL: 4.6410e+00  Test NLL: 2.3067e+00
# Epoch 20/1000  Train NLL: 4.5980e+00  Test NLL: 2.2855e+00
# Epoch 21/1000  Train NLL: 4.5555e+00  Test NLL: 2.2644e+00
# Epoch 22/1000  Train NLL: 4.5133e+00  Test NLL: 2.2435e+00
# Epoch 23/1000  Train NLL: 4.4715e+00  Test NLL: 2.2225e+00
# Epoch 24/1000  Train NLL: 4.4300e+00  Test NLL: 2.2019e+00
# Epoch 25/1000  Train NLL: 4.3888e+00  Test NLL: 2.1814e+00
# Epoch 26/1000  Train NLL: 4.3477e+00  Test NLL: 2.1610e+00
# Epoch 27/1000  Train NLL: 4.3069e+00  Test NLL: 2.1407e+00
# Epoch 28/1000  Train NLL: 4.2662e+00  Test NLL: 2.1203e+00
# Epoch 29/1000  Train NLL: 4.2256e+00  Test NLL: 2.1001e+00
# Epoch 30/1000  Train NLL: 4.1850e+00  Test NLL: 2.0798e+00
# Epoch 31/1000  Train NLL: 4.1444e+00  Test NLL: 2.0595e+00
# Epoch 32/1000  Train NLL: 4.1038e+00  Test NLL: 2.0393e+00
# Epoch 33/1000  Train NLL: 4.0632e+00  Test NLL: 2.0190e+00
# Epoch 34/1000  Train NLL: 4.0226e+00  Test NLL: 1.9986e+00
# Epoch 35/1000  Train NLL: 3.9819e+00  Test NLL: 1.9783e+00
# Epoch 36/1000  Train NLL: 3.9412e+00  Test NLL: 1.9579e+00
# Epoch 37/1000  Train NLL: 3.9003e+00  Test NLL: 1.9374e+00
# Epoch 38/1000  Train NLL: 3.8594e+00  Test NLL: 1.9170e+00
# Epoch 39/1000  Train NLL: 3.8184e+00  Test NLL: 1.8965e+00
# Epoch 40/1000  Train NLL: 3.7773e+00  Test NLL: 1.8759e+00
# Epoch 41/1000  Train NLL: 3.7361e+00  Test NLL: 1.8552e+00
# Epoch 42/1000  Train NLL: 3.6948e+00  Test NLL: 1.8345e+00
# Epoch 43/1000  Train NLL: 3.6533e+00  Test NLL: 1.8137e+00
# Epoch 44/1000  Train NLL: 3.6116e+00  Test NLL: 1.7928e+00
# Epoch 45/1000  Train NLL: 3.5698e+00  Test NLL: 1.7718e+00
# Epoch 46/1000  Train NLL: 3.5277e+00  Test NLL: 1.7507e+00
# Epoch 47/1000  Train NLL: 3.4855e+00  Test NLL: 1.7295e+00
# Epoch 48/1000  Train NLL: 3.4431e+00  Test NLL: 1.7084e+00
# Epoch 49/1000  Train NLL: 3.4006e+00  Test NLL: 1.6870e+00
# Epoch 50/1000  Train NLL: 3.3579e+00  Test NLL: 1.6655e+00
# Epoch 51/1000  Train NLL: 3.3150e+00  Test NLL: 1.6440e+00
# Epoch 52/1000  Train NLL: 3.2720e+00  Test NLL: 1.6224e+00
# Epoch 53/1000  Train NLL: 3.2287e+00  Test NLL: 1.6007e+00
# Epoch 54/1000  Train NLL: 3.1853e+00  Test NLL: 1.5790e+00
# Epoch 55/1000  Train NLL: 3.1417e+00  Test NLL: 1.5571e+00
# Epoch 56/1000  Train NLL: 3.0981e+00  Test NLL: 1.5353e+00
# Epoch 57/1000  Train NLL: 3.0543e+00  Test NLL: 1.5132e+00
# Epoch 58/1000  Train NLL: 3.0102e+00  Test NLL: 1.4911e+00
# Epoch 59/1000  Train NLL: 2.9659e+00  Test NLL: 1.4688e+00
# Epoch 60/1000  Train NLL: 2.9213e+00  Test NLL: 1.4463e+00
# Epoch 61/1000  Train NLL: 2.8764e+00  Test NLL: 1.4239e+00
# Epoch 62/1000  Train NLL: 2.8314e+00  Test NLL: 1.4011e+00
# Epoch 63/1000  Train NLL: 2.7862e+00  Test NLL: 1.3786e+00
# Epoch 64/1000  Train NLL: 2.7409e+00  Test NLL: 1.3557e+00
# Epoch 65/1000  Train NLL: 2.6953e+00  Test NLL: 1.3332e+00
# Epoch 66/1000  Train NLL: 2.6497e+00  Test NLL: 1.3100e+00
# Epoch 67/1000  Train NLL: 2.6038e+00  Test NLL: 1.2871e+00
# Epoch 68/1000  Train NLL: 2.5579e+00  Test NLL: 1.2641e+00
# Epoch 69/1000  Train NLL: 2.5121e+00  Test NLL: 1.2414e+00
# Epoch 70/1000  Train NLL: 2.4664e+00  Test NLL: 1.2183e+00
# Epoch 71/1000  Train NLL: 2.4206e+00  Test NLL: 1.1955e+00
# Epoch 72/1000  Train NLL: 2.3745e+00  Test NLL: 1.1721e+00
# Epoch 73/1000  Train NLL: 2.3280e+00  Test NLL: 1.1487e+00
# Epoch 74/1000  Train NLL: 2.2812e+00  Test NLL: 1.1251e+00
# Epoch 75/1000  Train NLL: 2.2341e+00  Test NLL: 1.1014e+00
# Epoch 76/1000  Train NLL: 2.1869e+00  Test NLL: 1.0783e+00
# Epoch 77/1000  Train NLL: 2.1400e+00  Test NLL: 1.0546e+00
# Epoch 78/1000  Train NLL: 2.0930e+00  Test NLL: 1.0308e+00
# Epoch 79/1000  Train NLL: 2.0458e+00  Test NLL: 1.0072e+00
# Epoch 80/1000  Train NLL: 1.9984e+00  Test NLL: 9.8354e-01
# Epoch 81/1000  Train NLL: 1.9509e+00  Test NLL: 9.5988e-01
# Epoch 82/1000  Train NLL: 1.9034e+00  Test NLL: 9.3584e-01
# Epoch 83/1000  Train NLL: 1.8557e+00  Test NLL: 9.1182e-01
# Epoch 84/1000  Train NLL: 1.8077e+00  Test NLL: 8.8765e-01
# Epoch 85/1000  Train NLL: 1.7595e+00  Test NLL: 8.6353e-01
# Epoch 86/1000  Train NLL: 1.7113e+00  Test NLL: 8.3961e-01
# Epoch 87/1000  Train NLL: 1.6633e+00  Test NLL: 8.1565e-01
# Epoch 88/1000  Train NLL: 1.6152e+00  Test NLL: 7.9158e-01
# Epoch 89/1000  Train NLL: 1.5672e+00  Test NLL: 7.6749e-01
# Epoch 90/1000  Train NLL: 1.5193e+00  Test NLL: 7.4385e-01
# Epoch 91/1000  Train NLL: 1.4717e+00  Test NLL: 7.1976e-01
# Epoch 92/1000  Train NLL: 1.4243e+00  Test NLL: 6.9634e-01
# Epoch 93/1000  Train NLL: 1.3780e+00  Test NLL: 6.7354e-01
# Epoch 94/1000  Train NLL: 1.3326e+00  Test NLL: 6.5104e-01
# Epoch 95/1000  Train NLL: 1.2874e+00  Test NLL: 6.2816e-01
# Epoch 96/1000  Train NLL: 1.2418e+00  Test NLL: 6.0564e-01
# Epoch 97/1000  Train NLL: 1.1963e+00  Test NLL: 5.8301e-01
# Epoch 98/1000  Train NLL: 1.1517e+00  Test NLL: 5.6097e-01
# Epoch 99/1000  Train NLL: 1.1074e+00  Test NLL: 5.3839e-01
# Epoch 100/1000  Train NLL: 1.0626e+00  Test NLL: 5.1615e-01
# Epoch 101/1000  Train NLL: 1.0184e+00  Test NLL: 4.9446e-01
# Epoch 102/1000  Train NLL: 9.7451e-01  Test NLL: 4.7315e-01
# Epoch 103/1000  Train NLL: 9.3145e-01  Test NLL: 4.5214e-01
# Epoch 104/1000  Train NLL: 8.9009e-01  Test NLL: 4.3174e-01
# Epoch 105/1000  Train NLL: 8.5020e-01  Test NLL: 4.1251e-01
# Epoch 106/1000  Train NLL: 8.1138e-01  Test NLL: 3.9284e-01
# Epoch 107/1000  Train NLL: 7.7263e-01  Test NLL: 3.7302e-01
# Epoch 108/1000  Train NLL: 7.3411e-01  Test NLL: 3.5380e-01
# Epoch 109/1000  Train NLL: 6.9544e-01  Test NLL: 3.3613e-01
# Epoch 110/1000  Train NLL: 6.5658e-01  Test NLL: 3.1545e-01
# Epoch 111/1000  Train NLL: 6.1806e-01  Test NLL: 2.9587e-01
# Epoch 112/1000  Train NLL: 5.8052e-01  Test NLL: 2.7837e-01
# Epoch 113/1000  Train NLL: 5.4430e-01  Test NLL: 2.5950e-01
# Epoch 114/1000  Train NLL: 5.0809e-01  Test NLL: 2.4235e-01
# Epoch 115/1000  Train NLL: 4.7246e-01  Test NLL: 2.2492e-01
# Epoch 116/1000  Train NLL: 4.3677e-01  Test NLL: 2.0643e-01
# Epoch 117/1000  Train NLL: 4.0108e-01  Test NLL: 1.8935e-01
# Epoch 118/1000  Train NLL: 3.6703e-01  Test NLL: 1.7210e-01
# Epoch 119/1000  Train NLL: 3.3390e-01  Test NLL: 1.5643e-01
# Epoch 120/1000  Train NLL: 3.0043e-01  Test NLL: 1.3863e-01
# Epoch 121/1000  Train NLL: 2.6580e-01  Test NLL: 1.2216e-01
# Epoch 122/1000  Train NLL: 2.3001e-01  Test NLL: 1.0523e-01
# Epoch 123/1000  Train NLL: 1.9719e-01  Test NLL: 8.8098e-02
# Epoch 124/1000  Train NLL: 1.6775e-01  Test NLL: 7.6588e-02
# Epoch 125/1000  Train NLL: 1.4288e-01  Test NLL: 6.6021e-02
# Epoch 126/1000  Train NLL: 1.2018e-01  Test NLL: 5.3567e-02
# Epoch 127/1000  Train NLL: 9.8834e-02  Test NLL: 4.1816e-02
# Epoch 128/1000  Train NLL: 7.7682e-02  Test NLL: 3.2252e-02
# Epoch 129/1000  Train NLL: 5.5805e-02  Test NLL: 1.9619e-02
# Epoch 130/1000  Train NLL: 3.2687e-02  Test NLL: 7.4805e-03
# Epoch 131/1000  Train NLL: 8.3213e-03  Test NLL: -3.3845e-03
# Epoch 132/1000  Train NLL: -1.4723e-02  Test NLL: -1.2574e-02
# Epoch 133/1000  Train NLL: -3.7347e-02  Test NLL: -2.2051e-02
# Epoch 134/1000  Train NLL: -5.8773e-02  Test NLL: -3.3876e-02
# Epoch 135/1000  Train NLL: -7.9520e-02  Test NLL: -4.2458e-02
# Epoch 136/1000  Train NLL: -9.7863e-02  Test NLL: -5.6516e-02
# Epoch 137/1000  Train NLL: -1.1749e-01  Test NLL: -6.4679e-02
# Epoch 138/1000  Train NLL: -1.3578e-01  Test NLL: -7.1066e-02
# Epoch 139/1000  Train NLL: -1.5252e-01  Test NLL: -7.7810e-02
# Epoch 140/1000  Train NLL: -1.6765e-01  Test NLL: -8.9503e-02
# Epoch 141/1000  Train NLL: -1.8446e-01  Test NLL: -9.5954e-02
# Epoch 142/1000  Train NLL: -2.0158e-01  Test NLL: -1.0214e-01
# Epoch 143/1000  Train NLL: -2.1926e-01  Test NLL: -1.1201e-01
# Epoch 144/1000  Train NLL: -2.3720e-01  Test NLL: -1.2508e-01
# Epoch 145/1000  Train NLL: -2.5584e-01  Test NLL: -1.3316e-01
# Epoch 146/1000  Train NLL: -2.7299e-01  Test NLL: -1.4187e-01
# Epoch 147/1000  Train NLL: -2.8955e-01  Test NLL: -1.4907e-01
# Epoch 148/1000  Train NLL: -3.0558e-01  Test NLL: -1.5757e-01
# Epoch 149/1000  Train NLL: -3.2146e-01  Test NLL: -1.6534e-01
# Epoch 150/1000  Train NLL: -3.3723e-01  Test NLL: -1.7338e-01
# Epoch 151/1000  Train NLL: -3.5317e-01  Test NLL: -1.8065e-01
# Epoch 152/1000  Train NLL: -3.6912e-01  Test NLL: -1.8889e-01
# Epoch 153/1000  Train NLL: -3.8530e-01  Test NLL: -1.9704e-01
# Epoch 154/1000  Train NLL: -4.0148e-01  Test NLL: -2.0540e-01
# Epoch 155/1000  Train NLL: -4.1779e-01  Test NLL: -2.1320e-01
# Epoch 156/1000  Train NLL: -4.3416e-01  Test NLL: -2.2223e-01
# Epoch 157/1000  Train NLL: -4.5081e-01  Test NLL: -2.2974e-01
# Epoch 158/1000  Train NLL: -4.6745e-01  Test NLL: -2.3841e-01
# Epoch 159/1000  Train NLL: -4.8434e-01  Test NLL: -2.4734e-01
# Epoch 160/1000  Train NLL: -5.0103e-01  Test NLL: -2.5580e-01
# Epoch 161/1000  Train NLL: -5.1797e-01  Test NLL: -2.6354e-01
# Epoch 162/1000  Train NLL: -5.3484e-01  Test NLL: -2.7165e-01
# Epoch 163/1000  Train NLL: -5.5194e-01  Test NLL: -2.8094e-01
# Epoch 164/1000  Train NLL: -5.6899e-01  Test NLL: -2.8993e-01
# Epoch 165/1000  Train NLL: -5.8578e-01  Test NLL: -2.9974e-01
# Epoch 166/1000  Train NLL: -6.0347e-01  Test NLL: -3.0416e-01
# Epoch 167/1000  Train NLL: -6.1974e-01  Test NLL: -3.1341e-01
# Epoch 168/1000  Train NLL: -6.3653e-01  Test NLL: -3.2255e-01
# Epoch 169/1000  Train NLL: -6.5220e-01  Test NLL: -3.3152e-01
# Epoch 170/1000  Train NLL: -6.6878e-01  Test NLL: -3.3921e-01
# Epoch 171/1000  Train NLL: -6.8488e-01  Test NLL: -3.4660e-01
# Epoch 172/1000  Train NLL: -7.0136e-01  Test NLL: -3.5434e-01
# Epoch 173/1000  Train NLL: -7.1820e-01  Test NLL: -3.6430e-01
# Epoch 174/1000  Train NLL: -7.3517e-01  Test NLL: -3.7339e-01
# Epoch 175/1000  Train NLL: -7.4833e-01  Test NLL: -3.4863e-01
# Epoch 176/1000  Train NLL: -7.5592e-01  Test NLL: -3.8598e-01
# Epoch 177/1000  Train NLL: -7.7623e-01  Test NLL: -3.8788e-01
# Epoch 178/1000  Train NLL: -7.8821e-01  Test NLL: -3.9596e-01
# Epoch 179/1000  Train NLL: -7.9807e-01  Test NLL: -4.0062e-01
# Epoch 180/1000  Train NLL: -8.1055e-01  Test NLL: -3.9512e-01
# Epoch 181/1000  Train NLL: -8.1872e-01  Test NLL: -4.1030e-01
# Epoch 182/1000  Train NLL: -8.3155e-01  Test NLL: -4.2063e-01
# Epoch 183/1000  Train NLL: -8.4324e-01  Test NLL: -4.1940e-01
# Epoch 184/1000  Train NLL: -8.5173e-01  Test NLL: -4.3073e-01
# Epoch 185/1000  Train NLL: -8.6444e-01  Test NLL: -4.3492e-01
# Epoch 186/1000  Train NLL: -8.7621e-01  Test NLL: -4.3144e-01
# Epoch 187/1000  Train NLL: -8.8634e-01  Test NLL: -4.4244e-01
# Epoch 188/1000  Train NLL: -8.9850e-01  Test NLL: -4.5620e-01
# Epoch 189/1000  Train NLL: -9.1015e-01  Test NLL: -4.5648e-01
# Epoch 190/1000  Train NLL: -9.2445e-01  Test NLL: -4.6200e-01
# Epoch 191/1000  Train NLL: -9.3445e-01  Test NLL: -4.6586e-01
# Epoch 192/1000  Train NLL: -9.4881e-01  Test NLL: -4.7414e-01
# Epoch 193/1000  Train NLL: -9.6301e-01  Test NLL: -4.8378e-01
# Epoch 194/1000  Train NLL: -9.7857e-01  Test NLL: -4.9103e-01
# Epoch 195/1000  Train NLL: -9.9323e-01  Test NLL: -4.9933e-01
# Epoch 196/1000  Train NLL: -1.0104e+00  Test NLL: -5.0860e-01
# Epoch 197/1000  Train NLL: -1.0269e+00  Test NLL: -5.1589e-01
# Epoch 198/1000  Train NLL: -1.0434e+00  Test NLL: -5.2405e-01
# Epoch 199/1000  Train NLL: -1.0584e+00  Test NLL: -5.3445e-01
# Epoch 200/1000  Train NLL: -1.0738e+00  Test NLL: -5.4080e-01
# Epoch 201/1000  Train NLL: -1.0888e+00  Test NLL: -5.4795e-01
# Epoch 202/1000  Train NLL: -1.1018e+00  Test NLL: -5.5019e-01
# Epoch 203/1000  Train NLL: -1.1153e+00  Test NLL: -5.5984e-01
# Epoch 204/1000  Train NLL: -1.1292e+00  Test NLL: -5.6760e-01
# Epoch 205/1000  Train NLL: -1.1426e+00  Test NLL: -5.7204e-01
# Epoch 206/1000  Train NLL: -1.1557e+00  Test NLL: -5.7897e-01
# Epoch 207/1000  Train NLL: -1.1676e+00  Test NLL: -5.8723e-01
# Epoch 208/1000  Train NLL: -1.1820e+00  Test NLL: -5.9298e-01
# Epoch 209/1000  Train NLL: -1.1938e+00  Test NLL: -6.0119e-01
# Epoch 210/1000  Train NLL: -1.2067e+00  Test NLL: -6.0088e-01
# Epoch 211/1000  Train NLL: -1.2177e+00  Test NLL: -6.1082e-01
# Epoch 212/1000  Train NLL: -1.2293e+00  Test NLL: -6.1792e-01
# Epoch 213/1000  Train NLL: -1.2405e+00  Test NLL: -6.2449e-01
# Epoch 214/1000  Train NLL: -1.2516e+00  Test NLL: -6.2475e-01
# Epoch 215/1000  Train NLL: -1.2627e+00  Test NLL: -6.3239e-01
# Epoch 216/1000  Train NLL: -1.2743e+00  Test NLL: -6.3873e-01
# Epoch 217/1000  Train NLL: -1.2851e+00  Test NLL: -6.4550e-01
# Epoch 218/1000  Train NLL: -1.2965e+00  Test NLL: -6.4761e-01
# Epoch 219/1000  Train NLL: -1.3078e+00  Test NLL: -6.5442e-01
# Epoch 220/1000  Train NLL: -1.3192e+00  Test NLL: -6.6226e-01
# Epoch 221/1000  Train NLL: -1.3303e+00  Test NLL: -6.6850e-01
# Epoch 222/1000  Train NLL: -1.3421e+00  Test NLL: -6.7033e-01
# Epoch 223/1000  Train NLL: -1.3537e+00  Test NLL: -6.7798e-01
# Epoch 224/1000  Train NLL: -1.3653e+00  Test NLL: -6.8499e-01
# Epoch 225/1000  Train NLL: -1.3768e+00  Test NLL: -6.9265e-01
# Epoch 226/1000  Train NLL: -1.3888e+00  Test NLL: -6.9358e-01
# Epoch 227/1000  Train NLL: -1.4007e+00  Test NLL: -7.0110e-01
# Epoch 228/1000  Train NLL: -1.4130e+00  Test NLL: -7.0938e-01
# Epoch 229/1000  Train NLL: -1.4248e+00  Test NLL: -7.1670e-01
# Epoch 230/1000  Train NLL: -1.4369e+00  Test NLL: -7.2199e-01
# Epoch 231/1000  Train NLL: -1.4478e+00  Test NLL: -7.2323e-01
# Epoch 232/1000  Train NLL: -1.4622e+00  Test NLL: -7.4014e-01
# Epoch 233/1000  Train NLL: -1.4826e+00  Test NLL: -7.4507e-01
# Epoch 234/1000  Train NLL: -1.4959e+00  Test NLL: -7.2912e-01
# Epoch 235/1000  Train NLL: -1.5072e+00  Test NLL: -7.5030e-01
# Epoch 236/1000  Train NLL: -1.5190e+00  Test NLL: -7.6025e-01
# Epoch 237/1000  Train NLL: -1.5336e+00  Test NLL: -7.6639e-01
# Epoch 238/1000  Train NLL: -1.5423e+00  Test NLL: -7.6343e-01
# Epoch 239/1000  Train NLL: -1.5411e+00  Test NLL: -7.3060e-01
# Epoch 240/1000  Train NLL: -1.5497e+00  Test NLL: -7.8386e-01
# Epoch 241/1000  Train NLL: -1.5731e+00  Test NLL: -7.7717e-01
# Epoch 242/1000  Train NLL: -1.5807e+00  Test NLL: -7.8265e-01
# Epoch 243/1000  Train NLL: -1.5833e+00  Test NLL: -7.8866e-01
# Epoch 244/1000  Train NLL: -1.5958e+00  Test NLL: -7.8388e-01
# Epoch 245/1000  Train NLL: -1.5939e+00  Test NLL: -7.9377e-01
# Epoch 246/1000  Train NLL: -1.6139e+00  Test NLL: -8.0912e-01
# Epoch 247/1000  Train NLL: -1.6258e+00  Test NLL: -7.9389e-01
# Epoch 248/1000  Train NLL: -1.6291e+00  Test NLL: -8.1485e-01
# Epoch 249/1000  Train NLL: -1.6427e+00  Test NLL: -8.0934e-01
# Epoch 250/1000  Train NLL: -1.6397e+00  Test NLL: -8.1780e-01
# Epoch 251/1000  Train NLL: -1.6531e+00  Test NLL: -8.3183e-01
# Epoch 252/1000  Train NLL: -1.6631e+00  Test NLL: -8.1372e-01
# Epoch 253/1000  Train NLL: -1.6669e+00  Test NLL: -8.3659e-01
# Epoch 254/1000  Train NLL: -1.6818e+00  Test NLL: -8.4343e-01
# Epoch 255/1000  Train NLL: -1.6922e+00  Test NLL: -8.4304e-01
# Epoch 256/1000  Train NLL: -1.7023e+00  Test NLL: -8.5420e-01
# Epoch 257/1000  Train NLL: -1.7156e+00  Test NLL: -8.6188e-01
# Epoch 258/1000  Train NLL: -1.7272e+00  Test NLL: -8.6797e-01
# Epoch 259/1000  Train NLL: -1.7390e+00  Test NLL: -8.6805e-01
# Epoch 260/1000  Train NLL: -1.7486e+00  Test NLL: -8.7533e-01
# Epoch 261/1000  Train NLL: -1.7598e+00  Test NLL: -8.7971e-01
# Epoch 262/1000  Train NLL: -1.7700e+00  Test NLL: -8.8258e-01
# Epoch 263/1000  Train NLL: -1.7787e+00  Test NLL: -8.8685e-01
# Epoch 264/1000  Train NLL: -1.7881e+00  Test NLL: -8.9359e-01
# Epoch 265/1000  Train NLL: -1.7966e+00  Test NLL: -8.9647e-01
# Epoch 266/1000  Train NLL: -1.8046e+00  Test NLL: -9.0507e-01
# Epoch 267/1000  Train NLL: -1.8141e+00  Test NLL: -9.0620e-01
# Epoch 268/1000  Train NLL: -1.8227e+00  Test NLL: -9.1202e-01
# Epoch 269/1000  Train NLL: -1.8312e+00  Test NLL: -9.1584e-01
# Epoch 270/1000  Train NLL: -1.8399e+00  Test NLL: -9.2136e-01
# Epoch 271/1000  Train NLL: -1.8486e+00  Test NLL: -9.2345e-01
# Epoch 272/1000  Train NLL: -1.8574e+00  Test NLL: -9.2989e-01
# Epoch 273/1000  Train NLL: -1.8661e+00  Test NLL: -9.3119e-01
# Epoch 274/1000  Train NLL: -1.8745e+00  Test NLL: -9.3658e-01
# Epoch 275/1000  Train NLL: -1.8836e+00  Test NLL: -9.4175e-01
# Epoch 276/1000  Train NLL: -1.8922e+00  Test NLL: -9.4723e-01
# Epoch 277/1000  Train NLL: -1.9010e+00  Test NLL: -9.4996e-01
# Epoch 278/1000  Train NLL: -1.9094e+00  Test NLL: -9.5566e-01
# Epoch 279/1000  Train NLL: -1.9182e+00  Test NLL: -9.5891e-01
# Epoch 280/1000  Train NLL: -1.9268e+00  Test NLL: -9.6526e-01
# Epoch 281/1000  Train NLL: -1.9355e+00  Test NLL: -9.6639e-01
# Epoch 282/1000  Train NLL: -1.9442e+00  Test NLL: -9.7220e-01
# Epoch 283/1000  Train NLL: -1.9534e+00  Test NLL: -9.7427e-01
# Epoch 284/1000  Train NLL: -1.9619e+00  Test NLL: -9.7969e-01
# Epoch 285/1000  Train NLL: -1.9710e+00  Test NLL: -9.8543e-01
# Epoch 286/1000  Train NLL: -1.9797e+00  Test NLL: -9.8835e-01
# Epoch 287/1000  Train NLL: -1.9882e+00  Test NLL: -9.9429e-01
# Epoch 288/1000  Train NLL: -1.9970e+00  Test NLL: -1.0001e+00
# Epoch 289/1000  Train NLL: -2.0060e+00  Test NLL: -1.0039e+00
# Epoch 290/1000  Train NLL: -2.0153e+00  Test NLL: -1.0084e+00
# Epoch 291/1000  Train NLL: -2.0245e+00  Test NLL: -1.0120e+00
# Epoch 292/1000  Train NLL: -2.0339e+00  Test NLL: -1.0110e+00
# Epoch 293/1000  Train NLL: -2.0424e+00  Test NLL: -1.0139e+00
# Epoch 294/1000  Train NLL: -2.0503e+00  Test NLL: -1.0299e+00
# Epoch 295/1000  Train NLL: -2.0599e+00  Test NLL: -1.0277e+00
# Epoch 296/1000  Train NLL: -2.0695e+00  Test NLL: -1.0357e+00
# Epoch 297/1000  Train NLL: -2.0835e+00  Test NLL: -1.0426e+00
# Epoch 298/1000  Train NLL: -2.0823e+00  Test NLL: -9.9385e-01
# Epoch 299/1000  Train NLL: -2.0829e+00  Test NLL: -1.0501e+00
# Epoch 300/1000  Train NLL: -2.1014e+00  Test NLL: -9.7056e-01
# Epoch 301/1000  Train NLL: -2.0845e+00  Test NLL: -1.0386e+00
# Epoch 302/1000  Train NLL: -2.1172e+00  Test NLL: -1.0404e+00
# Epoch 303/1000  Train NLL: -2.1244e+00  Test NLL: -1.0671e+00
# Epoch 304/1000  Train NLL: -2.1222e+00  Test NLL: -1.0569e+00
# Epoch 305/1000  Train NLL: -2.1407e+00  Test NLL: -1.0754e+00
# Epoch 306/1000  Train NLL: -2.1453e+00  Test NLL: -1.0183e+00
# Epoch 307/1000  Train NLL: -2.1414e+00  Test NLL: -1.0796e+00
# Epoch 308/1000  Train NLL: -2.1651e+00  Test NLL: -1.0516e+00
# Epoch 309/1000  Train NLL: -2.1517e+00  Test NLL: -1.0842e+00
# Epoch 310/1000  Train NLL: -2.1782e+00  Test NLL: -1.0840e+00
# Epoch 311/1000  Train NLL: -2.1886e+00  Test NLL: -1.0855e+00
# Epoch 312/1000  Train NLL: -2.1975e+00  Test NLL: -1.0869e+00
# Epoch 313/1000  Train NLL: -2.1966e+00  Test NLL: -1.1041e+00
# Epoch 314/1000  Train NLL: -2.2064e+00  Test NLL: -1.0568e+00
# Epoch 315/1000  Train NLL: -2.2024e+00  Test NLL: -1.1098e+00
# Epoch 316/1000  Train NLL: -2.2271e+00  Test NLL: -1.1174e+00
# Epoch 317/1000  Train NLL: -2.2373e+00  Test NLL: -1.1162e+00
# Epoch 318/1000  Train NLL: -2.2468e+00  Test NLL: -1.1172e+00
# Epoch 319/1000  Train NLL: -2.2497e+00  Test NLL: -1.1256e+00
# Epoch 320/1000  Train NLL: -2.2617e+00  Test NLL: -1.1240e+00
# Epoch 321/1000  Train NLL: -2.2704e+00  Test NLL: -1.1391e+00
# Epoch 322/1000  Train NLL: -2.2769e+00  Test NLL: -1.1405e+00
# Epoch 323/1000  Train NLL: -2.2866e+00  Test NLL: -1.1456e+00
# Epoch 324/1000  Train NLL: -2.2969e+00  Test NLL: -1.1512e+00
# Epoch 325/1000  Train NLL: -2.2987e+00  Test NLL: -1.1371e+00
# Epoch 326/1000  Train NLL: -2.2974e+00  Test NLL: -1.1540e+00
# Epoch 327/1000  Train NLL: -2.3135e+00  Test NLL: -1.1523e+00
# Epoch 328/1000  Train NLL: -2.3305e+00  Test NLL: -1.1659e+00
# Epoch 329/1000  Train NLL: -2.3380e+00  Test NLL: -1.1724e+00
# Epoch 330/1000  Train NLL: -2.3464e+00  Test NLL: -1.1650e+00
# Epoch 331/1000  Train NLL: -2.3531e+00  Test NLL: -1.1610e+00
# Epoch 332/1000  Train NLL: -2.3637e+00  Test NLL: -1.1838e+00
# Epoch 333/1000  Train NLL: -2.3718e+00  Test NLL: -1.1838e+00
# Epoch 334/1000  Train NLL: -2.3826e+00  Test NLL: -1.1935e+00
# Epoch 335/1000  Train NLL: -2.3898e+00  Test NLL: -1.1705e+00
# Epoch 336/1000  Train NLL: -2.3890e+00  Test NLL: -1.1938e+00
# Epoch 337/1000  Train NLL: -2.4052e+00  Test NLL: -1.2026e+00
# Epoch 338/1000  Train NLL: -2.4118e+00  Test NLL: -1.2037e+00
# Epoch 339/1000  Train NLL: -2.4215e+00  Test NLL: -1.2103e+00
# Epoch 340/1000  Train NLL: -2.4295e+00  Test NLL: -1.2172e+00
# Epoch 341/1000  Train NLL: -2.4373e+00  Test NLL: -1.2164e+00
# Epoch 342/1000  Train NLL: -2.4474e+00  Test NLL: -1.2262e+00
# Epoch 343/1000  Train NLL: -2.4538e+00  Test NLL: -1.2139e+00
# Epoch 344/1000  Train NLL: -2.4614e+00  Test NLL: -1.2251e+00
# Epoch 345/1000  Train NLL: -2.4704e+00  Test NLL: -1.2322e+00
# Epoch 346/1000  Train NLL: -2.4775e+00  Test NLL: -1.2376e+00
# Epoch 347/1000  Train NLL: -2.4847e+00  Test NLL: -1.2362e+00
# Epoch 348/1000  Train NLL: -2.4925e+00  Test NLL: -1.2434e+00
# Epoch 349/1000  Train NLL: -2.4999e+00  Test NLL: -1.2449e+00
# Epoch 350/1000  Train NLL: -2.5066e+00  Test NLL: -1.2493e+00
# Epoch 351/1000  Train NLL: -2.5139e+00  Test NLL: -1.2453e+00
# Epoch 352/1000  Train NLL: -2.5204e+00  Test NLL: -1.2469e+00
# Epoch 353/1000  Train NLL: -2.5269e+00  Test NLL: -1.2519e+00
# Epoch 354/1000  Train NLL: -2.5334e+00  Test NLL: -1.2680e+00
# Epoch 355/1000  Train NLL: -2.5420e+00  Test NLL: -1.2679e+00
# Epoch 356/1000  Train NLL: -2.5504e+00  Test NLL: -1.2683e+00
# Epoch 357/1000  Train NLL: -2.5569e+00  Test NLL: -1.2742e+00
# Epoch 358/1000  Train NLL: -2.5642e+00  Test NLL: -1.2759e+00
# Epoch 359/1000  Train NLL: -2.5701e+00  Test NLL: -1.2837e+00
# Epoch 360/1000  Train NLL: -2.5784e+00  Test NLL: -1.2848e+00
# Epoch 361/1000  Train NLL: -2.5856e+00  Test NLL: -1.2889e+00
# Epoch 362/1000  Train NLL: -2.5925e+00  Test NLL: -1.2954e+00
# Epoch 363/1000  Train NLL: -2.6001e+00  Test NLL: -1.2906e+00
# Epoch 364/1000  Train NLL: -2.6069e+00  Test NLL: -1.3020e+00
# Epoch 365/1000  Train NLL: -2.6135e+00  Test NLL: -1.3001e+00
# Epoch 366/1000  Train NLL: -2.6198e+00  Test NLL: -1.3086e+00
# Epoch 367/1000  Train NLL: -2.6284e+00  Test NLL: -1.2991e+00
# Epoch 368/1000  Train NLL: -2.6340e+00  Test NLL: -1.3034e+00
# Epoch 369/1000  Train NLL: -2.6418e+00  Test NLL: -1.3194e+00
# Epoch 370/1000  Train NLL: -2.6422e+00  Test NLL: -1.3247e+00
# Epoch 371/1000  Train NLL: -2.6166e+00  Test NLL: -1.3004e+00
# Epoch 372/1000  Train NLL: -2.6351e+00  Test NLL: -1.3107e+00
# Epoch 373/1000  Train NLL: -2.6568e+00  Test NLL: -1.3146e+00
# Epoch 374/1000  Train NLL: -2.6603e+00  Test NLL: -1.3029e+00
# Epoch 375/1000  Train NLL: -2.6556e+00  Test NLL: -1.3238e+00
# Epoch 376/1000  Train NLL: -2.6818e+00  Test NLL: -1.3154e+00
# Epoch 377/1000  Train NLL: -2.6806e+00  Test NLL: -1.3317e+00
# Epoch 378/1000  Train NLL: -2.6883e+00  Test NLL: -1.3450e+00
# Epoch 379/1000  Train NLL: -2.6766e+00  Test NLL: -1.3274e+00
# Epoch 380/1000  Train NLL: -2.7107e+00  Test NLL: -1.3424e+00
# Epoch 381/1000  Train NLL: -2.7175e+00  Test NLL: -1.3539e+00
# Epoch 382/1000  Train NLL: -2.7316e+00  Test NLL: -1.3620e+00
# Epoch 383/1000  Train NLL: -2.7414e+00  Test NLL: -1.3693e+00
# Epoch 384/1000  Train NLL: -2.7503e+00  Test NLL: -1.3453e+00
# Epoch 385/1000  Train NLL: -2.7319e+00  Test NLL: -1.3645e+00
# Epoch 386/1000  Train NLL: -2.7442e+00  Test NLL: -1.3568e+00
# Epoch 387/1000  Train NLL: -2.7582e+00  Test NLL: -1.3609e+00
# Epoch 388/1000  Train NLL: -2.7639e+00  Test NLL: -1.3733e+00
# Epoch 389/1000  Train NLL: -2.7762e+00  Test NLL: -1.3356e+00
# Epoch 390/1000  Train NLL: -2.7384e+00  Test NLL: -1.3947e+00
# Epoch 391/1000  Train NLL: -2.7655e+00  Test NLL: -1.3688e+00
# Epoch 392/1000  Train NLL: -2.7871e+00  Test NLL: -1.3753e+00
# Epoch 393/1000  Train NLL: -2.7887e+00  Test NLL: -1.3931e+00
# Epoch 394/1000  Train NLL: -2.8053e+00  Test NLL: -1.3416e+00
# Epoch 395/1000  Train NLL: -2.7902e+00  Test NLL: -1.3945e+00
# Epoch 396/1000  Train NLL: -2.8164e+00  Test NLL: -1.4154e+00
# Epoch 397/1000  Train NLL: -2.8209e+00  Test NLL: -1.3102e+00
# Epoch 398/1000  Train NLL: -2.7840e+00  Test NLL: -1.3740e+00
# Epoch 399/1000  Train NLL: -2.8302e+00  Test NLL: -1.4057e+00
# Epoch 400/1000  Train NLL: -2.8544e+00  Test NLL: -1.4271e+00
# Epoch 401/1000  Train NLL: -2.8614e+00  Test NLL: -1.3866e+00
# Epoch 402/1000  Train NLL: -2.8470e+00  Test NLL: -1.4095e+00
# Epoch 403/1000  Train NLL: -2.8521e+00  Test NLL: -1.4273e+00
# Epoch 404/1000  Train NLL: -2.8695e+00  Test NLL: -1.3315e+00
# Epoch 405/1000  Train NLL: -2.8500e+00  Test NLL: -1.4399e+00
# Epoch 406/1000  Train NLL: -2.8565e+00  Test NLL: -1.3893e+00
# Epoch 407/1000  Train NLL: -2.8730e+00  Test NLL: -1.4360e+00
# Epoch 408/1000  Train NLL: -2.8902e+00  Test NLL: -1.4075e+00
# Epoch 409/1000  Train NLL: -2.8751e+00  Test NLL: -1.4454e+00
# Epoch 410/1000  Train NLL: -2.9022e+00  Test NLL: -1.4507e+00
# Epoch 411/1000  Train NLL: -2.9028e+00  Test NLL: -1.3451e+00
# Epoch 412/1000  Train NLL: -2.8765e+00  Test NLL: -1.4377e+00
# Epoch 413/1000  Train NLL: -2.9188e+00  Test NLL: -1.4398e+00
# Epoch 414/1000  Train NLL: -2.9328e+00  Test NLL: -1.4111e+00
# Epoch 415/1000  Train NLL: -2.9119e+00  Test NLL: -1.4415e+00
# Epoch 416/1000  Train NLL: -2.9255e+00  Test NLL: -1.4357e+00
# Epoch 417/1000  Train NLL: -2.9391e+00  Test NLL: -1.4643e+00
# Epoch 418/1000  Train NLL: -2.9550e+00  Test NLL: -1.4602e+00
# Epoch 419/1000  Train NLL: -2.9583e+00  Test NLL: -1.4737e+00
# Epoch 420/1000  Train NLL: -2.9630e+00  Test NLL: -1.4680e+00
# Epoch 421/1000  Train NLL: -2.9587e+00  Test NLL: -1.4677e+00
# Epoch 422/1000  Train NLL: -2.9709e+00  Test NLL: -1.4914e+00
# Epoch 423/1000  Train NLL: -2.9810e+00  Test NLL: -1.4805e+00
# Epoch 424/1000  Train NLL: -2.9951e+00  Test NLL: -1.4979e+00
# Epoch 425/1000  Train NLL: -2.9887e+00  Test NLL: -1.4931e+00
# Epoch 426/1000  Train NLL: -3.0073e+00  Test NLL: -1.5001e+00
# Epoch 427/1000  Train NLL: -3.0095e+00  Test NLL: -1.4935e+00
# Epoch 428/1000  Train NLL: -3.0148e+00  Test NLL: -1.4980e+00
# Epoch 429/1000  Train NLL: -3.0218e+00  Test NLL: -1.5071e+00
# Epoch 430/1000  Train NLL: -3.0310e+00  Test NLL: -1.5033e+00
# Epoch 431/1000  Train NLL: -3.0330e+00  Test NLL: -1.4954e+00
# Epoch 432/1000  Train NLL: -3.0335e+00  Test NLL: -1.4947e+00
# Epoch 433/1000  Train NLL: -3.0353e+00  Test NLL: -1.5136e+00
# Epoch 434/1000  Train NLL: -3.0542e+00  Test NLL: -1.5237e+00
# Epoch 435/1000  Train NLL: -3.0413e+00  Test NLL: -1.5007e+00
# Epoch 436/1000  Train NLL: -3.0453e+00  Test NLL: -1.5156e+00
# Epoch 437/1000  Train NLL: -3.0604e+00  Test NLL: -1.4413e+00
# Epoch 438/1000  Train NLL: -3.0340e+00  Test NLL: -1.5221e+00
# Epoch 439/1000  Train NLL: -3.0615e+00  Test NLL: -1.4584e+00
# Epoch 440/1000  Train NLL: -3.0489e+00  Test NLL: -1.5308e+00
# Epoch 441/1000  Train NLL: -3.0803e+00  Test NLL: -1.5321e+00
# Epoch 442/1000  Train NLL: -3.0928e+00  Test NLL: -1.5452e+00
# Epoch 443/1000  Train NLL: -3.0987e+00  Test NLL: -1.5442e+00
# Epoch 444/1000  Train NLL: -3.1074e+00  Test NLL: -1.5468e+00
# Epoch 445/1000  Train NLL: -3.1138e+00  Test NLL: -1.5414e+00
# Epoch 446/1000  Train NLL: -3.1100e+00  Test NLL: -1.5314e+00
# Epoch 447/1000  Train NLL: -3.0881e+00  Test NLL: -1.4590e+00
# Epoch 448/1000  Train NLL: -3.0573e+00  Test NLL: -1.5105e+00
# Epoch 449/1000  Train NLL: -3.1112e+00  Test NLL: -1.5068e+00
# Epoch 450/1000  Train NLL: -3.1163e+00  Test NLL: -1.5359e+00
# Epoch 451/1000  Train NLL: -3.1438e+00  Test NLL: -1.5668e+00
# Epoch 452/1000  Train NLL: -3.1459e+00  Test NLL: -1.5694e+00
# Epoch 453/1000  Train NLL: -3.1535e+00  Test NLL: -1.5685e+00
# Epoch 454/1000  Train NLL: -3.1592e+00  Test NLL: -1.5679e+00
# Epoch 455/1000  Train NLL: -3.1669e+00  Test NLL: -1.5707e+00
# Epoch 456/1000  Train NLL: -3.1681e+00  Test NLL: -1.5767e+00
# Epoch 457/1000  Train NLL: -3.1777e+00  Test NLL: -1.5665e+00
# Epoch 458/1000  Train NLL: -3.1820e+00  Test NLL: -1.5654e+00
# Epoch 459/1000  Train NLL: -3.1870e+00  Test NLL: -1.5722e+00
# Epoch 460/1000  Train NLL: -3.1914e+00  Test NLL: -1.5584e+00
# Epoch 461/1000  Train NLL: -3.1892e+00  Test NLL: -1.5663e+00
# Epoch 462/1000  Train NLL: -3.1935e+00  Test NLL: -1.5614e+00
# Epoch 463/1000  Train NLL: -3.2020e+00  Test NLL: -1.5962e+00
# Epoch 464/1000  Train NLL: -3.2190e+00  Test NLL: -1.6028e+00
# Epoch 465/1000  Train NLL: -3.2273e+00  Test NLL: -1.5683e+00
# Epoch 466/1000  Train NLL: -3.2095e+00  Test NLL: -1.6113e+00
# Epoch 467/1000  Train NLL: -3.2200e+00  Test NLL: -1.5915e+00
# Epoch 468/1000  Train NLL: -3.2401e+00  Test NLL: -1.6027e+00
# Epoch 469/1000  Train NLL: -3.2373e+00  Test NLL: -1.6118e+00
# Epoch 470/1000  Train NLL: -3.2511e+00  Test NLL: -1.6155e+00
# Epoch 471/1000  Train NLL: -3.2219e+00  Test NLL: -1.3704e+00
# Epoch 472/1000  Train NLL: -3.1635e+00  Test NLL: -1.5698e+00
# Epoch 473/1000  Train NLL: -3.2411e+00  Test NLL: -1.5743e+00
# Epoch 474/1000  Train NLL: -3.2585e+00  Test NLL: -1.6136e+00
# Epoch 475/1000  Train NLL: -3.2677e+00  Test NLL: -1.6198e+00
# Epoch 476/1000  Train NLL: -3.2712e+00  Test NLL: -1.6235e+00
# Epoch 477/1000  Train NLL: -3.2874e+00  Test NLL: -1.6178e+00
# Epoch 478/1000  Train NLL: -3.2679e+00  Test NLL: -1.6206e+00
# Epoch 479/1000  Train NLL: -3.2881e+00  Test NLL: -1.6289e+00
# Epoch 480/1000  Train NLL: -3.2918e+00  Test NLL: -1.6483e+00
# Epoch 481/1000  Train NLL: -3.3088e+00  Test NLL: -1.6337e+00
# Epoch 482/1000  Train NLL: -3.3107e+00  Test NLL: -1.6511e+00
# Epoch 483/1000  Train NLL: -3.3149e+00  Test NLL: -1.6531e+00
# Epoch 484/1000  Train NLL: -3.3095e+00  Test NLL: -1.6466e+00
# Epoch 485/1000  Train NLL: -3.3267e+00  Test NLL: -1.6139e+00
# Epoch 486/1000  Train NLL: -3.3277e+00  Test NLL: -1.6654e+00
# Epoch 487/1000  Train NLL: -3.3336e+00  Test NLL: -1.6674e+00
# Epoch 488/1000  Train NLL: -3.3099e+00  Test NLL: -1.5221e+00
# Epoch 489/1000  Train NLL: -3.2917e+00  Test NLL: -1.6537e+00
# Epoch 490/1000  Train NLL: -3.3405e+00  Test NLL: -1.5749e+00
# Epoch 491/1000  Train NLL: -3.3093e+00  Test NLL: -1.6517e+00
# Epoch 492/1000  Train NLL: -3.3424e+00  Test NLL: -1.6392e+00
# Epoch 493/1000  Train NLL: -3.3603e+00  Test NLL: -1.6583e+00
# Epoch 494/1000  Train NLL: -3.3777e+00  Test NLL: -1.6483e+00
# Epoch 495/1000  Train NLL: -3.3652e+00  Test NLL: -1.6841e+00
# Epoch 496/1000  Train NLL: -3.3767e+00  Test NLL: -1.6608e+00
# Epoch 497/1000  Train NLL: -3.3842e+00  Test NLL: -1.6623e+00
# Epoch 498/1000  Train NLL: -3.3889e+00  Test NLL: -1.6878e+00
# Epoch 499/1000  Train NLL: -3.3960e+00  Test NLL: -1.6769e+00
# Epoch 500/1000  Train NLL: -3.3998e+00  Test NLL: -1.6771e+00
# Epoch 501/1000  Train NLL: -3.4071e+00  Test NLL: -1.6864e+00
# Epoch 502/1000  Train NLL: -3.4119e+00  Test NLL: -1.6845e+00
# Epoch 503/1000  Train NLL: -3.4183e+00  Test NLL: -1.6899e+00
# Epoch 504/1000  Train NLL: -3.4222e+00  Test NLL: -1.6937e+00
# Epoch 505/1000  Train NLL: -3.4283e+00  Test NLL: -1.6810e+00
# Epoch 506/1000  Train NLL: -3.4325e+00  Test NLL: -1.6871e+00
# Epoch 507/1000  Train NLL: -3.4296e+00  Test NLL: -1.7147e+00
# Epoch 508/1000  Train NLL: -3.4374e+00  Test NLL: -1.7188e+00
# Epoch 509/1000  Train NLL: -3.4331e+00  Test NLL: -1.6661e+00
# Epoch 510/1000  Train NLL: -3.4443e+00  Test NLL: -1.6526e+00
# Epoch 511/1000  Train NLL: -3.4169e+00  Test NLL: -1.6618e+00
# Epoch 512/1000  Train NLL: -3.4150e+00  Test NLL: -1.7078e+00
# Epoch 513/1000  Train NLL: -3.4407e+00  Test NLL: -1.6167e+00
# Epoch 514/1000  Train NLL: -3.4275e+00  Test NLL: -1.6830e+00
# Epoch 515/1000  Train NLL: -3.4238e+00  Test NLL: -1.6995e+00
# Epoch 516/1000  Train NLL: -3.4628e+00  Test NLL: -1.4935e+00
# Epoch 517/1000  Train NLL: -3.3727e+00  Test NLL: -1.6686e+00
# Epoch 518/1000  Train NLL: -3.4403e+00  Test NLL: -1.6761e+00
# Epoch 519/1000  Train NLL: -3.4347e+00  Test NLL: -1.6352e+00
# Epoch 520/1000  Train NLL: -3.4373e+00  Test NLL: -1.6753e+00
# Epoch 521/1000  Train NLL: -3.4533e+00  Test NLL: -1.7036e+00
# Epoch 522/1000  Train NLL: -3.4871e+00  Test NLL: -1.6775e+00
# Epoch 523/1000  Train NLL: -3.4907e+00  Test NLL: -1.7203e+00
# Epoch 524/1000  Train NLL: -3.4954e+00  Test NLL: -1.7460e+00
# Epoch 525/1000  Train NLL: -3.5022e+00  Test NLL: -1.7432e+00
# Epoch 526/1000  Train NLL: -3.5184e+00  Test NLL: -1.7353e+00
# Epoch 527/1000  Train NLL: -3.5150e+00  Test NLL: -1.7495e+00
# Epoch 528/1000  Train NLL: -3.5348e+00  Test NLL: -1.7054e+00
# Epoch 529/1000  Train NLL: -3.4608e+00  Test NLL: -1.6408e+00
# Epoch 530/1000  Train NLL: -3.4811e+00  Test NLL: -1.7354e+00
# Epoch 531/1000  Train NLL: -3.5262e+00  Test NLL: -1.7681e+00
# Epoch 532/1000  Train NLL: -3.5402e+00  Test NLL: -1.7390e+00
# Epoch 533/1000  Train NLL: -3.5405e+00  Test NLL: -1.7400e+00
# Epoch 534/1000  Train NLL: -3.5428e+00  Test NLL: -1.7771e+00
# Epoch 535/1000  Train NLL: -3.5573e+00  Test NLL: -1.7658e+00
# Epoch 536/1000  Train NLL: -3.5628e+00  Test NLL: -1.7509e+00
# Epoch 537/1000  Train NLL: -3.5674e+00  Test NLL: -1.7634e+00
# Epoch 538/1000  Train NLL: -3.5711e+00  Test NLL: -1.7700e+00
# Epoch 539/1000  Train NLL: -3.5748e+00  Test NLL: -1.7793e+00
# Epoch 540/1000  Train NLL: -3.5821e+00  Test NLL: -1.7698e+00
# Epoch 541/1000  Train NLL: -3.5907e+00  Test NLL: -1.7590e+00
# Epoch 542/1000  Train NLL: -3.5904e+00  Test NLL: -1.7858e+00
# Epoch 543/1000  Train NLL: -3.5979e+00  Test NLL: -1.7709e+00
# Epoch 544/1000  Train NLL: -3.6014e+00  Test NLL: -1.7627e+00
# Epoch 545/1000  Train NLL: -3.6060e+00  Test NLL: -1.7740e+00
# Epoch 546/1000  Train NLL: -3.6057e+00  Test NLL: -1.7636e+00
# Epoch 547/1000  Train NLL: -3.6070e+00  Test NLL: -1.8046e+00
# Epoch 548/1000  Train NLL: -3.6129e+00  Test NLL: -1.7975e+00
# Epoch 549/1000  Train NLL: -3.6255e+00  Test NLL: -1.8100e+00
# Epoch 550/1000  Train NLL: -3.6224e+00  Test NLL: -1.8156e+00
# Epoch 551/1000  Train NLL: -3.5792e+00  Test NLL: -1.6911e+00
# Epoch 552/1000  Train NLL: -3.5802e+00  Test NLL: -1.7985e+00
# Epoch 553/1000  Train NLL: -3.6156e+00  Test NLL: -1.5425e+00
# Epoch 554/1000  Train NLL: -3.5400e+00  Test NLL: -1.7598e+00
# Epoch 555/1000  Train NLL: -3.6230e+00  Test NLL: -1.8058e+00
# Epoch 556/1000  Train NLL: -3.6647e+00  Test NLL: -1.8006e+00
# Epoch 557/1000  Train NLL: -3.6587e+00  Test NLL: -1.8156e+00
# Epoch 558/1000  Train NLL: -3.6775e+00  Test NLL: -1.8157e+00
# Epoch 559/1000  Train NLL: -3.6654e+00  Test NLL: -1.7662e+00
# Epoch 560/1000  Train NLL: -3.6342e+00  Test NLL: -1.8082e+00
# Epoch 561/1000  Train NLL: -3.6469e+00  Test NLL: -1.8028e+00
# Epoch 562/1000  Train NLL: -3.6411e+00  Test NLL: -1.7513e+00
# Epoch 563/1000  Train NLL: -3.6705e+00  Test NLL: -1.8321e+00
# Epoch 564/1000  Train NLL: -3.6930e+00  Test NLL: -1.7999e+00
# Epoch 565/1000  Train NLL: -3.6952e+00  Test NLL: -1.7879e+00
# Epoch 566/1000  Train NLL: -3.6914e+00  Test NLL: -1.8311e+00
# Epoch 567/1000  Train NLL: -3.6966e+00  Test NLL: -1.8434e+00
# Epoch 568/1000  Train NLL: -3.7114e+00  Test NLL: -1.8318e+00
# Epoch 569/1000  Train NLL: -3.7141e+00  Test NLL: -1.8116e+00
# Epoch 570/1000  Train NLL: -3.7146e+00  Test NLL: -1.8425e+00
# Epoch 571/1000  Train NLL: -3.7281e+00  Test NLL: -1.8186e+00
# Epoch 572/1000  Train NLL: -3.7188e+00  Test NLL: -1.8467e+00
# Epoch 573/1000  Train NLL: -3.7280e+00  Test NLL: -1.8666e+00
# Epoch 574/1000  Train NLL: -3.7448e+00  Test NLL: -1.7274e+00
# Epoch 575/1000  Train NLL: -3.5693e+00  Test NLL: -1.8526e+00
# Epoch 576/1000  Train NLL: -3.4466e+00  Test NLL: -1.7940e+00
# Epoch 577/1000  Train NLL: -3.6029e+00  Test NLL: -1.6776e+00
# Epoch 578/1000  Train NLL: -3.6459e+00  Test NLL: -1.7580e+00
# Epoch 579/1000  Train NLL: -3.7076e+00  Test NLL: -1.8339e+00
# Epoch 580/1000  Train NLL: -3.7552e+00  Test NLL: -1.8719e+00
# Epoch 581/1000  Train NLL: -3.7753e+00  Test NLL: -1.8598e+00
# Epoch 582/1000  Train NLL: -3.7602e+00  Test NLL: -1.8406e+00
# Epoch 583/1000  Train NLL: -3.7581e+00  Test NLL: -1.7930e+00
# Epoch 584/1000  Train NLL: -3.7513e+00  Test NLL: -1.8725e+00
# Epoch 585/1000  Train NLL: -3.7686e+00  Test NLL: -1.8829e+00
# Epoch 586/1000  Train NLL: -3.7873e+00  Test NLL: -1.8564e+00
# Epoch 587/1000  Train NLL: -3.7853e+00  Test NLL: -1.8442e+00
# Epoch 588/1000  Train NLL: -3.7861e+00  Test NLL: -1.8824e+00
# Epoch 589/1000  Train NLL: -3.7986e+00  Test NLL: -1.8732e+00
# Epoch 590/1000  Train NLL: -3.8026e+00  Test NLL: -1.8767e+00
# Epoch 591/1000  Train NLL: -3.8060e+00  Test NLL: -1.8690e+00
# Epoch 592/1000  Train NLL: -3.8076e+00  Test NLL: -1.8901e+00
# Epoch 593/1000  Train NLL: -3.8128e+00  Test NLL: -1.8850e+00
# Epoch 594/1000  Train NLL: -3.8240e+00  Test NLL: -1.8411e+00
# Epoch 595/1000  Train NLL: -3.8194e+00  Test NLL: -1.8798e+00
# Epoch 596/1000  Train NLL: -3.8224e+00  Test NLL: -1.8959e+00
# Epoch 597/1000  Train NLL: -3.8275e+00  Test NLL: -1.8692e+00
# Epoch 598/1000  Train NLL: -3.8343e+00  Test NLL: -1.8777e+00
# Epoch 599/1000  Train NLL: -3.8409e+00  Test NLL: -1.8822e+00
# Epoch 600/1000  Train NLL: -3.8427e+00  Test NLL: -1.9032e+00
# Epoch 601/1000  Train NLL: -3.8494e+00  Test NLL: -1.8892e+00
# Epoch 602/1000  Train NLL: -3.8485e+00  Test NLL: -1.8925e+00
# Epoch 603/1000  Train NLL: -3.8572e+00  Test NLL: -1.8989e+00
# Epoch 604/1000  Train NLL: -3.8632e+00  Test NLL: -1.8959e+00
# Epoch 605/1000  Train NLL: -3.8675e+00  Test NLL: -1.8859e+00
# Epoch 606/1000  Train NLL: -3.8689e+00  Test NLL: -1.9120e+00
# Epoch 607/1000  Train NLL: -3.8717e+00  Test NLL: -1.8726e+00
# Epoch 608/1000  Train NLL: -3.8702e+00  Test NLL: -1.9226e+00
# Epoch 609/1000  Train NLL: -3.8856e+00  Test NLL: -1.9110e+00
# Epoch 610/1000  Train NLL: -3.8863e+00  Test NLL: -1.9085e+00
# Epoch 611/1000  Train NLL: -3.8918e+00  Test NLL: -1.9123e+00
# Epoch 612/1000  Train NLL: -3.9016e+00  Test NLL: -1.8459e+00
# Epoch 613/1000  Train NLL: -3.8718e+00  Test NLL: -1.8424e+00
# Epoch 614/1000  Train NLL: -3.8032e+00  Test NLL: -1.7525e+00
# Epoch 615/1000  Train NLL: -3.7693e+00  Test NLL: -1.9475e+00
# Epoch 616/1000  Train NLL: -3.8950e+00  Test NLL: -1.8989e+00
# Epoch 617/1000  Train NLL: -3.9037e+00  Test NLL: -1.9356e+00
# Epoch 618/1000  Train NLL: -3.9070e+00  Test NLL: -1.9445e+00
# Epoch 619/1000  Train NLL: -3.9202e+00  Test NLL: -1.9257e+00
# Epoch 620/1000  Train NLL: -3.9202e+00  Test NLL: -1.9154e+00
# Epoch 621/1000  Train NLL: -3.9287e+00  Test NLL: -1.9437e+00
# Epoch 622/1000  Train NLL: -3.9298e+00  Test NLL: -1.9556e+00
# Epoch 623/1000  Train NLL: -3.9309e+00  Test NLL: -1.9190e+00
# Epoch 624/1000  Train NLL: -3.9495e+00  Test NLL: -1.9163e+00
# Epoch 625/1000  Train NLL: -3.9237e+00  Test NLL: -1.9664e+00
# Epoch 626/1000  Train NLL: -3.9327e+00  Test NLL: -1.8695e+00
# Epoch 627/1000  Train NLL: -3.9350e+00  Test NLL: -1.9243e+00
# Epoch 628/1000  Train NLL: -3.9466e+00  Test NLL: -1.9235e+00
# Epoch 629/1000  Train NLL: -3.9452e+00  Test NLL: -1.9590e+00
# Epoch 630/1000  Train NLL: -3.9474e+00  Test NLL: -1.8913e+00
# Epoch 631/1000  Train NLL: -3.9537e+00  Test NLL: -1.9300e+00
# Epoch 632/1000  Train NLL: -3.9622e+00  Test NLL: -1.9561e+00
# Epoch 633/1000  Train NLL: -3.9669e+00  Test NLL: -1.9669e+00
# Epoch 634/1000  Train NLL: -3.9733e+00  Test NLL: -1.9178e+00
# Epoch 635/1000  Train NLL: -3.9741e+00  Test NLL: -1.9307e+00
# Epoch 636/1000  Train NLL: -3.9808e+00  Test NLL: -1.9678e+00
# Epoch 637/1000  Train NLL: -3.9860e+00  Test NLL: -1.9700e+00
# Epoch 638/1000  Train NLL: -3.9862e+00  Test NLL: -1.9389e+00
# Epoch 639/1000  Train NLL: -3.9935e+00  Test NLL: -1.9428e+00
# Epoch 640/1000  Train NLL: -3.9949e+00  Test NLL: -1.9861e+00
# Epoch 641/1000  Train NLL: -4.0005e+00  Test NLL: -1.9917e+00
# Epoch 642/1000  Train NLL: -4.0000e+00  Test NLL: -1.9665e+00
# Epoch 643/1000  Train NLL: -4.0111e+00  Test NLL: -1.9234e+00
# Epoch 644/1000  Train NLL: -4.0145e+00  Test NLL: -1.9568e+00
# Epoch 645/1000  Train NLL: -4.0096e+00  Test NLL: -1.9434e+00
# Epoch 646/1000  Train NLL: -4.0172e+00  Test NLL: -1.9424e+00
# Epoch 647/1000  Train NLL: -4.0258e+00  Test NLL: -1.9199e+00
# Epoch 648/1000  Train NLL: -4.0241e+00  Test NLL: -2.0119e+00
# Epoch 649/1000  Train NLL: -4.0373e+00  Test NLL: -2.0138e+00
# Epoch 650/1000  Train NLL: -4.0411e+00  Test NLL: -1.9791e+00
# Epoch 651/1000  Train NLL: -4.0455e+00  Test NLL: -1.9905e+00
# Epoch 652/1000  Train NLL: -4.0483e+00  Test NLL: -1.9894e+00
# Epoch 653/1000  Train NLL: -4.0503e+00  Test NLL: -2.0038e+00
# Epoch 654/1000  Train NLL: -4.0572e+00  Test NLL: -1.9576e+00
# Epoch 655/1000  Train NLL: -4.0621e+00  Test NLL: -1.9588e+00
# Epoch 656/1000  Train NLL: -4.0624e+00  Test NLL: -2.0235e+00
# Epoch 657/1000  Train NLL: -4.0713e+00  Test NLL: -2.0178e+00
# Epoch 658/1000  Train NLL: -4.0751e+00  Test NLL: -1.9768e+00
# Epoch 659/1000  Train NLL: -4.0789e+00  Test NLL: -1.9912e+00
# Epoch 660/1000  Train NLL: -4.0767e+00  Test NLL: -2.0261e+00
# Epoch 661/1000  Train NLL: -4.0803e+00  Test NLL: -2.0343e+00
# Epoch 662/1000  Train NLL: -4.0877e+00  Test NLL: -2.0041e+00
# Epoch 663/1000  Train NLL: -4.0953e+00  Test NLL: -1.9926e+00
# Epoch 664/1000  Train NLL: -4.0984e+00  Test NLL: -2.0411e+00
# Epoch 665/1000  Train NLL: -4.1038e+00  Test NLL: -2.0444e+00
# Epoch 666/1000  Train NLL: -4.1080e+00  Test NLL: -1.9952e+00
# Epoch 667/1000  Train NLL: -4.1097e+00  Test NLL: -2.0177e+00
# Epoch 668/1000  Train NLL: -4.1138e+00  Test NLL: -2.0232e+00
# Epoch 669/1000  Train NLL: -4.1189e+00  Test NLL: -2.0448e+00
# Epoch 670/1000  Train NLL: -4.1240e+00  Test NLL: -1.9583e+00
# Epoch 671/1000  Train NLL: -4.1226e+00  Test NLL: -2.0081e+00
# Epoch 672/1000  Train NLL: -4.1304e+00  Test NLL: -2.0551e+00
# Epoch 673/1000  Train NLL: -4.1046e+00  Test NLL: -1.8967e+00
# Epoch 674/1000  Train NLL: -3.9947e+00  Test NLL: -2.0380e+00
# Epoch 675/1000  Train NLL: -4.0684e+00  Test NLL: -1.8081e+00
# Epoch 676/1000  Train NLL: -4.0637e+00  Test NLL: -1.8896e+00
# Epoch 677/1000  Train NLL: -4.0412e+00  Test NLL: -2.0546e+00
# Epoch 678/1000  Train NLL: -4.0902e+00  Test NLL: -1.8680e+00
# Epoch 679/1000  Train NLL: -4.0699e+00  Test NLL: -1.9634e+00
# Epoch 680/1000  Train NLL: -4.0445e+00  Test NLL: -2.0038e+00
# Epoch 681/1000  Train NLL: -4.0997e+00  Test NLL: -1.7625e+00
# Epoch 682/1000  Train NLL: -4.0771e+00  Test NLL: -1.8855e+00
# Epoch 683/1000  Train NLL: -4.0640e+00  Test NLL: -2.0724e+00
# Epoch 684/1000  Train NLL: -4.0833e+00  Test NLL: -1.9652e+00
# Epoch 685/1000  Train NLL: -4.0747e+00  Test NLL: -2.0243e+00
# Epoch 686/1000  Train NLL: -4.0938e+00  Test NLL: -2.0119e+00
# Epoch 687/1000  Train NLL: -4.1079e+00  Test NLL: -1.8421e+00
# Epoch 688/1000  Train NLL: -4.0803e+00  Test NLL: -1.9685e+00
# Epoch 689/1000  Train NLL: -4.1017e+00  Test NLL: -2.0493e+00
# Epoch 690/1000  Train NLL: -4.1175e+00  Test NLL: -1.9340e+00
# Epoch 691/1000  Train NLL: -4.0757e+00  Test NLL: -2.0364e+00
# Epoch 692/1000  Train NLL: -4.1027e+00  Test NLL: -1.9892e+00
# Epoch 693/1000  Train NLL: -4.1353e+00  Test NLL: -1.7830e+00
# Epoch 694/1000  Train NLL: -4.0922e+00  Test NLL: -1.9128e+00
# Epoch 695/1000  Train NLL: -4.0916e+00  Test NLL: -2.0810e+00
# Epoch 696/1000  Train NLL: -4.1091e+00  Test NLL: -1.9655e+00
# Epoch 697/1000  Train NLL: -4.1001e+00  Test NLL: -2.0378e+00
# Epoch 698/1000  Train NLL: -4.1196e+00  Test NLL: -2.0138e+00
# Epoch 699/1000  Train NLL: -4.1360e+00  Test NLL: -1.8421e+00
# Epoch 700/1000  Train NLL: -4.1044e+00  Test NLL: -1.9642e+00
# Epoch 701/1000  Train NLL: -4.1189e+00  Test NLL: -2.0781e+00
# Epoch 702/1000  Train NLL: -4.1407e+00  Test NLL: -1.9755e+00
# Epoch 703/1000  Train NLL: -4.1182e+00  Test NLL: -2.0467e+00
# Epoch 704/1000  Train NLL: -4.1317e+00  Test NLL: -2.0423e+00
# Epoch 705/1000  Train NLL: -4.1558e+00  Test NLL: -1.9077e+00
# Epoch 706/1000  Train NLL: -4.1293e+00  Test NLL: -2.0087e+00
# Epoch 707/1000  Train NLL: -4.1548e+00  Test NLL: -2.0734e+00
# Epoch 708/1000  Train NLL: -4.1714e+00  Test NLL: -1.9708e+00
# Epoch 709/1000  Train NLL: -4.1431e+00  Test NLL: -2.0539e+00
# Epoch 710/1000  Train NLL: -4.1544e+00  Test NLL: -2.0532e+00
# Epoch 711/1000  Train NLL: -4.1637e+00  Test NLL: -1.9225e+00
# Epoch 712/1000  Train NLL: -4.1506e+00  Test NLL: -1.9939e+00
# Epoch 713/1000  Train NLL: -4.1612e+00  Test NLL: -2.0920e+00
# Epoch 714/1000  Train NLL: -4.1703e+00  Test NLL: -1.9958e+00
# Epoch 715/1000  Train NLL: -4.1525e+00  Test NLL: -2.0674e+00
# Epoch 716/1000  Train NLL: -4.1693e+00  Test NLL: -2.0257e+00
# Epoch 717/1000  Train NLL: -4.1931e+00  Test NLL: -1.8739e+00
# Epoch 718/1000  Train NLL: -4.1494e+00  Test NLL: -2.0214e+00
# Epoch 719/1000  Train NLL: -4.1897e+00  Test NLL: -2.1114e+00
# Epoch 720/1000  Train NLL: -4.1759e+00  Test NLL: -2.0268e+00
# Epoch 721/1000  Train NLL: -4.1621e+00  Test NLL: -2.0807e+00
# Epoch 722/1000  Train NLL: -4.2035e+00  Test NLL: -2.0579e+00
# Epoch 723/1000  Train NLL: -4.2021e+00  Test NLL: -1.9750e+00
# Epoch 724/1000  Train NLL: -4.1615e+00  Test NLL: -2.0777e+00
# Epoch 725/1000  Train NLL: -4.2128e+00  Test NLL: -2.0500e+00
# Epoch 726/1000  Train NLL: -4.2300e+00  Test NLL: -1.9385e+00
# Epoch 727/1000  Train NLL: -4.1858e+00  Test NLL: -2.0596e+00
# Epoch 728/1000  Train NLL: -4.1950e+00  Test NLL: -2.0535e+00
# Epoch 729/1000  Train NLL: -4.2301e+00  Test NLL: -1.8701e+00
# Epoch 730/1000  Train NLL: -4.2018e+00  Test NLL: -1.9986e+00
# Epoch 731/1000  Train NLL: -4.2075e+00  Test NLL: -2.1117e+00
# Epoch 732/1000  Train NLL: -4.2358e+00  Test NLL: -1.9950e+00
# Epoch 733/1000  Train NLL: -4.2094e+00  Test NLL: -2.0752e+00
# Epoch 734/1000  Train NLL: -4.2217e+00  Test NLL: -2.0811e+00
# Epoch 735/1000  Train NLL: -4.2359e+00  Test NLL: -1.9447e+00
# Epoch 736/1000  Train NLL: -4.2161e+00  Test NLL: -2.0361e+00
# Epoch 737/1000  Train NLL: -4.2344e+00  Test NLL: -2.1058e+00
# Epoch 738/1000  Train NLL: -4.2554e+00  Test NLL: -1.9706e+00
# Epoch 739/1000  Train NLL: -4.2228e+00  Test NLL: -2.0777e+00
# Epoch 740/1000  Train NLL: -4.2373e+00  Test NLL: -2.0776e+00
# Epoch 741/1000  Train NLL: -4.2603e+00  Test NLL: -1.9189e+00
# Epoch 742/1000  Train NLL: -4.2332e+00  Test NLL: -2.0162e+00
# Epoch 743/1000  Train NLL: -4.2470e+00  Test NLL: -2.1361e+00
# Epoch 744/1000  Train NLL: -4.2595e+00  Test NLL: -2.0467e+00
# Epoch 745/1000  Train NLL: -4.2392e+00  Test NLL: -2.1141e+00
# Epoch 746/1000  Train NLL: -4.2636e+00  Test NLL: -2.0688e+00
# Epoch 747/1000  Train NLL: -4.2876e+00  Test NLL: -1.8794e+00
# Epoch 748/1000  Train NLL: -4.2573e+00  Test NLL: -1.9764e+00
# Epoch 749/1000  Train NLL: -4.2271e+00  Test NLL: -2.1231e+00
# Epoch 750/1000  Train NLL: -4.3016e+00  Test NLL: -1.8273e+00
# Epoch 751/1000  Train NLL: -4.2208e+00  Test NLL: -2.1178e+00
# Epoch 752/1000  Train NLL: -4.2914e+00  Test NLL: -2.0929e+00
# Epoch 753/1000  Train NLL: -4.2997e+00  Test NLL: -1.9615e+00
# Epoch 754/1000  Train NLL: -4.2889e+00  Test NLL: -1.9348e+00
# Epoch 755/1000  Train NLL: -4.2264e+00  Test NLL: -2.0333e+00
# Epoch 756/1000  Train NLL: -3.9941e+00  Test NLL: -1.9960e+00
# Epoch 757/1000  Train NLL: -4.1394e+00  Test NLL: -2.1312e+00
# Epoch 758/1000  Train NLL: -4.2724e+00  Test NLL: -2.1162e+00
# Epoch 759/1000  Train NLL: -4.3581e+00  Test NLL: -1.8782e+00
# Epoch 760/1000  Train NLL: -4.1972e+00  Test NLL: -2.0524e+00
# Epoch 761/1000  Train NLL: -4.2406e+00  Test NLL: -2.0353e+00
# Epoch 762/1000  Train NLL: -4.2292e+00  Test NLL: -1.9715e+00
# Epoch 763/1000  Train NLL: -4.1624e+00  Test NLL: -2.0994e+00
# Epoch 764/1000  Train NLL: -4.2425e+00  Test NLL: -2.1118e+00
# Epoch 765/1000  Train NLL: -4.3205e+00  Test NLL: -2.1076e+00
# Epoch 766/1000  Train NLL: -4.3365e+00  Test NLL: -2.1668e+00
# Epoch 767/1000  Train NLL: -4.3414e+00  Test NLL: -2.1564e+00
# Epoch 768/1000  Train NLL: -4.3482e+00  Test NLL: -2.1080e+00
# Epoch 769/1000  Train NLL: -4.3640e+00  Test NLL: -2.0682e+00
# Epoch 770/1000  Train NLL: -4.3297e+00  Test NLL: -2.0928e+00
# Epoch 771/1000  Train NLL: -4.3547e+00  Test NLL: -2.0447e+00
# Epoch 772/1000  Train NLL: -4.3535e+00  Test NLL: -2.0740e+00
# Epoch 773/1000  Train NLL: -4.3616e+00  Test NLL: -2.0987e+00
# Epoch 774/1000  Train NLL: -4.3612e+00  Test NLL: -2.1313e+00
# Epoch 775/1000  Train NLL: -4.3677e+00  Test NLL: -2.0830e+00
# Epoch 776/1000  Train NLL: -4.3679e+00  Test NLL: -2.0837e+00
# Epoch 777/1000  Train NLL: -4.3742e+00  Test NLL: -2.1058e+00
# Epoch 778/1000  Train NLL: -4.3799e+00  Test NLL: -2.0689e+00
# Epoch 779/1000  Train NLL: -4.3814e+00  Test NLL: -2.0359e+00
# Epoch 780/1000  Train NLL: -4.3713e+00  Test NLL: -2.1319e+00
# Epoch 781/1000  Train NLL: -4.3857e+00  Test NLL: -2.0805e+00
# Epoch 782/1000  Train NLL: -4.3672e+00  Test NLL: -2.1681e+00
# Epoch 783/1000  Train NLL: -4.3904e+00  Test NLL: -2.1236e+00
# Epoch 784/1000  Train NLL: -4.3860e+00  Test NLL: -2.1794e+00
# Epoch 785/1000  Train NLL: -4.3917e+00  Test NLL: -2.0772e+00
# Epoch 786/1000  Train NLL: -4.3865e+00  Test NLL: -2.1780e+00
# Epoch 787/1000  Train NLL: -4.4044e+00  Test NLL: -2.0755e+00
# Epoch 788/1000  Train NLL: -4.3988e+00  Test NLL: -2.1582e+00
# Epoch 789/1000  Train NLL: -4.4160e+00  Test NLL: -2.1013e+00
# Epoch 790/1000  Train NLL: -4.4108e+00  Test NLL: -2.1590e+00
# Epoch 791/1000  Train NLL: -4.4250e+00  Test NLL: -2.0999e+00
# Epoch 792/1000  Train NLL: -4.4232e+00  Test NLL: -2.1218e+00
# Epoch 793/1000  Train NLL: -4.4271e+00  Test NLL: -2.1670e+00
# Epoch 794/1000  Train NLL: -4.4323e+00  Test NLL: -2.1815e+00
# Epoch 795/1000  Train NLL: -4.4343e+00  Test NLL: -2.0846e+00
# Epoch 796/1000  Train NLL: -4.4298e+00  Test NLL: -2.1024e+00
# Epoch 797/1000  Train NLL: -4.4351e+00  Test NLL: -2.1731e+00
# Epoch 798/1000  Train NLL: -4.4499e+00  Test NLL: -2.1563e+00
# Epoch 799/1000  Train NLL: -4.4481e+00  Test NLL: -2.1376e+00
# Epoch 800/1000  Train NLL: -4.4530e+00  Test NLL: -2.1447e+00
# Epoch 801/1000  Train NLL: -4.4564e+00  Test NLL: -2.1334e+00
# Epoch 802/1000  Train NLL: -4.4560e+00  Test NLL: -2.1436e+00
# Epoch 803/1000  Train NLL: -4.4545e+00  Test NLL: -2.1797e+00
# Epoch 804/1000  Train NLL: -4.4710e+00  Test NLL: -2.1635e+00
# Epoch 805/1000  Train NLL: -4.4652e+00  Test NLL: -2.2026e+00
# Epoch 806/1000  Train NLL: -4.4666e+00  Test NLL: -2.2216e+00
# Epoch 807/1000  Train NLL: -4.4740e+00  Test NLL: -2.1268e+00
# Epoch 808/1000  Train NLL: -4.4748e+00  Test NLL: -2.1468e+00
# Epoch 809/1000  Train NLL: -4.4806e+00  Test NLL: -2.1889e+00
# Epoch 810/1000  Train NLL: -4.4879e+00  Test NLL: -2.1662e+00
# Epoch 811/1000  Train NLL: -4.4814e+00  Test NLL: -2.2189e+00
# Epoch 812/1000  Train NLL: -4.4991e+00  Test NLL: -2.1480e+00
# Epoch 813/1000  Train NLL: -4.4889e+00  Test NLL: -2.1995e+00
# Epoch 814/1000  Train NLL: -4.5100e+00  Test NLL: -2.1183e+00
# Epoch 815/1000  Train NLL: -4.4643e+00  Test NLL: -2.1332e+00
# Epoch 816/1000  Train NLL: -4.4753e+00  Test NLL: -2.1853e+00
# Epoch 817/1000  Train NLL: -4.4964e+00  Test NLL: -2.2033e+00
# Epoch 818/1000  Train NLL: -4.5209e+00  Test NLL: -2.2017e+00
# Epoch 819/1000  Train NLL: -4.4895e+00  Test NLL: -2.1983e+00
# Epoch 820/1000  Train NLL: -4.4911e+00  Test NLL: -2.2409e+00
# Epoch 821/1000  Train NLL: -4.5005e+00  Test NLL: -2.1080e+00
# Epoch 822/1000  Train NLL: -4.4997e+00  Test NLL: -2.2181e+00
# Epoch 823/1000  Train NLL: -4.5209e+00  Test NLL: -2.1982e+00
# Epoch 824/1000  Train NLL: -4.5194e+00  Test NLL: -2.2058e+00
# Epoch 825/1000  Train NLL: -4.5603e+00  Test NLL: -1.9901e+00
# Epoch 826/1000  Train NLL: -4.3558e+00  Test NLL: -2.1440e+00
# Epoch 827/1000  Train NLL: -4.3507e+00  Test NLL: -2.0500e+00
# Epoch 828/1000  Train NLL: -4.3426e+00  Test NLL: -2.1056e+00
# Epoch 829/1000  Train NLL: -4.3947e+00  Test NLL: -2.1959e+00
# Epoch 830/1000  Train NLL: -4.4230e+00  Test NLL: -1.7339e+00
# Epoch 831/1000  Train NLL: -4.3756e+00  Test NLL: -2.0392e+00
# Epoch 832/1000  Train NLL: -4.3638e+00  Test NLL: -2.0342e+00
# Epoch 833/1000  Train NLL: -4.4743e+00  Test NLL: -2.0499e+00
# Epoch 834/1000  Train NLL: -4.3167e+00  Test NLL: -2.1969e+00
# Epoch 835/1000  Train NLL: -4.4396e+00  Test NLL: -2.1301e+00
# Epoch 836/1000  Train NLL: -4.4672e+00  Test NLL: -1.8918e+00
# Epoch 837/1000  Train NLL: -4.3741e+00  Test NLL: -2.1536e+00
# Epoch 838/1000  Train NLL: -4.4378e+00  Test NLL: -2.1274e+00
# Epoch 839/1000  Train NLL: -4.4823e+00  Test NLL: -1.8608e+00
# Epoch 840/1000  Train NLL: -4.3990e+00  Test NLL: -2.1500e+00
# Epoch 841/1000  Train NLL: -4.4427e+00  Test NLL: -2.0701e+00
# Epoch 842/1000  Train NLL: -4.5156e+00  Test NLL: -1.8553e+00
# Epoch 843/1000  Train NLL: -4.3816e+00  Test NLL: -2.1955e+00
# Epoch 844/1000  Train NLL: -4.5031e+00  Test NLL: -2.1911e+00
# Epoch 845/1000  Train NLL: -4.4991e+00  Test NLL: -2.0531e+00
# Epoch 846/1000  Train NLL: -4.3926e+00  Test NLL: -2.2496e+00
# Epoch 847/1000  Train NLL: -4.5021e+00  Test NLL: -2.1426e+00
# Epoch 848/1000  Train NLL: -4.4955e+00  Test NLL: -2.1635e+00
# Epoch 849/1000  Train NLL: -4.5137e+00  Test NLL: -1.8265e+00
# Epoch 850/1000  Train NLL: -4.2295e+00  Test NLL: -1.5703e+00
# Epoch 851/1000  Train NLL: -4.1946e+00  Test NLL: -1.6107e+00
# Epoch 852/1000  Train NLL: -4.0115e+00  Test NLL: -1.9582e+00
# Epoch 853/1000  Train NLL: -4.3597e+00  Test NLL: -2.0402e+00
# Epoch 854/1000  Train NLL: -4.3522e+00  Test NLL: -1.7748e+00
# Epoch 855/1000  Train NLL: -4.3898e+00  Test NLL: -2.3003e+00
# Epoch 856/1000  Train NLL: -4.3950e+00  Test NLL: -2.0562e+00
# Epoch 857/1000  Train NLL: -4.4530e+00  Test NLL: -2.1356e+00
# Epoch 858/1000  Train NLL: -4.4809e+00  Test NLL: -2.1365e+00
# Epoch 859/1000  Train NLL: -4.5460e+00  Test NLL: -2.2936e+00
# Epoch 860/1000  Train NLL: -4.3848e+00  Test NLL: -2.0219e+00
# Epoch 861/1000  Train NLL: -4.4260e+00  Test NLL: -2.1389e+00
# Epoch 862/1000  Train NLL: -4.6131e+00  Test NLL: -2.0621e+00
# Epoch 863/1000  Train NLL: -4.4536e+00  Test NLL: -2.2519e+00
# Epoch 864/1000  Train NLL: -4.5865e+00  Test NLL: -2.3088e+00
# Epoch 865/1000  Train NLL: -4.5938e+00  Test NLL: -2.2091e+00
# Epoch 866/1000  Train NLL: -4.6458e+00  Test NLL: -1.9821e+00
# Epoch 867/1000  Train NLL: -4.4822e+00  Test NLL: -2.2311e+00
# Epoch 868/1000  Train NLL: -4.6058e+00  Test NLL: -2.1424e+00
# Epoch 869/1000  Train NLL: -4.6539e+00  Test NLL: -2.2497e+00
# Epoch 870/1000  Train NLL: -4.6425e+00  Test NLL: -2.1655e+00
# Epoch 871/1000  Train NLL: -4.6356e+00  Test NLL: -2.1923e+00
# Epoch 872/1000  Train NLL: -4.5651e+00  Test NLL: -2.2268e+00
# Epoch 873/1000  Train NLL: -4.6138e+00  Test NLL: -2.0145e+00
# Epoch 874/1000  Train NLL: -4.5328e+00  Test NLL: -2.2405e+00
# Epoch 875/1000  Train NLL: -4.6114e+00  Test NLL: -2.3030e+00
# Epoch 876/1000  Train NLL: -4.6093e+00  Test NLL: -2.0641e+00
# Epoch 877/1000  Train NLL: -4.5677e+00  Test NLL: -2.1872e+00
# Epoch 878/1000  Train NLL: -4.5834e+00  Test NLL: -2.2611e+00
# Epoch 879/1000  Train NLL: -4.6155e+00  Test NLL: -2.0267e+00
# Epoch 880/1000  Train NLL: -4.5691e+00  Test NLL: -2.2041e+00
# Epoch 881/1000  Train NLL: -4.6008e+00  Test NLL: -2.2527e+00
# Epoch 882/1000  Train NLL: -4.6245e+00  Test NLL: -2.0415e+00
# Epoch 883/1000  Train NLL: -4.5816e+00  Test NLL: -2.2454e+00
# Epoch 884/1000  Train NLL: -4.5981e+00  Test NLL: -2.1706e+00
# Epoch 885/1000  Train NLL: -4.6632e+00  Test NLL: -2.0466e+00
# Epoch 886/1000  Train NLL: -4.5943e+00  Test NLL: -2.2786e+00
# Epoch 887/1000  Train NLL: -4.5959e+00  Test NLL: -2.1420e+00
# Epoch 888/1000  Train NLL: -4.5724e+00  Test NLL: -2.3236e+00
# Epoch 889/1000  Train NLL: -4.6739e+00  Test NLL: -2.3118e+00
# Epoch 890/1000  Train NLL: -4.6830e+00  Test NLL: -2.2497e+00
# Epoch 891/1000  Train NLL: -4.6735e+00  Test NLL: -2.2966e+00
# Epoch 892/1000  Train NLL: -4.6617e+00  Test NLL: -2.3376e+00
# Epoch 893/1000  Train NLL: -4.7554e+00  Test NLL: -2.2556e+00
# Epoch 894/1000  Train NLL: -4.7341e+00  Test NLL: -2.3353e+00
# Epoch 895/1000  Train NLL: -4.7445e+00  Test NLL: -2.0903e+00
# Epoch 896/1000  Train NLL: -4.6506e+00  Test NLL: -2.2665e+00
# Epoch 897/1000  Train NLL: -4.7307e+00  Test NLL: -2.2516e+00
# Epoch 898/1000  Train NLL: -4.7122e+00  Test NLL: -1.9977e+00
# Epoch 899/1000  Train NLL: -4.1161e+00  Test NLL: -2.3218e+00
# Epoch 900/1000  Train NLL: -4.2931e+00  Test NLL: -1.9932e+00
# Epoch 901/1000  Train NLL: -4.4844e+00  Test NLL: -2.1320e+00
# Epoch 902/1000  Train NLL: -4.6274e+00  Test NLL: -2.2085e+00
# Epoch 903/1000  Train NLL: -4.7152e+00  Test NLL: -2.2349e+00
# Epoch 904/1000  Train NLL: -4.7059e+00  Test NLL: -2.3296e+00
# Epoch 905/1000  Train NLL: -4.7654e+00  Test NLL: -2.3449e+00
# Epoch 906/1000  Train NLL: -4.7458e+00  Test NLL: -2.2960e+00
# Epoch 907/1000  Train NLL: -4.7677e+00  Test NLL: -2.2554e+00
# Epoch 908/1000  Train NLL: -4.7549e+00  Test NLL: -2.3609e+00
# Epoch 909/1000  Train NLL: -4.7654e+00  Test NLL: -2.3476e+00
# Epoch 910/1000  Train NLL: -4.7637e+00  Test NLL: -2.3259e+00
# Epoch 911/1000  Train NLL: -4.7719e+00  Test NLL: -2.2318e+00
# Epoch 912/1000  Train NLL: -4.7775e+00  Test NLL: -2.2855e+00
# Epoch 913/1000  Train NLL: -4.7667e+00  Test NLL: -2.3752e+00
# Epoch 914/1000  Train NLL: -4.7587e+00  Test NLL: -2.3573e+00
# Epoch 915/1000  Train NLL: -4.7525e+00  Test NLL: -2.2941e+00
# Epoch 916/1000  Train NLL: -4.8128e+00  Test NLL: -2.3931e+00
# Epoch 917/1000  Train NLL: -4.8350e+00  Test NLL: -2.2769e+00
# Epoch 918/1000  Train NLL: -4.7642e+00  Test NLL: -2.3443e+00
# Epoch 919/1000  Train NLL: -4.7805e+00  Test NLL: -2.2581e+00
# Epoch 920/1000  Train NLL: -4.7445e+00  Test NLL: -2.2988e+00
# Epoch 921/1000  Train NLL: -4.7688e+00  Test NLL: -2.3542e+00
# Epoch 922/1000  Train NLL: -4.7768e+00  Test NLL: -2.3200e+00
# Epoch 923/1000  Train NLL: -4.7843e+00  Test NLL: -2.3116e+00
# Epoch 924/1000  Train NLL: -4.7827e+00  Test NLL: -2.3469e+00
# Epoch 925/1000  Train NLL: -4.7864e+00  Test NLL: -2.2506e+00
# Epoch 926/1000  Train NLL: -4.7785e+00  Test NLL: -2.3364e+00
# Epoch 927/1000  Train NLL: -4.7969e+00  Test NLL: -2.2023e+00
# Epoch 928/1000  Train NLL: -4.7829e+00  Test NLL: -2.2870e+00
# Epoch 929/1000  Train NLL: -4.7989e+00  Test NLL: -2.2734e+00
# Epoch 930/1000  Train NLL: -4.7959e+00  Test NLL: -2.3098e+00
# Epoch 931/1000  Train NLL: -4.8129e+00  Test NLL: -2.2246e+00
# Epoch 932/1000  Train NLL: -4.8076e+00  Test NLL: -2.2027e+00
# Epoch 933/1000  Train NLL: -4.7983e+00  Test NLL: -2.3757e+00
# Epoch 934/1000  Train NLL: -4.8221e+00  Test NLL: -2.3557e+00
# Epoch 935/1000  Train NLL: -4.8236e+00  Test NLL: -2.3137e+00
# Epoch 936/1000  Train NLL: -4.8266e+00  Test NLL: -2.3442e+00
# Epoch 937/1000  Train NLL: -4.8295e+00  Test NLL: -2.3112e+00
# Epoch 938/1000  Train NLL: -4.8347e+00  Test NLL: -2.3311e+00
# Epoch 939/1000  Train NLL: -4.8373e+00  Test NLL: -2.3096e+00
# Epoch 940/1000  Train NLL: -4.8400e+00  Test NLL: -2.3163e+00
# Epoch 941/1000  Train NLL: -4.8420e+00  Test NLL: -2.3528e+00
# Epoch 942/1000  Train NLL: -4.8488e+00  Test NLL: -2.3721e+00
# Epoch 943/1000  Train NLL: -4.8482e+00  Test NLL: -2.2888e+00
# Epoch 944/1000  Train NLL: -4.8473e+00  Test NLL: -2.2997e+00
# Epoch 945/1000  Train NLL: -4.8498e+00  Test NLL: -2.3494e+00
# Epoch 946/1000  Train NLL: -4.8588e+00  Test NLL: -2.3450e+00
# Epoch 947/1000  Train NLL: -4.8556e+00  Test NLL: -2.3652e+00
# Epoch 948/1000  Train NLL: -4.8551e+00  Test NLL: -2.3843e+00
# Epoch 949/1000  Train NLL: -4.8611e+00  Test NLL: -2.3932e+00
# Epoch 950/1000  Train NLL: -4.8829e+00  Test NLL: -2.3320e+00
# Epoch 951/1000  Train NLL: -4.8689e+00  Test NLL: -2.2943e+00
# Epoch 952/1000  Train NLL: -4.8680e+00  Test NLL: -2.3399e+00
# Epoch 953/1000  Train NLL: -4.8720e+00  Test NLL: -2.3760e+00
# Epoch 954/1000  Train NLL: -4.8783e+00  Test NLL: -2.3627e+00
# Epoch 955/1000  Train NLL: -4.8804e+00  Test NLL: -2.3577e+00
# Epoch 956/1000  Train NLL: -4.8915e+00  Test NLL: -2.3701e+00
# Epoch 957/1000  Train NLL: -4.8871e+00  Test NLL: -2.3673e+00
# Epoch 958/1000  Train NLL: -4.8874e+00  Test NLL: -2.3973e+00
# Epoch 959/1000  Train NLL: -4.8924e+00  Test NLL: -2.2729e+00
# Epoch 960/1000  Train NLL: -4.8891e+00  Test NLL: -2.3319e+00
# Epoch 961/1000  Train NLL: -4.9000e+00  Test NLL: -2.3311e+00
# Epoch 962/1000  Train NLL: -4.9051e+00  Test NLL: -2.3385e+00
# Epoch 963/1000  Train NLL: -4.9055e+00  Test NLL: -2.3762e+00
# Epoch 964/1000  Train NLL: -4.9095e+00  Test NLL: -2.3725e+00
# Epoch 965/1000  Train NLL: -4.9127e+00  Test NLL: -2.3636e+00
# Epoch 966/1000  Train NLL: -4.9107e+00  Test NLL: -2.3802e+00
# Epoch 967/1000  Train NLL: -4.9063e+00  Test NLL: -2.4195e+00
# Epoch 968/1000  Train NLL: -4.9105e+00  Test NLL: -2.3955e+00
# Epoch 969/1000  Train NLL: -4.9159e+00  Test NLL: -2.4397e+00
# Epoch 970/1000  Train NLL: -4.8921e+00  Test NLL: -2.3581e+00
# Epoch 971/1000  Train NLL: -4.9688e+00  Test NLL: -2.4581e+00
# Epoch 972/1000  Train NLL: -4.7993e+00  Test NLL: -1.9523e+00
# Epoch 973/1000  Train NLL: -4.7608e+00  Test NLL: -2.2595e+00
# Epoch 974/1000  Train NLL: -4.8397e+00  Test NLL: -2.4636e+00
# Epoch 975/1000  Train NLL: -4.5457e+00  Test NLL: -2.0528e+00
# Epoch 976/1000  Train NLL: -4.6665e+00  Test NLL: -2.1435e+00
# Epoch 977/1000  Train NLL: -4.8126e+00  Test NLL: -2.2185e+00
# Epoch 978/1000  Train NLL: -4.8991e+00  Test NLL: -2.4166e+00
# Epoch 979/1000  Train NLL: -4.9143e+00  Test NLL: -2.3727e+00
# Epoch 980/1000  Train NLL: -4.9237e+00  Test NLL: -2.2963e+00
# Epoch 981/1000  Train NLL: -4.9268e+00  Test NLL: -2.4599e+00
# Epoch 982/1000  Train NLL: -4.9343e+00  Test NLL: -2.4579e+00
# Epoch 983/1000  Train NLL: -4.9461e+00  Test NLL: -2.2750e+00
# Epoch 984/1000  Train NLL: -4.9391e+00  Test NLL: -2.3412e+00
# Epoch 985/1000  Train NLL: -4.9547e+00  Test NLL: -2.3779e+00
# Epoch 986/1000  Train NLL: -4.9498e+00  Test NLL: -2.4221e+00
# Epoch 987/1000  Train NLL: -4.9594e+00  Test NLL: -2.3088e+00
# Epoch 988/1000  Train NLL: -4.9621e+00  Test NLL: -2.3357e+00
# Epoch 989/1000  Train NLL: -4.9689e+00  Test NLL: -2.4231e+00
# Epoch 990/1000  Train NLL: -4.9743e+00  Test NLL: -2.4268e+00
# Epoch 991/1000  Train NLL: -4.9725e+00  Test NLL: -2.2987e+00
# Epoch 992/1000  Train NLL: -4.9787e+00  Test NLL: -2.3139e+00
# Epoch 993/1000  Train NLL: -4.9782e+00  Test NLL: -2.3516e+00
# Epoch 994/1000  Train NLL: -4.9696e+00  Test NLL: -2.3622e+00
# Epoch 995/1000  Train NLL: -4.9850e+00  Test NLL: -2.2964e+00
# Epoch 996/1000  Train NLL: -4.9772e+00  Test NLL: -2.4108e+00
# Epoch 997/1000  Train NLL: -4.9824e+00  Test NLL: -2.3468e+00
# Epoch 998/1000  Train NLL: -4.9703e+00  Test NLL: -2.4343e+00
# Epoch 999/1000  Train NLL: -5.0051e+00  Test NLL: -2.2514e+00
# Epoch 1000/1000  Train NLL: -4.9912e+00  Test NLL: -2.3358e+00

# %%
# Python
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

sec_per_year = 365*24*60*60

# 1) Build dt arrays (seconds and years)
tt_tr = pd.to_datetime(outs.C_train.index.values)  # [`pipeline.Algo1Outputs.C_train`](pipeline/algo1.py)
tt_te = pd.to_datetime(outs.C_test.index.values)   # [`pipeline.Algo1Outputs.C_test`](pipeline/algo1.py)

# Differences as Timedeltas, then robustly convert to NumPy float seconds
dt_tr_td = tt_tr[1:] - tt_tr[:-1]
dt_te_td = tt_te[1:] - tt_te[:-1]

dt_tr_s = np.asarray(pd.to_timedelta(dt_tr_td).total_seconds(), dtype=np.float64)
dt_te_s = np.asarray(pd.to_timedelta(dt_te_td).total_seconds(), dtype=np.float64)

dt_tr_y = dt_tr_s / sec_per_year
dt_te_y = dt_te_s / sec_per_year

# 2) Text summary
def summarize_dt(name, dt_s):
    dt_s = np.asarray(dt_s, dtype=np.float64)
    q = np.quantile(dt_s, [0,.01,.05,.25,.5,.75,.95,.99,1.0])
    print(f"{name}: pairs={dt_s.size}  mean={np.mean(dt_s):.2f}s  std={np.std(dt_s):.2f}s  median={q[4]:.2f}s")
    print(f"  quantiles (s): 0%={q[0]:.2f}, 1%={q[1]:.2f}, 5%={q[2]:.2f}, 25%={q[3]:.2f}, "
          f"50%={q[4]:.2f}, 75%={q[5]:.2f}, 95%={q[6]:.2f}, 99%={q[7]:.2f}, 100%={q[8]:.2f}")
    for thr in (1, 5, 10, 60, 300, 900):
        frac = float((dt_s > thr).mean())
        print(f"  frac(dt > {thr:>3}s) = {frac:6.2%}")

summarize_dt("Train Δt", dt_tr_s)
summarize_dt("Test  Δt", dt_te_s)

# 3) Plots: histogram (seconds) and ECDF
p99 = max(np.quantile(dt_tr_s, 0.99), np.quantile(dt_te_s, 0.99))
bins = np.linspace(0, p99, 60)

fig, axes = plt.subplots(1, 2, figsize=(10, 3.6))

# Histogram up to 99th percentile (seconds)
axes[0].hist(dt_tr_s, bins=bins, alpha=0.5, label="train")
axes[0].hist(dt_te_s, bins=bins, alpha=0.5, label="test")
axes[0].set_title("Δt histogram (seconds, up to 99th pct)")
axes[0].set_xlabel("Δt [s]"); axes[0].set_ylabel("count"); axes[0].legend()

# ECDF (years) for full range
def ecdf(x):
    x = np.sort(np.asarray(x, dtype=np.float64))
    y = np.linspace(0, 1, len(x), endpoint=False)
    return x, y

x_tr, y_tr = ecdf(dt_tr_y); x_te, y_te = ecdf(dt_te_y)
axes[1].plot(x_tr, y_tr, label="train")
axes[1].plot(x_te, y_te, label="test")
axes[1].set_title("Δt ECDF (years)")
axes[1].set_xlabel("Δt [years]"); axes[1].set_ylabel("F(Δt)"); axes[1].legend(loc="lower right")

plt.tight_layout(); plt.show()
# Out:
# Train Δt: pairs=1100  mean=60.00s  std=0.00s  median=60.00s
#   quantiles (s): 0%=60.00, 1%=60.00, 5%=60.00, 25%=60.00, 50%=60.00, 75%=60.00, 95%=60.00, 99%=60.00, 100%=60.00
#   frac(dt >   1s) = 100.00%
#   frac(dt >   5s) = 100.00%
#   frac(dt >  10s) = 100.00%
#   frac(dt >  60s) =  0.00%
#   frac(dt > 300s) =  0.00%
#   frac(dt > 900s) =  0.00%
# Test  Δt: pairs=339  mean=60.00s  std=0.00s  median=60.00s
#   quantiles (s): 0%=60.00, 1%=60.00, 5%=60.00, 25%=60.00, 50%=60.00, 75%=60.00, 95%=60.00, 99%=60.00, 100%=60.00
#   frac(dt >   1s) = 100.00%
#   frac(dt >   5s) = 100.00%
#   frac(dt >  10s) = 100.00%
#   frac(dt >  60s) =  0.00%
#   frac(dt > 300s) =  0.00%
#   frac(dt > 900s) =  0.00%

# %%
# In your neural_sde.ipynb after training
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
from scipy import stats
from neural_sde.loss import build_xi_training_data  # -> [`neural_sde.loss.build_xi_training_data`](neural_sde/loss.py)

sde_model = model

# 1) In-sample factor matrix (columns = factors: dyn | stat | sa)
X_train, _, names = build_xi_training_data(outs)  # names like ["dyn0","dyn1",...,"stat0",...,"sa0",...]

# 2) Compute dt in years from training timestamps (align lengths)
tt = pd.to_datetime(outs.C_train.index.values)
# sec_per_year = 1
dt = np.asarray((tt[1:] - tt[:-1]).total_seconds(), dtype=np.float64) / sec_per_year

L = min(len(dt), X_train.shape[0]-1)

device = next(sde_model.parameters()).device
Y0 = torch.from_numpy(X_train[:L]).float().to(device)
Y1 = torch.from_numpy(X_train[1:L+1]).float().to(device)
dt_t = torch.from_numpy(dt[:L].copy()).float().unsqueeze(1).clamp_min(1e-12).to(device)

with torch.no_grad():
    mu  = sde_model.f(0.0, Y0)
    sig = sde_model.g(0.0, Y0).clamp_min(1e-9)
    eps = (Y1 - Y0 - mu*dt_t) / (sig * torch.sqrt(dt_t))
resid = eps.cpu().numpy()

# 3) One-step standardized residuals under the trained SDE
#    ε_t = (x_{t+1} - x_t - f(x_t)Δt) / (g(x_t)√Δt)
with torch.no_grad():
    mu = sde_model.f(0.0, Y0)                        # [`neural_sde.nets.NeuralSDE.f`](neural_sde/nets.py)
    sig = sde_model.g(0.0, Y0).clamp_min(1e-9)       # [`neural_sde.nets.NeuralSDE.g`](neural_sde/nets.py)
    eps = (Y1 - Y0 - mu*dt_t) / (sig * torch.sqrt(dt_t))
resid = eps.cpu().numpy()

# 4) QQ plots per factor
d = resid.shape[1]
cols = 3
rows = int(np.ceil(d/cols))
fig, axes = plt.subplots(rows, cols, figsize=(cols*3.2, rows*3.2))
axes = axes.ravel()

for j in range(d):
    stats.probplot(resid[:, j], dist="norm", plot=axes[j])
    axes[j].set_title(names[j] if names else f"factor {j}")

for k in range(d, len(axes)):
    axes[k].axis("off")

plt.tight_layout()
plt.show()

# %%
# Pairwise scatter plots of residuals
import numpy as np
import matplotlib.pyplot as plt
from itertools import combinations
import math

R = np.asarray(resid, float)  # shape (T-1, d)
d = R.shape[1]
labels = names if (isinstance(names, (list, tuple)) and len(names)==d) else [f"f{j}" for j in range(d)]

pairs = list(combinations(range(d), 2))
cols = min(3, len(pairs))
rows = math.ceil(len(pairs) / cols)
fig, axes = plt.subplots(rows, cols, figsize=(cols*4.2, rows*3.8), squeeze=False)

for ax, (i, j) in zip(axes.ravel(), pairs):
    x, y = R[:, i], R[:, j]
    rho = np.corrcoef(x, y)[0, 1]
    ax.scatter(x, y, s=10, alpha=0.4, edgecolors="none")
    ax.axhline(0, color="k", lw=0.5, alpha=0.6)
    ax.axvline(0, color="k", lw=0.5, alpha=0.6)
    ax.set_xlabel(labels[i]); ax.set_ylabel(labels[j])
    ax.set_title(f"{labels[i]} vs {labels[j]}  (ρ={rho:.2f})")
    ax.grid(alpha=0.15)

# hide any unused axes
for k in range(len(pairs), rows*cols):
    fig.delaxes(axes.ravel()[k])

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Simulation of Prices with Factors

# %%
# Requires:
# - outs from decoding (Algo1Outputs, e.g. from decoding_aggre.ipynb)
# - model from neural_sde training (e.g. likelihood_training)
# Optional:
# - mu, sd returned by likelihood_training if standardisation was used

import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
from neural_sde.loss import build_xi_training_data  # -> [`neural_sde.loss.build_xi_training_data`](neural_sde/loss.py)

device = next(model.parameters()).device

# 1) Factor dimension and helper to split [dyn|stat|sa] blocks (order matches build_xi_training_data)
k_dyn  = outs.G_dyn.shape[0] if getattr(outs, "G_dyn", None) is not None and outs.G_dyn.size else 0
k_stat = outs.G_stat.shape[0] if getattr(outs, "G_stat", None) is not None and outs.G_stat.size else 0
k_sa   = outs.G_sa.shape[0]   if getattr(outs, "G_sa",   None) is not None and outs.G_sa.size   else 0
p = k_dyn + k_stat + k_sa
N = outs.G0.shape[0]  # number of nodes

def split_blocks(x):
    """x: (..., p) -> (xd, xs, xa)"""
    i = 0
    xd = x[..., i:i+k_dyn];  i += k_dyn
    xs = x[..., i:i+k_stat]; i += k_stat
    xa = x[..., i:i+k_sa] if k_sa>0 else x[..., :0]
    return xd, xs, xa

# 2) Build train factors (for x0) and dt (years)
X_tr, _, names = build_xi_training_data(outs)
x0_raw = X_tr[-1].astype(np.float64)  # last observed state as start

sec_per_year = 365.0*24*3600
tt_tr = pd.to_datetime(outs.C_train.index.values)
dt_tr = np.asarray((tt_tr[1:] - tt_tr[:-1]).total_seconds(), dtype=np.float64) / sec_per_year
dt = float(np.median(dt_tr)) if len(dt_tr) else (1.0/365/24/60)  # ~1 minute fallback

# 3) Prepare standardisation if available (depends on your likelihood_training return)
def to_model_space(x):
    if 'mu' in globals() and 'sd' in globals() and (mu is not None) and (sd is not None):
        mu_np = mu.detach().cpu().numpy() if torch.is_tensor(mu) else np.asarray(mu)
        sd_np = sd.detach().cpu().numpy() if torch.is_tensor(sd) else np.asarray(sd)
        return (x - mu_np.ravel()) / (sd_np.ravel() + 1e-9)
    return x

def from_model_space(x):
    if 'mu' in globals() and 'sd' in globals() and (mu is not None) and (sd is not None):
        mu_np = mu.detach().cpu().numpy() if torch.is_tensor(mu) else np.asarray(mu)
        sd_np = sd.detach().cpu().numpy() if torch.is_tensor(sd) else np.asarray(sd)
        return x * sd_np.ravel() + mu_np.ravel()
    return x

# 4) Euler–Maruyama simulation for factors under [`neural_sde.nets.NeuralSDE`](neural_sde/nets.py)
@torch.no_grad()
def simulate_factors(model, x0_raw, n_steps=60, n_paths=256, dt_years=dt, clamp_sig=1e-9):
    x0 = to_model_space(x0_raw.astype(np.float64))
    x  = torch.from_numpy(np.tile(x0, (n_paths, 1))).float().to(device)  # (B, p)
    out = [x.clone()]
    DT = torch.tensor(dt_years, dtype=torch.float32, device=device).view(1,1)
    for _ in range(n_steps):
        mu  = model.f(0.0, x)
        sig = model.g(0.0, x).clamp_min(clamp_sig)        # diagonal diffusion per-dim
        eps = torch.randn_like(x)
        x   = x + mu*DT + sig*torch.sqrt(DT)*eps
        out.append(x.clone())
    X_std = torch.stack(out, dim=1)  # (B, T+1, p)
    X_raw = from_model_space(X_std.cpu().numpy())
    return X_raw  # numpy (n_paths, n_steps+1, p)

# 5) Map factors -> normalized option prices at each lattice node
#    C = G0 + Xi_dyn·G_dyn + Xi_stat·G_stat + Xi_sa·G_sa  (see [`factors.decode.reconstruct_prices`](factors/decode.py))
def factors_to_prices(X):
    """
    X: (B, T+1, p) in raw Xi space
    Returns: C: (B, T+1, N) normalized prices per node
    """
    B, T1, _ = X.shape
    C = np.empty((B, T1, N), dtype=np.float64)
    G0 = outs.G0.astype(np.float64)
    Gd = outs.G_dyn.astype(np.float64) if k_dyn>0 else np.zeros((0, N))
    Gs = outs.G_stat.astype(np.float64) if k_stat>0 else np.zeros((0, N))
    Ga = outs.G_sa.astype(np.float64)   if k_sa>0   else np.zeros((0, N))
    for t in range(T1):
        xt = X[:, t, :]                    # (B, p)
        xd, xs, xa = split_blocks(xt)      # (B,k_*)
        C[:, t, :] = (G0[None, :]
                      + (xd @ Gd) if k_dyn>0 else 0.0
                      + (xs @ Gs) if k_stat>0 else 0.0
                      + (xa @ Ga) if k_sa>0   else 0.0)
    # Optional no‑arb clipping to [max(1-exp(m),0), 1]
    m = outs.nodes_sub[:, 1].astype(np.float64)
    lb = np.maximum(1.0 - np.exp(m), 0.0)
    C = np.clip(C, lb[None, None, :], 1.0)
    return C

# 6) Run simulation and get price distribution at horizon
n_paths = 256
n_steps = 60   # horizon steps (~60 minutes if dt is 1 minute)
X_sim = simulate_factors(model, x0_raw, n_steps=n_steps, n_paths=n_paths, dt_years=dt)
C_sim = factors_to_prices(X_sim)   # (B, T+1, N)

# Choose horizon snapshot (final time)
C_T = C_sim[:, -1, :]              # (B, N)

from matplotlib.ticker import ScalarFormatter, FormatStrFormatter

def tidy_x_axis(ax, data):
    # turn off offset/scientific notation
    ax.ticklabel_format(axis="x", style="plain", useOffset=False)
    ax.get_xaxis().get_offset_text().set_visible(False)
    # choose a readable fixed-decimal formatter based on range
    rng = float(np.ptp(data))
    if rng < 0.02:
        fmt = FormatStrFormatter('%.4f')
    elif rng < 0.2:
        fmt = FormatStrFormatter('%.3f')
    else:
        fmt = FormatStrFormatter('%.2f')
    ax.xaxis.set_major_formatter(fmt)

# 7) Visualise: histograms for first 12 nodes and a violin summary
n_show = min(12, C_T.shape[1])
fig, axes = plt.subplots(int(np.ceil(n_show/4)), 4, figsize=(12, 2.2*np.ceil(n_show/4)), squeeze=False)
axes = axes.ravel()
for j in range(n_show):
    ax = axes[j]
    ax.hist(C_T[:, j], bins=40, alpha=0.8, color="#3a78b4")
    τ, m = outs.nodes_sub[j, 0], outs.nodes_sub[j, 1]
    tidy_x_axis(ax, C_T[:, j])
    ax.set_title(f"node {j}\nτ={τ:.2f}, m={m:.2f}", fontsize=9)
    ax.grid(alpha=0.2)
for k in range(n_show, len(axes)):
    fig.delaxes(axes[k])
fig.suptitle("Simulated normalized call price distributions at horizon", y=0.98)
plt.tight_layout(); plt.show()

# Violin summary: also remove offset on y (prices)
plt.figure(figsize=(10,3))
q_lo, q_md, q_hi = np.quantile(C_T, [0.1, 0.5, 0.9], axis=0)
plt.fill_between(np.arange(N), q_lo, q_hi, color="#c7dcef", alpha=0.9, label="10–90%")
plt.plot(q_md, color="#2c5d8a", lw=1.5, label="median")
ax = plt.gca()
ax.ticklabel_format(axis="y", style="plain", useOffset=False)
ax.get_yaxis().get_offset_text().set_visible(False)
ax.yaxis.set_major_formatter(FormatStrFormatter('%.3f'))
plt.title("Across-node distribution summary (horizon)"); plt.xlabel("node index"); plt.ylabel("C/F")
plt.legend(); plt.tight_layout(); plt.show()

# %%
def portfolio_var_from_C(C_sim, q, F0=1.0, multipliers=None, alpha=0.99):
    """
    C_sim: (B, T+1, N) normalized prices C/F
    q:     (N,) portfolio holdings per node
    F0:    scalar forward at t0 to convert to dollars (use 1.0 to stay normalized)
    multipliers: (N,) contract multipliers (default 1.0)
    """
    C_sim = np.asarray(C_sim)
    q = np.asarray(q).reshape(-1)
    B, T1, N = C_sim.shape
    assert q.shape[0] == N, "q must match number of nodes"

    w = np.ones(N) if multipliers is None else np.asarray(multipliers).reshape(-1)
    notional = q * F0 * w  # (N,)

    V0 = C_sim[:, 0, :] @ notional      # (B,)
    VT = C_sim[:, -1, :] @ notional     # (B,)
    dV = VT - V0                        # (B,)

    qtile = np.quantile(dV, 1 - alpha)
    var   = -qtile
    cvar  = -dV[dV <= qtile].mean()
    return var, cvar, dV


# ------------------------------------------------------------
# Helpers: map specs -> q vectors
# ------------------------------------------------------------
def nearest_node_index(tau, m, nodes):
    """
    nodes: array of shape (N,2) with columns [tau, m]
    returns index j of the nearest node by Euclidean distance in (tau, m).
    """
    diffs = nodes - np.array([tau, m])[None, :]
    j = np.argmin(np.sum(diffs*diffs, axis=1))
    return int(j)

def make_q_from_spec(spec, nodes):
    """
    Build q vector (N,) from a portfolio spec.
    spec can be:
      - dict {int_node_index: qty, ...}
      - list of (tau, m, qty) tuples (mapped to nearest node)
    """
    N = nodes.shape[0]
    q = np.zeros(N, dtype=float)
    if isinstance(spec, dict):
        for j, qty in spec.items():
            q[int(j)] += float(qty)
        return q

    # assume iterable of (tau, m, qty)
    for tau, m, qty in spec:
        j = nearest_node_index(float(tau), float(m), nodes)
        q[j] += float(qty)
    return q

# ------------------------------------------------------------
# Bulk evaluation
# ------------------------------------------------------------
def evaluate_var_for_portfolios(C_sim, portfolios, nodes, F0=1.0, multipliers=None, alphas=(0.99,)):
    """
    portfolios: dict name -> spec (dict of {node_index: qty} OR list of (tau, m, qty))
    returns: (summary_df, details) where:
      - summary_df: tidy table with VaR/CVaR per portfolio & alpha
      - details: dict name -> dict { 'q': q, 'PnL': dV }
    """
    results = []
    details = {}
    for name, spec in portfolios.items():
        q = make_q_from_spec(spec, nodes)
        # compute once, then grab for all alphas
        _, _, dV = portfolio_var_from_C(C_sim, q, F0=F0, multipliers=multipliers, alpha=alphas[0])
        details[name] = {'q': q, 'PnL': dV}

        for a in alphas:
            var_a, cvar_a, _ = portfolio_var_from_C(C_sim, q, F0=F0, multipliers=multipliers, alpha=a)
            results.append({
                'portfolio': name,
                'alpha': a,
                'VaR': var_a,
                'CVaR': cvar_a,
                'mean_PnL': float(np.mean(dV)),
                'std_PnL': float(np.std(dV, ddof=1)),
                'notional_abs_sum': float(np.sum(np.abs(q)))  # in normalized units unless F0/multipliers used
            })

    summary = pd.DataFrame(results).sort_values(['alpha','VaR'], ascending=[True, False]).reset_index(drop=True)
    return summary, details

# ------------------------------------------------------------
# Example portfolio set
# nodes_2d should be your (tau, m) for each lattice node.
# Prefer outs.nodes_sub if present, else outs.nodes.
# ------------------------------------------------------------
nodes_2d = getattr(outs, 'nodes_sub', getattr(outs, 'nodes_sub'))
assert nodes_2d.shape[1] == 2, "nodes must have shape (N,2) with [tau, m]"

# Build a few example portfolios (edit to your needs):
tau_near_1d = 1.0/365.0
tau_near_3d = 3.0/365.0
m_atm       = 0.0
m_otm_up    = +0.10
m_otm_dn    = -0.10

portfolios = {
    # 1) Long single near-ATM call (by (tau,m))
    "Long ATM ~1d": [
        (tau_near_1d, m_atm, +1.0)
    ],

    # 2) Short OTM ~1d
    "Short OTM +0.10 ~1d": [
        (tau_near_1d, m_otm_up, -1.0)
    ],

    # 3) Call butterfly around ATM at ~1d: +1 at m=-0.10, -2 at m=0, +1 at m=+0.10
    "1x2x1 Call Fly ~1d": [
        (tau_near_1d, m_otm_dn, +1.0),
        (tau_near_1d, m_atm,    -2.0),
        (tau_near_1d, m_otm_up, +1.0)
    ],
}


# ------------------------------------------------------------
# Run VaR evaluation
# ------------------------------------------------------------
# Choose your conversion to dollars if you want absolute VaR:
# - F0: current forward/spot at t0 (e.g., BTCUSD price)
# - multipliers: contract sizes per node (vector length N) if needed
F0 = 1.0
multipliers = None
alphas = (0.95, 0.99)

summary_df, details = evaluate_var_for_portfolios(
    C_sim=C_sim,
    portfolios=portfolios,
    nodes=nodes_2d,
    F0=F0,
    multipliers=multipliers,
    alphas=alphas
)

print(summary_df)

# ------------------------------------------------------------
# (Optional) quick P&L histogram per portfolio
# ------------------------------------------------------------
import matplotlib.pyplot as plt
cols = len(portfolios)
fig, axes = plt.subplots(1, cols, figsize=(4.2*cols, 3.2), squeeze=False)
for ax, (name, info) in zip(axes.ravel(), details.items()):
    dV = info['PnL']
    ax.hist(dV, bins=40, alpha=0.85)
    ax.set_title(name)
    ax.set_xlabel("PnL")
    ax.set_ylabel("count")
    ax.grid(alpha=0.2)
plt.tight_layout(); plt.show()
# Out:
#              portfolio  alpha           VaR          CVaR      mean_PnL  \
# 0   1x2x1 Call Fly ~1d   0.95  4.340708e-06  5.504352e-06 -3.566157e-07
# 1         Long ATM ~1d   0.95  3.679888e-07  5.047363e-07  4.010726e-08
# 2  Short OTM +0.10 ~1d   0.95  3.216392e-07  4.078633e-07 -2.642463e-08
# 3   1x2x1 Call Fly ~1d   0.99  6.162656e-06  6.855497e-06 -3.566157e-07
# 4         Long ATM ~1d   0.99  5.693369e-07  6.244880e-07  4.010726e-08
# 5  Short OTM +0.10 ~1d   0.99  4.566425e-07  5.079808e-07 -2.642463e-08
#
#         std_PnL  notional_abs_sum
# 0  2.353703e-06               4.0
# 1  2.647123e-07               1.0
# 2  1.744055e-07               1.0
# 3  2.353703e-06               4.0
# 4  2.647123e-07               1.0
# 5  1.744055e-07               1.0

# %%
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt

device = next(model.parameters()).device

# ---------------------------
# 1) Factors & dt (TEST SET)
# ---------------------------
# Build test factors in the SAME order as training
_, X_te, names = build_xi_training_data(outs)  # shape (T_test, p)
X_te = X_te.astype(np.float64)
T_test, p = X_te.shape

# Test dt in years from test index
sec_per_year = 1
tt_te = pd.to_datetime(outs.C_test.index.values)
dt_te = np.asarray((tt_te[1:] - tt_te[:-1]).astype('timedelta64[s]'), dtype=np.int64) / sec_per_year
assert len(dt_te) == T_test 

# ---------------------------
# 2) Standardisation hooks
# ---------------------------
def to_model_space(x):
    # if 'mu' in globals() and 'sd' in globals() and (mu is not None) and (sd is not None):
    #     mu_np = mu.detach().cpu().numpy() if torch.is_tensor(mu) else np.asarray(mu)
    #     sd_np = sd.detach().cpu().numpy() if torch.is_tensor(sd) else np.asarray(sd)
    #     return (x - mu_np.ravel()) / (sd_np.ravel() + 1e-9)
    return x

def from_model_space(x):
    # if 'mu' in globals() and 'sd' in globals() and (mu is not None) and (sd is not None):
    #     mu_np = mu.detach().cpu().numpy() if torch.is_tensor(mu) else np.asarray(mu)
    #     sd_np = sd.detach().cpu().numpy() if torch.is_tensor(sd) else np.asarray(sd)
    #     return x * sd_np.ravel() + mu_np.ravel()
    return x

# ---------------------------
# 3) Factors → prices (batch)
# ---------------------------
k_dyn  = outs.G_dyn.shape[0] if getattr(outs, "G_dyn", None) is not None and outs.G_dyn.size else 0
k_stat = outs.G_stat.shape[0] if getattr(outs, "G_stat", None) is not None and outs.G_stat.size else 0
k_sa   = outs.G_sa.shape[0]   if getattr(outs, "G_sa",   None) is not None and outs.G_sa.size   else 0
N = outs.G0.shape[0]

G0 = outs.G0.astype(np.float64)
Gd = outs.G_dyn.astype(np.float64) if k_dyn  > 0 else np.zeros((0, N))
Gs = outs.G_stat.astype(np.float64) if k_stat > 0 else np.zeros((0, N))
Ga = outs.G_sa.astype(np.float64)   if k_sa   > 0 else np.zeros((0, N))

def split_blocks(x):
    i = 0
    xd = x[..., i:i+k_dyn];  i += k_dyn
    xs = x[..., i:i+k_stat]; i += k_stat
    xa = x[..., i:i+k_sa] if k_sa>0 else x[..., :0]
    return xd, xs, xa

def x_to_prices_batch(X_batch):
    """
    X_batch: (B, p) raw Xi → returns (B, N) normalized prices
    """
    xd, xs, xa = split_blocks(X_batch)
    term = np.broadcast_to(G0, (X_batch.shape[0], N)).copy()
    if k_dyn  > 0: term += xd @ Gd
    if k_stat > 0: term += xs @ Gs
    if k_sa   > 0: term += xa @ Ga
    # No-arb clipping
    m = outs.nodes_sub[:, 1].astype(np.float64) if hasattr(outs, 'nodes_sub') else outs.nodes[:,1].astype(np.float64)
    lb = np.maximum(1.0 - np.exp(m), 0.0)
    return np.clip(term, lb[None, :], 1.0)

# ---------------------------
# 4) One-step predictive draw
# ---------------------------
@torch.no_grad()
def one_step_draw_C(model, x0_raw, dt_years, n_paths=512, clamp_sig=1e-9):
    """
    x0_raw: (p,) raw Xi at time t
    dt_years: scalar
    returns: C_{t+1} draws as (n_paths, N)
    """
    x0 = to_model_space(x0_raw.astype(np.float64))
    x  = torch.from_numpy(np.tile(x0, (n_paths, 1))).float().to(device)  # (B, p)
    DT = torch.tensor(dt_years, dtype=torch.float32, device=device).view(1,1)

    mu  = model.f(0.0, x)
    sig = model.g(0.0, x).clamp_min(clamp_sig)   # diagonal diffusion per dim
    eps = torch.randn_like(x)
    x1  = x + mu*DT + sig*torch.sqrt(DT)*eps     # Euler one-step

    X1_raw = from_model_space(x1.detach().cpu().numpy())
    C1     = x_to_prices_batch(X1_raw)           # (n_paths, N)
    return C1

# ---------------------------
# 5) Roll through test set:
#    node overlay and histogram
# ---------------------------
node_idx   = 40              # <- choose the lattice node to evaluate/plot
alpha_band = (0.05, 0.95)   # predictive band

C_actual = outs.C_test.values.astype(np.float64)  # (T_test, N) normalized
assert C_actual.shape[0] == T_test + 1

n_paths = 512
q_lo_series, q_md_series, q_hi_series = [], [], []
actual_series = []
time_index = tt_te[1:]  # we predict t+1

# collect also PIT values if you want calibration later
pit_vals = []

for t in range(T_test - 1):
    C1_draws = one_step_draw_C(model, X_te[t], dt_te[t], n_paths=n_paths)  # (B, N)
    # predictive stats for chosen node
    draws_node = C1_draws[:, node_idx]
    q_lo, q_md, q_hi = np.quantile(draws_node, [alpha_band[0], 0.5, alpha_band[1]])
    q_lo_series.append(q_lo); q_md_series.append(q_md); q_hi_series.append(q_hi)
    actual = C_actual[t+1, node_idx]
    actual_series.append(actual)
    # PIT
    pit_vals.append((draws_node <= actual).mean())

q_lo_series = np.array(q_lo_series)
q_md_series = np.array(q_md_series)
q_hi_series = np.array(q_hi_series)
actual_series = np.array(actual_series)
pit_vals = np.array(pit_vals)

# ---------------------------
# 6) Plot: predictive band vs actual
# ---------------------------
steps = np.arange(q_lo_series.size)             # align x with computed series
# optional: keep a matching time index if you want to label dates later
time_index_plot = tt_te[1:][:q_lo_series.size]  # from [`pipeline.Algo1Outputs.C_test`](pipeline/algo1.py)

plt.figure(figsize=(11,3.6))
plt.fill_between(steps, q_lo_series, q_hi_series, alpha=0.25,
                 label=f'{int(100*(alpha_band[1]-alpha_band[0]))}% pred. band')
plt.plot(steps, q_md_series, lw=1.5, label='predictive median')
plt.plot(steps, actual_series, lw=1.2, label='actual', alpha=0.9)
plt.title(f"One-step predictive band vs actual  (node {node_idx})")
plt.xlabel("test step"); plt.ylabel("C/F (normalized)")
plt.legend(); plt.grid(alpha=0.2); plt.tight_layout(); plt.show()

# ---------------------------
# 7) One example step histogram with actual overlay
# ---------------------------
t_example = steps.size // 3                     # pick a valid step
C1_draws = one_step_draw_C(model, X_te[t_example], dt_te[t_example], n_paths=n_paths)
draws_node = C1_draws[:, node_idx]
plt.figure(figsize=(6,3))
plt.hist(draws_node, bins=50, alpha=0.85)
plt.axvline(C_actual[t_example+1, node_idx], color='k', ls='--', lw=1.5, label='actual next price')
plt.title(f"Predictive C_(t+1) distribution @ step {t_example}, node {node_idx}")
plt.xlabel("C/F"); plt.ylabel("count"); plt.legend(); plt.tight_layout(); plt.show()

# (Optional) PIT quick check
print("PIT mean (should be ~0.5 if calibrated):", pit_vals.mean())
# Out:
# PIT mean (should be ~0.5 if calibrated): 0.21678531804733728

# %%
# ---------- align once ----------
sec_per_year = 1  
C_test = outs.C_test.values.astype(np.float64)           # (T_c, N)
idx_c  = pd.to_datetime(outs.C_test.index.values)
dt_years = np.asarray((idx_c[1:] - idx_c[:-1]).astype('timedelta64[s]'),
                      dtype=np.int64) / sec_per_year     # (T_c-1,)

_, X_te, _ = build_xi_training_data(outs)                # (T_x, p)
X_te = X_te.astype(np.float64)

steps = min(len(dt_years), X_te.shape[0], C_test.shape[0]-1)
N = outs.G0.shape[0]

# ---------- compute bands for ALL nodes ----------
def one_step_bands_all_nodes(model, X_te, dt_years, C_next, n_paths=1024, band=(0.06,0.94)):
    T = min(len(dt_years), X_te.shape[0], C_next.shape[0])
    q_lo = np.empty((T, N)); q_md = np.empty((T, N)); q_hi = np.empty((T, N))
    pits = np.empty((T, N))
    for t in range(T):
        C1_draws = one_step_draw_C(model, X_te[t], dt_years[t], n_paths=n_paths)  # (B, N)
        qs = np.quantile(C1_draws, [band[0], 0.5, band[1]], axis=0)               # (3, N)
        q_lo[t], q_md[t], q_hi[t] = qs[0], qs[1], qs[2]
        pits[t] = (C1_draws <= C_next[t]).mean(axis=0)
    return q_lo, q_md, q_hi, pits

q_lo, q_md, q_hi, pits = one_step_bands_all_nodes(
    model,
    X_te[:steps],
    dt_years[:steps],
    C_test[1:steps+1],          # actual at t+1
    n_paths=1024,
    band=(0.05, 0.95)         # ~89% like your plot
)

# ---------- small-multiple plots over nodes ----------
nodes_2d = getattr(outs, 'nodes_sub', getattr(outs, 'nodes_sub'))  # (N,2) [tau, m]

def plot_bands_grid(q_lo, q_md, q_hi, actual, nodes_2d, cols=4, rows=3):
    T, N = q_lo.shape
    idx = np.arange(T)
    per_fig = cols*rows
    for start in range(0, N, per_fig):
        end = min(start+per_fig, N)
        m = end - start
        r = math.ceil(m/cols)
        fig, axes = plt.subplots(r, cols, figsize=(cols*4.0, r*2.6), squeeze=False)
        axes = axes.ravel()
        for k, j in enumerate(range(start, end)):
            ax = axes[k]
            ax.fill_between(idx, q_lo[:, j], q_hi[:, j], alpha=0.25, label='band' if k==0 else None)
            ax.plot(idx, q_md[:, j], lw=1.0, label='median' if k==0 else None)
            ax.plot(idx, actual[:, j], lw=1.0, label='actual' if k==0 else None)
            tau, moneyness = nodes_2d[j, 0], nodes_2d[j, 1]
            ax.set_title(f"node {j} (τ={tau:.2f}, m={moneyness:.2f})", fontsize=9)
            ax.grid(alpha=0.2)
        # remove empty axes
        for k in range(m, len(axes)):
            fig.delaxes(axes[k])
        handles, labels = axes[0].get_legend_handles_labels()
        if handles:
            fig.legend(handles, labels, loc='upper left', bbox_to_anchor=(0.01, 0.99))
        fig.suptitle(f"One-step predictive band vs actual (nodes {start}-{end-1})", y=0.99)
        plt.tight_layout(); plt.show()

plot_bands_grid(q_lo, q_md, q_hi, C_test[1:steps+1], nodes_2d, cols=4, rows=3)

# ---------- optional: per-node calibration summary ----------
coverage = ((C_test[1:steps+1] >= q_lo) & (C_test[1:steps+1] <= q_hi)).mean(axis=0)   # (N,)
pit_mean = pits.mean(axis=0)                                                          # (N,)
print("Mean coverage across nodes:", float(coverage.mean()))
print("Mean PIT mean across nodes:", float(pit_mean.mean()))
# Out:
# Mean coverage across nodes: 0.8504178957718781
# Mean PIT mean across nodes: 0.46375183885662485

# %%
# compute on TEST set, same X_te and dt_te you use in bands
# ...existing code...
import torch, numpy as np

device = next(model.parameters()).device
Y0 = torch.from_numpy(X_te[:-1]).float().to(device)
Y1 = torch.from_numpy(X_te[1:]).float().to(device)
DT = torch.from_numpy(dt_te[:-1].copy()).float().to(device).unsqueeze(1).clamp_min(1e-12)

with torch.no_grad():
    mu  = model.f(0.0, Y0)                     # drift
    sig = model.g(0.0, Y0).clamp_min(1e-9)     # diffusion

# realized vs model one-step increment (factor space)
dx_real = (Y1 - Y0).cpu().numpy()
dx_pred = (mu*DT).cpu().numpy()

drift_bias = dx_pred.mean(0) - dx_real.mean(0)
print("Mean realized Δx per factor:", np.round(dx_real.mean(0), 6))
print("Mean model μ·Δt per factor:", np.round(dx_pred.mean(0), 6))
print("Drift bias (μΔt - Δx):     ", np.round(drift_bias, 6))
# Out:
# Mean realized Δx per factor: [ 9.6e-05 -6.1e-05 -7.0e-06]
# Mean model μ·Δt per factor: [0. 0. 0.]
# Drift bias (μΔt - Δx):      [-9.6e-05  6.1e-05  7.0e-06]

# %%
# ...existing code...
import math
import numpy as np
import matplotlib.pyplot as plt

def plot_one_step_dists_all_nodes(model, X_te, dt_te, C_test, t, n_paths=512, bins=40, cols=4):
    """
    Small-multiple histograms of predictive C_(t+1) per node with actual overlay.
    - X_te: (T_test, p) factors
    - dt_te: (T_test,) time deltas (same unit used in training/inference)
    - C_test: (T_test+1, N) normalized prices from outs (see [`pipeline.Algo1Outputs.C_test`](pipeline/algo1.py))
    - t: int step index where we predict t+1
    """
    assert 0 <= t < min(len(dt_te), X_te.shape[0], C_test.shape[0]-1)
    draws = one_step_draw_C(model, X_te[t], dt_te[t], n_paths=n_paths)   # (B, N)
    actual_next = C_test[t+1]                                           # (N,)
    N = draws.shape[1]
    nodes_2d = getattr(outs, 'nodes_sub', getattr(outs, 'nodes_sub'))

    rows = math.ceil(N / cols)
    fig, axes = plt.subplots(rows, cols, figsize=(cols*3.8, rows*2.8), squeeze=False)
    axes = axes.ravel()

    for j in range(N):
        ax = axes[j]
        dj = draws[:, j]
        ax.hist(dj, bins=bins, alpha=0.85, color="#3a78b4")
        ax.axvline(actual_next[j], color="k", ls="--", lw=1.2, label="actual next")
        # optional: show PIT and median
        pit = float((dj <= actual_next[j]).mean())
        med = float(np.median(dj))
        τ, m = nodes_2d[j, 0], nodes_2d[j, 1]
        ax.set_title(f"node {j}  τ={τ:.2f}, m={m:.2f}\nPIT={pit:.2f}, med={med:.3f}", fontsize=8)
        ax.grid(alpha=0.2)
        if j % cols == 0: ax.set_ylabel("count")
        ax.set_xlabel("C/F")

    for k in range(N, len(axes)):
        fig.delaxes(axes[k])

    fig.suptitle(f"Predictive C_(t+1) distributions @ step {t}", y=0.99)
    handles, labels = axes[0].get_legend_handles_labels()
    if handles:
        fig.legend(handles, labels, loc='upper right')
    plt.tight_layout(); plt.show()

# Example usage (pick a valid test step index)
t_example = 220
C_test_np = outs.C_test.values.astype(np.float64)  # [`pipeline.Algo1Outputs.C_test`](pipeline/algo1.py)
plot_one_step_dists_all_nodes(model, X_te, dt_te, C_test_np, t=t_example, n_paths=512, bins=50, cols=4)
# ...existing code...

# %%
# Reconstruct C_t from X_t and compare to actual C_t (same time, not t+1)
C_now_pred = x_to_prices_batch(X_te)                  # shape (T_test, N)
C_now_act  = outs.C_test.values.astype(np.float64)[:-1]  # drop last to match length
r2 = np.corrcoef(C_now_pred.ravel(), C_now_act.ravel())[0,1]**2
mae = np.mean(np.abs(C_now_pred - C_now_act))
print(f"Nowcast R^2 ~ {r2:.4f}, MAE ~ {mae:.6g}")
# Compare per-node mean level from nowcasts vs actuals
lvl_diff = C_now_pred.mean(0) - C_now_act.mean(0)
print("Max abs node-level mean diff:", float(np.max(np.abs(lvl_diff))))
# Out:
# Nowcast R^2 ~ 0.9956, MAE ~ 0.00394858
# Max abs node-level mean diff: 0.03019164734414806

# %%
import numpy as np
import torch
from sklearn.linear_model import Ridge

device = "cuda" if torch.cuda.is_available() else "cpu"

# 1) Training data: Xi and normalized calls c = C/F
X_tr, X_te, xi_names = build_xi_training_data(outs)          # shapes: (T,k), (T*,k)
C_tr_full = outs.C_train.values.astype(np.float64)           # (T,N)
L = min(len(C_tr_full)-1, X_tr.shape[0])                     # align to Xi length

C_tr = C_tr_full[:L]                 # (T,N)
F_tr = getattr(outs, "F_train", None)
if F_tr is not None:
    F_tr = np.asarray(F_tr.values, dtype=np.float64)          # (T,)
    c_tr = C_tr / F_tr[:, None]
else:
    # If you don't track F, work purely in normalized units provided in outs.C_train already
    # (i.e., assume outs.C_* are normalized). Adjust to your pipeline.
    c_tr = C_tr

# 2) Fit linear decoder: c ≈ μ + B xi
reg = Ridge(alpha=1e-6, fit_intercept=True)
reg.fit(X_tr, c_tr)
B_np = reg.coef_.astype(np.float64)      # (N,k)
mu_np = reg.intercept_.astype(np.float64)# (N,)

# Torch tensors
B = torch.tensor(B_np, dtype=torch.float32, device=device)  # (N,k)
mu = torch.tensor(mu_np, dtype=torch.float32, device=device) # (N,)

def decoder_linear(xi_t: torch.Tensor) -> torch.Tensor:
    """xi_t: (k,) -> c_t: (N,) normalized prices"""
    return mu + (B @ xi_t)


from typing import List, Tuple

def vector_q(N: int, positions: List[Tuple[int, float]], device="cpu"):
    q = torch.zeros(N, dtype=torch.float32, device=device)
    for idx, qty in positions:
        q[idx] += float(qty)
    return q

def build_sensitivity_hedge(B: torch.Tensor,
                            portfolio_positions: List[Tuple[int, float]],
                            hedge_universe: List[int],
                            l2_reg: float = 1e-6):
    """
    B: (N,k) decoder loadings => sensitivities w.r.t Xi
    portfolio_positions: list of (node_idx, qty)
    hedge_universe: list of node indices you can trade as hedges

    Returns hedge weights aligned to hedge_universe, and residual exposure.
    """
    N, k = B.shape
    q = vector_q(N, portfolio_positions, device=B.device)     # (N,)
    g = B.T @ q                                               # (k,)
    BH = B[hedge_universe, :]                                 # (|H|, k)
    A = BH.T                                                  # (k, |H|)

    # Solve (A^T A + λI) h = -A^T g
    ATA = A.T @ A + l2_reg*torch.eye(A.shape[1], device=B.device)
    ATg = A.T @ g
    h = torch.linalg.solve(ATA, -ATg)                         # (|H|,)

    residual = A @ h + g                                      # (k,)
    return h.detach(), residual.detach()


# Example portfolio: long 10 at node i0, short 3 at node i1
portfolio = [(1, 10.0), (26, -3.0)]
# Hedge on a small set (e.g., 3–10 near-ATM nodes you actually can trade)
hedge_universe = [9, 10, 14]

h, res = build_sensitivity_hedge(B, portfolio, hedge_universe, l2_reg=1e-5)
print("Hedge weights (aligned to hedge_universe):", h.cpu().numpy())
print("Residual factor exposure (should be small):", res.cpu().numpy())

def price_vector_linear(mu: torch.Tensor, B: torch.Tensor, xi_t: torch.Tensor, F_t: float = None):
    c = mu + B @ xi_t   # normalized prices (N,)
    return c if F_t is None else c * F_t

def run_simple_backtest(mu, B, X_test_np, F_test_np, portfolio, hedge_universe, rebalance_every=1, l2_reg=1e-6):
    X_te = torch.tensor(X_test_np, dtype=torch.float32, device=B.device)   # (T*,k)
    T = X_te.shape[0]
    hedge = [(i, 0.0) for i in hedge_universe]

    records = []
    for t in range(T-1):
        xi_t, xi_tp1 = X_te[t], X_te[t+1]
        F_t  = None if F_test_np is None else float(F_test_np[t])
        F_tp1= None if F_test_np is None else float(F_test_np[t+1])

        p_t   = price_vector_linear(mu, B, xi_t,   F_t)
        p_tp1 = price_vector_linear(mu, B, xi_tp1, F_tp1)

        if (t % rebalance_every) == 0:
            # Recompute sensitivity hedge using current positions (book + hedge)
            h, _ = build_sensitivity_hedge(B, portfolio + hedge, hedge_universe, l2_reg)
            hedge = list(zip(hedge_universe, h.cpu().numpy().tolist()))

        def value(p, pos): return sum(q * p[idx].item() for idx, q in pos)
        dV_book  = value(p_tp1, portfolio) - value(p_t, portfolio)
        dV_hedge = value(p_tp1, hedge)     - value(p_t, hedge)
        records.append({"t": t, "dV_book": dV_book, "dV_hedge": dV_hedge, "dV_net": dV_book + dV_hedge})
    return records
# Out:
# Hedge weights (aligned to hedge_universe): [-2.1822243 -2.79881   13.949217 ]
# Residual factor exposure (should be small): [-0.03205272 -0.00954083 -0.00057178]

# %%
import numpy as np
import torch
from math import log, sqrt, exp
from typing import List, Tuple, Optional, Dict

# -----------------------------
# (A) Black–Scholes utilities
# -----------------------------
from math import erf

def _nd(x):
    # standard normal pdf
    return (1.0/np.sqrt(2*np.pi))*np.exp(-0.5*x*x)

def _Nc(x):
    # standard normal cdf
    return 0.5*(1.0 + erf(x/np.sqrt(2.0)))

def _bs_norm_call_from_m_tau(m: float, tau: float, vol: float) -> float:
    """
    Normalized BS call price c = C/F when F is the forward (r=q=0),
    strike ratio m = K/F, and tau is time to expiry (in years).
    """
    if tau <= 0.0 or vol <= 1e-12:
        return max(1.0 - m, 0.0)
    v = vol * np.sqrt(tau)
    if v <= 1e-12:
        return max(1.0 - m, 0.0)
    ln_1_over_m = -np.log(m)
    d1 = (ln_1_over_m + 0.5*v*v)/v
    d2 = d1 - v
    return _Nc(d1) - m*_Nc(d2)

def _implied_vol_from_c_m_tau(c: float, m: float, tau: float, tol: float=1e-8, max_iter: int=80) -> float:
    """
    Solve for BS vol from normalized price c and (m,tau) using a robust bisection.
    Returns np.nan if it cannot bracket sensibly.
    """
    if tau <= 0.0:
        # expiry: price is intrinsic -> vol undefined; return ~0
        return 0.0
    # Price bounds as vol->0 and vol->infty
    c_low = max(1.0 - m, 0.0)  # vol -> 0
    c_high = 1.0               # vol -> +inf (limit of N(d1) - m N(d2) is 1)
    # Clamp c into feasible interval
    c_clamped = min(max(c, c_low), c_high - 1e-12)
    if abs(c_clamped - c) > 1e-10:
        c = c_clamped
    # Quick exits
    if abs(c - c_low) < 1e-12: return 1e-10
    if c >= 1.0 - 1e-12:       return 5.0

    lo, hi = 1e-6, 5.0
    f_lo = _bs_norm_call_from_m_tau(m, tau, lo) - c
    f_hi = _bs_norm_call_from_m_tau(m, tau, hi) - c
    # Ensure monotone bracket
    if f_lo > 0.0: 
        # shift bracket down
        for _ in range(10):
            hi = lo; f_hi = f_lo
            lo *= 0.5
            f_lo = _bs_norm_call_from_m_tau(m, tau, lo) - c
            if f_lo <= 0.0: break
    if f_hi < 0.0:
        # shift bracket up
        for _ in range(10):
            lo = hi; f_lo = f_hi
            hi *= 2.0
            if hi > 50.0: break
            f_hi = _bs_norm_call_from_m_tau(m, tau, hi) - c
            if f_hi >= 0.0: break

    if not (f_lo <= 0.0 <= f_hi):
        # Failed to bracket; return a safe guess
        return np.nan

    for _ in range(max_iter):
        mid = 0.5*(lo+hi)
        f_mid = _bs_norm_call_from_m_tau(m, tau, mid) - c
        if abs(f_mid) < tol: 
            return mid
        if f_mid > 0.0:
            hi = mid
        else:
            lo = mid
        if (hi - lo) < 1e-8:
            return 0.5*(lo+hi)
    return 0.5*(lo+hi)

def _bs_forward_delta_from_m_tau_vol(m: float, tau: float, vol: float) -> float:
    """
    Forward delta: ∂C/∂F = N(d1) when pricing under forward with discount=1.
    (This is the delta you’d hedge with the underlying F or spot if r≈q≈0.)
    """
    if tau <= 0.0 or vol <= 1e-12:
        return 1.0 if (1.0 > m) else (0.0 if (1.0 < m) else 0.5)
    v = vol * np.sqrt(tau)
    d1 = (-np.log(m) + 0.5*v*v)/v
    return _Nc(d1)

# -----------------------------
# (B) Delta hedge backtest
# -----------------------------
def _compute_delta_vector_from_decoder_prices(
    mu: torch.Tensor, B: torch.Tensor, xi_t: torch.Tensor,
    nodes: np.ndarray, F_t: Optional[float] = None
) -> np.ndarray:
    """
    Compute BS forward deltas for ALL nodes at time t by:
      1) pricing c_t = mu + B @ xi_t  (normalized),
      2) inverting for sigma_i from (c_i, m_i, tau_i),
      3) delta_i = N(d1_i).
    Returns np.ndarray shape (N,), deltas w.r.t. F.
    """
    with torch.no_grad():
        c_t = (mu + B @ xi_t).detach().cpu().numpy()  # normalized vector (N,)
    taus = nodes[:, 0]
    ms   = nodes[:, 1]

    deltas = np.empty_like(c_t)
    for i, (c_i, tau_i, m_i) in enumerate(zip(c_t, taus, ms)):
        vol_i = _implied_vol_from_c_m_tau(float(c_i), float(m_i), float(tau_i))
        if np.isnan(vol_i):
            # Fallback: clip to small vol to keep stable
            vol_i = 1e-6
        deltas[i] = _bs_forward_delta_from_m_tau_vol(float(m_i), float(tau_i), float(vol_i))
    return deltas  # (N,)

def run_delta_hedge_backtest(
    mu: torch.Tensor, B: torch.Tensor,
    X_test_np: np.ndarray, F_test_np: Optional[np.ndarray],
    nodes: np.ndarray,
    portfolio: List[Tuple[int, float]],
    rebalance_every: int = 1
):
    """
    Delta-only hedge with the UNDERLYING as the single hedge instrument:
      X_S(t) = - sum_i q_i * Delta_i(t)
    Prices for options come from the linear decoder (mu,B). Underlying PnL uses F_path.
    """
    device = B.device
    X_te = torch.tensor(X_test_np, dtype=torch.float32, device=device)  # (T,k)
    T, _ = X_te.shape

    # Helper: value of options block
    def _value_opts(xi, F):
        c = (mu + B @ xi)                    # (N,)
        return sum(q * (c[idx].item() if F is None else (c[idx].item()*F)) for idx, q in portfolio)

    records = []
    X_S = 0.0  # hedge in units of underlying
    for t in range(T-1):
        xi_t, xi_tp1 = X_te[t], X_te[t+1]
        F_t   = None if F_test_np is None else float(F_test_np[t])
        F_tp1 = None if F_test_np is None else float(F_test_np[t+1])

        # Rebalance hedge every k bars
        if (t % rebalance_every) == 0:
            deltas_t = _compute_delta_vector_from_decoder_prices(mu, B, xi_t, nodes, F_t)
            port_delta = sum(q * deltas_t[idx] for idx, q in portfolio)  # w.r.t F
            X_S = - port_delta  # neutralize delta

        # PnLs
        Vt   = _value_opts(xi_t,   F_t)
        Vt1  = _value_opts(xi_tp1, F_tp1)
        dV_book  = Vt1 - Vt
        dV_hedge = 0.0
        if F_test_np is not None:
            dV_hedge = X_S * (F_tp1 - F_t)
        # If F_path is None (normalized), we can treat underlying hedge as N/A (=0)
        records.append({"t": t, "dV_book": dV_book, "dV_hedge": dV_hedge, "dV_net": dV_book + dV_hedge})
    return records

# -----------------------------
# (C) Error metrics & compare
# -----------------------------
import pandas as pd

def hedging_error_summary(records: List[Dict], label: str) -> pd.DataFrame:
    df = pd.DataFrame(records)
    out = {
        "strategy": label,
        "steps": len(df),
        "net_std": float(df["dV_net"].std(ddof=1)),
        "book_std": float(df["dV_book"].std(ddof=1)),
        "hedge_std": float(df["dV_hedge"].std(ddof=1)),
        "net_mean": float(df["dV_net"].mean()),
    }
    return pd.DataFrame([out])

def compare_sensitivity_vs_delta(
    mu: torch.Tensor, B: torch.Tensor,
    X_test_np: np.ndarray, F_test_np: Optional[np.ndarray],
    nodes: np.ndarray,
    portfolio: List[Tuple[int, float]],
    hedge_universe: List[int],
    rebalance_every: int = 1,
    l2_reg: float = 1e-6
):
    """
    Runs:
      1) Sensitivity-based hedge  (your run_simple_backtest),
      2) BS delta hedge (underlying only),
    and prints a small summary table of hedging errors (std of net PnL).
    """
    # 1) Sensitivity hedge backtest (uses your function)
    sens_records = run_simple_backtest(mu, B, X_test_np, F_test_np, portfolio, hedge_universe,
                                       rebalance_every=rebalance_every, l2_reg=l2_reg)

    # 2) Delta hedge backtest
    delta_records = run_delta_hedge_backtest(mu, B, X_test_np, F_test_np, nodes, portfolio,
                                             rebalance_every=rebalance_every)

    # Summaries
    df_sens  = hedging_error_summary(sens_records,  "Sensitivity (Xi)")
    df_delta = hedging_error_summary(delta_records, "Delta (BS)")

    # Combine & sort by net_std
    out = pd.concat([df_sens, df_delta], ignore_index=True).sort_values("net_std").reset_index(drop=True)
    return out, sens_records, delta_records

summary, sens_recs, delta_recs = compare_sensitivity_vs_delta(
    mu, B,
    X_te, outs.C_test.values,               # replace with your test arrays
    outs.nodes_sub,
    portfolio, hedge_universe,
    rebalance_every=1,        # e.g. rebalance every bar
    l2_reg=1e-5
)

print(summary)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 222
#     219     out = pd.concat([df_sens, df_delta], ignore_index=True).sort_values("net_std").reset_index(drop=True)
#     220     return out, sens_records, delta_records
# --> 222 summary, sens_recs, delta_recs = compare_sensitivity_vs_delta(
#     223     mu, B,
#     224     X_te, outs.C_test.values,               # replace with your test arrays
#     225     outs.nodes_sub,
#     226     portfolio, hedge_universe,
#     227     rebalance_every=1,        # e.g. rebalance every bar
#     228     l2_reg=1e-5
#     229 )
#     231 print(summary)
#
# Cell In[46], line 207, in compare_sensitivity_vs_delta(mu, B, X_test_np, F_test_np, nodes, portfolio, hedge_universe, rebalance_every, l2_reg)
#     200 """
#     201 Runs:
#     202   1) Sensitivity-based hedge  (your run_simple_backtest),
#     203   2) BS delta hedge (underlying only),
#     204 and prints a small summary table of hedging errors (std of net PnL).
#     205 """
#     206 # 1) Sensitivity hedge backtest (uses your function)
# --> 207 sens_records = run_simple_backtest(mu, B, X_test_np, F_test_np, portfolio, hedge_universe,
#     208                                    rebalance_every=rebalance_every, l2_reg=l2_reg)
#     210 # 2) Delta hedge backtest
#     211 delta_records = run_delta_hedge_backtest(mu, B, X_test_np, F_test_np, nodes, portfolio,
#     212                                          rebalance_every=rebalance_every)
#
# Cell In[45], line 92, in run_simple_backtest(mu, B, X_test_np, F_test_np, portfolio, hedge_universe, rebalance_every, l2_reg)
#      90 for t in range(T-1):
#      91     xi_t, xi_tp1 = X_te[t], X_te[t+1]
# ---> 92     F_t  = None if F_test_np is None else float(F_test_np[t])
#      93     F_tp1= None if F_test_np is None else float(F_test_np[t+1])
#      95     p_t   = price_vector_linear(mu, B, xi_t,   F_t)
#
# TypeError: only length-1 arrays can be converted to Python scalars

# %%
pip install pycddlib
# Out:
# Collecting pycddlib
#   Using cached pycddlib-3.0.2.tar.gz (31 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Building wheels for collected packages: pycddlib
#   Building wheel for pycddlib (pyproject.toml) ... error
#   error: subprocess-exited-with-error
#
#   × Building wheel for pycddlib (pyproject.toml) did not run successfully.
#   │ exit code: 1
#   ╰─> [55 lines of output]
#       /private/var/folders/7p/px6mp0t52794gwq4s0r9jst0ytvmtk/T/pip-build-env-klvtsxuw/overlay/lib/python3.12/site-packages/setuptools/config/_apply_pyprojecttoml.py:61: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: GNU General Public License v2 or later (GPLv2+)
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         dist._finalize_license_expression()
#       /private/var/folders/7p/px6mp0t52794gwq4s0r9jst0ytvmtk/T/pip-build-env-klvtsxuw/overlay/lib/python3.12/site-packages/setuptools/dist.py:759: SetuptoolsDeprecationWarning: License classifiers are deprecated.
#       !!
#
#               ********************************************************************************
#               Please consider removing the following classifiers in favor of a SPDX license expression:
#
#               License :: OSI Approved :: GNU General Public License v2 or later (GPLv2+)
#
#               See https://packaging.python.org/en/latest/guides/writing-pyproject-toml/#license for details.
#               ********************************************************************************
#
#       !!
#         self._finalize_license_expression()
#       running bdist_wheel
#       running build
#       running build_py
#       running egg_info
#       writing src/pycddlib.egg-info/PKG-INFO
#       writing dependency_links to src/pycddlib.egg-info/dependency_links.txt
#       writing requirements to src/pycddlib.egg-info/requires.txt
#       writing top-level names to src/pycddlib.egg-info/top_level.txt
#       reading manifest file 'src/pycddlib.egg-info/SOURCES.txt'
#       reading manifest template 'MANIFEST.in'
#       no previously-included directories found matching 'test'
#       adding license file 'LICENSE.md'
#       adding license file 'AUTHORS'
#       writing manifest file 'src/pycddlib.egg-info/SOURCES.txt'
#       creating build/lib.macosx-11.0-arm64-cpython-312/cdd
#       copying src/cdd/__init__.pyi -> build/lib.macosx-11.0-arm64-cpython-312/cdd
#       copying src/cdd/gmp.pyi -> build/lib.macosx-11.0-arm64-cpython-312/cdd
#       copying src/cdd/py.typed -> build/lib.macosx-11.0-arm64-cpython-312/cdd
#       running build_ext
#       Compiling cython/_cdd.pyx because it changed.
#       [1/1] Cythonizing cython/_cdd.pyx
#       building 'cdd.__init__' extension
#       creating build/temp.macosx-11.0-arm64-cpython-312/cython
#       clang -fno-strict-overflow -Wsign-compare -Wunreachable-code -DNDEBUG -O2 -Wall -fPIC -O2 -isystem /opt/anaconda3/envs/csiro_stem/include -arch arm64 -fPIC -O2 -isystem /opt/anaconda3/envs/csiro_stem/include -arch arm64 -I/opt/anaconda3/envs/csiro_stem/include/python3.12 -c cython/_cdd.c -o build/temp.macosx-11.0-arm64-cpython-312/cython/_cdd.o
#       cython/_cdd.c:1147:10: fatal error: 'cddlib/setoper.h' file not found
#        1147 | #include "cddlib/setoper.h"
#             |          ^~~~~~~~~~~~~~~~~~
#       1 error generated.
#       error: command '/usr/bin/clang' failed with exit code 1
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for pycddlib
# Failed to build pycddlib
# ERROR: Failed to build installable wheels for some pyproject.toml based projects (pycddlib)
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from numpy.linalg import norm
from scipy.optimize import linprog
from scipy.spatial import HalfspaceIntersection

def halfspace_vertices(W_in, b_in, r_tol=1e-7, nudge=1e-6, highs_opts=None):
    """
    Return vertices of {x | W x >= b} using SciPy HalfspaceIntersection,
    computing a strictly interior point via Chebyshev center.
    - Normalizes half-space rows for numerical stability.
    - Raises if region is infeasible or effectively unbounded (r <= r_tol).
    """
    # --- Densify
    W = W_in.toarray().astype(float) if hasattr(W_in, "toarray") else np.asarray(W_in, dtype=float)
    b = np.asarray(b_in, dtype=float).reshape(-1)
    m, n = W.shape
    assert b.shape == (m,)

    # --- Qhull halfspaces: a^T x + c <= 0  with a=-W_i, c=b_i
    A = -W.copy()
    c = b.copy()

    # --- Normalize each row by ||a_i||_2 to make Chebyshev LP well-conditioned
    row_norms = np.maximum(norm(A, axis=1), 1e-12)
    A_n = A / row_norms[:, None]
    c_n = c / row_norms

    # --- Chebyshev center LP:
    # vars: [x(0..n-1), r]
    # maximize r  <=> minimize -r
    # constraints: A_n @ x + c_n <= -r  ->  A_lp @ [x;r] <= b_lp
    A_lp = np.hstack([A_n, np.ones((m,1))])  # coefficient for r is +1
    b_lp = -c_n
    c_obj = np.zeros(n+1); c_obj[-1] = -1.0  # minimize -r

    bounds = [(None, None)]*n + [(0, None)]   # r >= 0
    res = linprog(c=c_obj, A_ub=A_lp, b_ub=b_lp, bounds=bounds,
                  method="highs", options=(highs_opts or {}))
    if not res.success:
        raise RuntimeError(f"Infeasible region W x >= b: {res.message}")

    x_cheb = res.x[:n]
    r_cheb = res.x[-1]

    if not np.isfinite(r_cheb) or r_cheb <= r_tol:
        # r ~ 0 => either unbounded or "sliver" polytope; Qhull will likely fail
        raise RuntimeError(
            "Region is unbounded or has ~zero inradius (r≈0). "
            "HalfspaceIntersection requires a bounded polytope and a strict interior point."
        )

    # Strict interior: step inward (by nudge * average inward normal)
    slacks = A_n @ x_cheb + c_n            # should be <= -r_cheb
    # inward normal for face i is -A_n[i]
    inward = (-A_n[slacks > -r_cheb + 1e-12]).mean(axis=0) if np.any(slacks > -r_cheb + 1e-12) else (-A_n).mean(axis=0)
    if norm(inward) > 0:
        x_int = x_cheb + nudge * inward / norm(inward)
    else:
        x_int = x_cheb

    # Build unnormalized halfspace matrix for Qhull: [A | c]
    halfspaces = np.hstack([A, c.reshape(-1,1)])  # (m, n+1)

    hs = HalfspaceIntersection(halfspaces, x_int)
    return np.asarray(hs.intersections)


vertices = halfspace_vertices(outs.A, outs.b)

# %%
print(outs.A.shape)  # (m, n)
print(outs.b.shape)
# Out:
# (156, 48)
# (156,)
