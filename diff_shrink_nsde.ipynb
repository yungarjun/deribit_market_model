# %%
import joblib
outs = joblib.load("outputs/artifacts/algo1_outs_2025-05-22_1min_agreg.pkl")

# %%
import torch
from neural_sde.constraints import compute_factor_polytope_vertices, assemble_Wb_for_shrinkage, build_factor_path, calc_diffusion_scaling
from neural_sde.nets import NeuralSDEWithShrink                       # [neural_sde/nets.py](neural_sde/nets.py)
from neural_sde.loss import likelihood_training, build_xi_training_data                        # [neural_sde/loss.py](neural_sde/loss.py)
import numpy as np

torch.manual_seed(80085) 

poly = compute_factor_polytope_vertices(
    outs,
    xi_builder=None,      # or None if Xi_*_train are on outs
    k_box=6.0,
    verbose=False,
    return_mappings=True,
)

# 2) Assemble (W,b) for shrinkage and row-normalise
W, b = assemble_Wb_for_shrinkage(poly, include_box=True)

# 3) Build factor path X and its single-step differences dX (align shapes)
X  = build_factor_path(outs, xi_builder=None)          # shape (T, p)
dX = np.diff(X, axis=0)                                      # shape (T-1, p)
X  = X[:-1]                                                  # align to dX

# 4) Choose shrinkage hyperparams (tune these)
# --- Calibrate dist_multiplier to hit epsilon/proj_scale = 0.95
frac_critical_threshold = 0.9
critical_value = 0.95
proj_scale = 0.1

# distances to halfspaces (W rows must be unit-norm already)
dist_X = np.abs(W @ X.T - b[:, None])               # (n_faces, T)
per_face_max = np.max(dist_X, axis=1)               # (n_faces,)
critical_threshold = frac_critical_threshold * np.min(per_face_max)
dist_multiplier = (1.0/(1.0 - critical_value) - 1.0) / critical_threshold

# 5) Compute adaptive diffusion shrinkage terms for train
Omegas, det_Omega, proj_dX = calc_diffusion_scaling(
    W=W, b=b, X=X, dX=dX,
    dist_multiplier=dist_multiplier,
    proj_scale=proj_scale
)


# Compute adaptive diffusion shrinkage terms for test
_, X_te, _ = build_xi_training_data(outs)  # or your builder returning test too
dX_te = np.diff(X_te, axis=0); X_te = X_te[:-1]
Omegas_te, det_Omega_te, proj_dX_te = calc_diffusion_scaling(
    W=W, b=b, X=X_te, dX=dX_te,
    dist_multiplier=dist_multiplier,
    proj_scale=proj_scale
)
# Out:
# 100%|██████████| 1099/1099 [00:00<00:00, 29363.87it/s]
# 100%|██████████| 338/338 [00:00<00:00, 32444.04it/s]

# %%
train_losses, test_losses, model, X_train = likelihood_training(
    outs,
    Omega_tr=Omegas,
    det_Omega_tr = det_Omega,
    proj_dX_tr=proj_dX,
    Omega_te = Omegas_te,
    det_Omega_te = det_Omega_te,
    proj_dX_te = proj_dX_te,
    n_epochs=1000,
    batch_size=256,
    lr=1e-4,
    data='xi',
    zero_drift=False,
    model = None
)

import matplotlib.pyplot as plt
plt.figure()
plt.plot(train_losses, label="Train NLL")
plt.plot(test_losses, label="Test NLL")
plt.title("One-Step Euler–Maruyama Negative Log-Likelihood")
plt.xlabel("Epoch")
plt.ylabel("NLL")
plt.legend()
plt.show()
# Out:
# Epoch 1/1000  Train NLL: 2.2928e+02  Test NLL: 1.4230e+02
# Epoch 2/1000  Train NLL: 1.5118e+02  Test NLL: 8.9480e+01
# Epoch 3/1000  Train NLL: 9.6957e+01  Test NLL: 5.4474e+01
# Epoch 4/1000  Train NLL: 5.8852e+01  Test NLL: 3.4483e+01
# Epoch 5/1000  Train NLL: 3.5925e+01  Test NLL: 2.2839e+01
# Epoch 6/1000  Train NLL: 2.2101e+01  Test NLL: 1.2282e+01
# Epoch 7/1000  Train NLL: 1.0375e+01  Test NLL: 1.3234e+00
# Epoch 8/1000  Train NLL: 8.8815e-01  Test NLL: -6.8941e+00
# Epoch 9/1000  Train NLL: -5.4928e+00  Test NLL: -1.0914e+01
# Epoch 10/1000  Train NLL: -9.4401e+00  Test NLL: -1.1757e+01
# Epoch 11/1000  Train NLL: -1.1386e+01  Test NLL: -1.2120e+01
# Epoch 12/1000  Train NLL: -1.1612e+01  Test NLL: -1.1223e+01
# Epoch 13/1000  Train NLL: -1.1512e+01  Test NLL: -1.1220e+01
# Epoch 14/1000  Train NLL: -1.1866e+01  Test NLL: -1.2525e+01
# Epoch 15/1000  Train NLL: -1.2334e+01  Test NLL: -1.2413e+01
# Epoch 16/1000  Train NLL: -1.2613e+01  Test NLL: -1.3201e+01
# Epoch 17/1000  Train NLL: -1.2941e+01  Test NLL: -1.3316e+01
# Epoch 18/1000  Train NLL: -1.3263e+01  Test NLL: -1.3200e+01
# Epoch 19/1000  Train NLL: -1.3562e+01  Test NLL: -1.3960e+01
# Epoch 20/1000  Train NLL: -1.3956e+01  Test NLL: -1.4051e+01
# Epoch 21/1000  Train NLL: -1.4248e+01  Test NLL: -1.4786e+01
# Epoch 22/1000  Train NLL: -1.4582e+01  Test NLL: -1.4808e+01
# Epoch 23/1000  Train NLL: -1.4913e+01  Test NLL: -1.4963e+01
# Epoch 24/1000  Train NLL: -1.5217e+01  Test NLL: -1.5439e+01
# Epoch 25/1000  Train NLL: -1.5531e+01  Test NLL: -1.5814e+01
# Epoch 26/1000  Train NLL: -1.5832e+01  Test NLL: -1.5991e+01
# Epoch 27/1000  Train NLL: -1.6121e+01  Test NLL: -1.6468e+01
# Epoch 28/1000  Train NLL: -1.6426e+01  Test NLL: -1.6834e+01
# Epoch 29/1000  Train NLL: -1.6692e+01  Test NLL: -1.6829e+01
# Epoch 30/1000  Train NLL: -1.6976e+01  Test NLL: -1.7356e+01
# Epoch 31/1000  Train NLL: -1.7237e+01  Test NLL: -1.7560e+01
# Epoch 32/1000  Train NLL: -1.7509e+01  Test NLL: -1.7782e+01
# Epoch 33/1000  Train NLL: -1.7793e+01  Test NLL: -1.8020e+01
# Epoch 34/1000  Train NLL: -1.8058e+01  Test NLL: -1.8203e+01
# Epoch 35/1000  Train NLL: -1.8262e+01  Test NLL: -1.8526e+01
# Epoch 36/1000  Train NLL: -1.8480e+01  Test NLL: -1.8747e+01
# Epoch 37/1000  Train NLL: -1.8687e+01  Test NLL: -1.8944e+01
# Epoch 38/1000  Train NLL: -1.8882e+01  Test NLL: -1.9001e+01
# Epoch 39/1000  Train NLL: -1.9100e+01  Test NLL: -1.9413e+01
# Epoch 40/1000  Train NLL: -1.9218e+01  Test NLL: -1.9415e+01
# Epoch 41/1000  Train NLL: -1.9418e+01  Test NLL: -1.9653e+01
# Epoch 42/1000  Train NLL: -1.9585e+01  Test NLL: -1.9824e+01
# Epoch 43/1000  Train NLL: -1.9783e+01  Test NLL: -1.9953e+01
# Epoch 44/1000  Train NLL: -1.9983e+01  Test NLL: -2.0196e+01
# Epoch 45/1000  Train NLL: -2.0224e+01  Test NLL: -2.0509e+01
# Epoch 46/1000  Train NLL: -2.0487e+01  Test NLL: -2.0823e+01
# Epoch 47/1000  Train NLL: -2.0734e+01  Test NLL: -2.0961e+01
# Epoch 48/1000  Train NLL: -2.0991e+01  Test NLL: -2.1173e+01
# Epoch 49/1000  Train NLL: -2.1209e+01  Test NLL: -2.1360e+01
# Epoch 50/1000  Train NLL: -2.1424e+01  Test NLL: -2.1701e+01
# Epoch 51/1000  Train NLL: -2.1665e+01  Test NLL: -2.1960e+01
# Epoch 52/1000  Train NLL: -2.1884e+01  Test NLL: -2.2138e+01
# Epoch 53/1000  Train NLL: -2.2120e+01  Test NLL: -2.2408e+01
# Epoch 54/1000  Train NLL: -2.2359e+01  Test NLL: -2.2552e+01
# Epoch 55/1000  Train NLL: -2.2593e+01  Test NLL: -2.2848e+01
# Epoch 56/1000  Train NLL: -2.2826e+01  Test NLL: -2.3041e+01
# Epoch 57/1000  Train NLL: -2.3065e+01  Test NLL: -2.3385e+01
# Epoch 58/1000  Train NLL: -2.3317e+01  Test NLL: -2.3579e+01
# Epoch 59/1000  Train NLL: -2.3568e+01  Test NLL: -2.3867e+01
# Epoch 60/1000  Train NLL: -2.3813e+01  Test NLL: -2.4119e+01
# Epoch 61/1000  Train NLL: -2.4064e+01  Test NLL: -2.4312e+01
# Epoch 62/1000  Train NLL: -2.4296e+01  Test NLL: -2.4572e+01
# Epoch 63/1000  Train NLL: -2.4507e+01  Test NLL: -2.4711e+01
# Epoch 64/1000  Train NLL: -2.4685e+01  Test NLL: -2.4951e+01
# Epoch 65/1000  Train NLL: -2.4879e+01  Test NLL: -2.5116e+01
# Epoch 66/1000  Train NLL: -2.5048e+01  Test NLL: -2.5290e+01
# Epoch 67/1000  Train NLL: -2.5226e+01  Test NLL: -2.5498e+01
# Epoch 68/1000  Train NLL: -2.5425e+01  Test NLL: -2.5705e+01
# Epoch 69/1000  Train NLL: -2.5657e+01  Test NLL: -2.5957e+01
# Epoch 70/1000  Train NLL: -2.5898e+01  Test NLL: -2.6214e+01
# Epoch 71/1000  Train NLL: -2.6135e+01  Test NLL: -2.6395e+01
# Epoch 72/1000  Train NLL: -2.6306e+01  Test NLL: -2.6614e+01
# Epoch 73/1000  Train NLL: -2.6500e+01  Test NLL: -2.6724e+01
# Epoch 74/1000  Train NLL: -2.6632e+01  Test NLL: -2.6789e+01
# Epoch 75/1000  Train NLL: -2.6754e+01  Test NLL: -2.6972e+01
# Epoch 76/1000  Train NLL: -2.6884e+01  Test NLL: -2.7054e+01
# Epoch 77/1000  Train NLL: -2.7003e+01  Test NLL: -2.7197e+01
# Epoch 78/1000  Train NLL: -2.7136e+01  Test NLL: -2.7359e+01
# Epoch 79/1000  Train NLL: -2.7273e+01  Test NLL: -2.7447e+01
# Epoch 80/1000  Train NLL: -2.7415e+01  Test NLL: -2.7635e+01
# Epoch 81/1000  Train NLL: -2.7577e+01  Test NLL: -2.7838e+01
# Epoch 82/1000  Train NLL: -2.7781e+01  Test NLL: -2.8061e+01
# Epoch 83/1000  Train NLL: -2.7996e+01  Test NLL: -2.8269e+01
# Epoch 84/1000  Train NLL: -2.8193e+01  Test NLL: -2.8408e+01
# Epoch 85/1000  Train NLL: -2.8375e+01  Test NLL: -2.8622e+01
# Epoch 86/1000  Train NLL: -2.8548e+01  Test NLL: -2.8787e+01
# Epoch 87/1000  Train NLL: -2.8724e+01  Test NLL: -2.8968e+01
# Epoch 88/1000  Train NLL: -2.8893e+01  Test NLL: -2.9144e+01
# Epoch 89/1000  Train NLL: -2.9060e+01  Test NLL: -2.9313e+01
# Epoch 90/1000  Train NLL: -2.9223e+01  Test NLL: -2.9491e+01
# Epoch 91/1000  Train NLL: -2.9364e+01  Test NLL: -2.9589e+01
# Epoch 92/1000  Train NLL: -2.9521e+01  Test NLL: -2.9627e+01
# Epoch 93/1000  Train NLL: -2.9591e+01  Test NLL: -2.9875e+01
# Epoch 94/1000  Train NLL: -2.9775e+01  Test NLL: -3.0051e+01
# Epoch 95/1000  Train NLL: -2.9917e+01  Test NLL: -3.0086e+01
# Epoch 96/1000  Train NLL: -3.0021e+01  Test NLL: -3.0197e+01
# Epoch 97/1000  Train NLL: -3.0170e+01  Test NLL: -3.0344e+01
# Epoch 98/1000  Train NLL: -3.0275e+01  Test NLL: -3.0386e+01
# Epoch 99/1000  Train NLL: -3.0349e+01  Test NLL: -3.0623e+01
# Epoch 100/1000  Train NLL: -3.0501e+01  Test NLL: -3.0794e+01
# Epoch 101/1000  Train NLL: -3.0589e+01  Test NLL: -3.0825e+01
# Epoch 102/1000  Train NLL: -3.0669e+01  Test NLL: -3.0809e+01
# Epoch 103/1000  Train NLL: -3.0719e+01  Test NLL: -3.1022e+01
# Epoch 104/1000  Train NLL: -3.0875e+01  Test NLL: -3.1103e+01
# Epoch 105/1000  Train NLL: -3.0960e+01  Test NLL: -3.1089e+01
# Epoch 106/1000  Train NLL: -3.1046e+01  Test NLL: -3.1281e+01
# Epoch 107/1000  Train NLL: -3.1193e+01  Test NLL: -3.1439e+01
# Epoch 108/1000  Train NLL: -3.1303e+01  Test NLL: -3.1569e+01
# Epoch 109/1000  Train NLL: -3.1437e+01  Test NLL: -3.1710e+01
# Epoch 110/1000  Train NLL: -3.1567e+01  Test NLL: -3.1779e+01
# Epoch 111/1000  Train NLL: -3.1722e+01  Test NLL: -3.1996e+01
# Epoch 112/1000  Train NLL: -3.1899e+01  Test NLL: -3.2170e+01
# Epoch 113/1000  Train NLL: -3.2070e+01  Test NLL: -3.2265e+01
# Epoch 114/1000  Train NLL: -3.2229e+01  Test NLL: -3.2462e+01
# Epoch 115/1000  Train NLL: -3.2408e+01  Test NLL: -3.2677e+01
# Epoch 116/1000  Train NLL: -3.2547e+01  Test NLL: -3.2756e+01
# Epoch 117/1000  Train NLL: -3.2647e+01  Test NLL: -3.2882e+01
# Epoch 118/1000  Train NLL: -3.2757e+01  Test NLL: -3.3031e+01
# Epoch 119/1000  Train NLL: -3.2885e+01  Test NLL: -3.3109e+01
# Epoch 120/1000  Train NLL: -3.3015e+01  Test NLL: -3.3208e+01
# Epoch 121/1000  Train NLL: -3.3134e+01  Test NLL: -3.3412e+01
# Epoch 122/1000  Train NLL: -3.3263e+01  Test NLL: -3.3525e+01
# Epoch 123/1000  Train NLL: -3.3388e+01  Test NLL: -3.3541e+01
# Epoch 124/1000  Train NLL: -3.3492e+01  Test NLL: -3.3598e+01
# Epoch 125/1000  Train NLL: -3.3576e+01  Test NLL: -3.3822e+01
# Epoch 126/1000  Train NLL: -3.3667e+01  Test NLL: -3.3893e+01
# Epoch 127/1000  Train NLL: -3.3747e+01  Test NLL: -3.4013e+01
# Epoch 128/1000  Train NLL: -3.3770e+01  Test NLL: -3.3756e+01
# Epoch 129/1000  Train NLL: -3.3690e+01  Test NLL: -3.3787e+01
# Epoch 130/1000  Train NLL: -3.3881e+01  Test NLL: -3.4245e+01
# Epoch 131/1000  Train NLL: -3.3937e+01  Test NLL: -3.4277e+01
# Epoch 132/1000  Train NLL: -3.4088e+01  Test NLL: -3.4305e+01
# Epoch 133/1000  Train NLL: -3.4112e+01  Test NLL: -3.4317e+01
# Epoch 134/1000  Train NLL: -3.4120e+01  Test NLL: -3.4241e+01
# Epoch 135/1000  Train NLL: -3.4080e+01  Test NLL: -3.4372e+01
# Epoch 136/1000  Train NLL: -3.4279e+01  Test NLL: -3.4508e+01
# Epoch 137/1000  Train NLL: -3.4385e+01  Test NLL: -3.4678e+01
# Epoch 138/1000  Train NLL: -3.4519e+01  Test NLL: -3.4650e+01
# Epoch 139/1000  Train NLL: -3.4567e+01  Test NLL: -3.4771e+01
# Epoch 140/1000  Train NLL: -3.4725e+01  Test NLL: -3.4979e+01
# Epoch 141/1000  Train NLL: -3.4829e+01  Test NLL: -3.5021e+01
# Epoch 142/1000  Train NLL: -3.4895e+01  Test NLL: -3.5140e+01
# Epoch 143/1000  Train NLL: -3.5041e+01  Test NLL: -3.5251e+01
# Epoch 144/1000  Train NLL: -3.5104e+01  Test NLL: -3.5395e+01
# Epoch 145/1000  Train NLL: -3.5254e+01  Test NLL: -3.5225e+01
# Epoch 146/1000  Train NLL: -3.5206e+01  Test NLL: -3.5496e+01
# Epoch 147/1000  Train NLL: -3.5377e+01  Test NLL: -3.5658e+01
# Epoch 148/1000  Train NLL: -3.5475e+01  Test NLL: -3.5329e+01
# Epoch 149/1000  Train NLL: -3.5398e+01  Test NLL: -3.5703e+01
# Epoch 150/1000  Train NLL: -3.5504e+01  Test NLL: -3.5739e+01
# Epoch 151/1000  Train NLL: -3.5594e+01  Test NLL: -3.5452e+01
# Epoch 152/1000  Train NLL: -3.5578e+01  Test NLL: -3.5802e+01
# Epoch 153/1000  Train NLL: -3.5720e+01  Test NLL: -3.5981e+01
# Epoch 154/1000  Train NLL: -3.5841e+01  Test NLL: -3.6027e+01
# Epoch 155/1000  Train NLL: -3.5905e+01  Test NLL: -3.6135e+01
# Epoch 156/1000  Train NLL: -3.5989e+01  Test NLL: -3.6214e+01
# Epoch 157/1000  Train NLL: -3.6060e+01  Test NLL: -3.6253e+01
# Epoch 158/1000  Train NLL: -3.6147e+01  Test NLL: -3.6277e+01
# Epoch 159/1000  Train NLL: -3.6207e+01  Test NLL: -3.6479e+01
# Epoch 160/1000  Train NLL: -3.6306e+01  Test NLL: -3.6326e+01
# Epoch 161/1000  Train NLL: -3.6300e+01  Test NLL: -3.6307e+01
# Epoch 162/1000  Train NLL: -3.6152e+01  Test NLL: -3.6693e+01
# Epoch 163/1000  Train NLL: -3.5826e+01  Test NLL: -3.6619e+01
# Epoch 164/1000  Train NLL: -3.6158e+01  Test NLL: -3.6315e+01
# Epoch 165/1000  Train NLL: -3.6177e+01  Test NLL: -3.6761e+01
# Epoch 166/1000  Train NLL: -3.6093e+01  Test NLL: -3.6626e+01
# Epoch 167/1000  Train NLL: -3.6311e+01  Test NLL: -3.5824e+01
# Epoch 168/1000  Train NLL: -3.6244e+01  Test NLL: -3.6705e+01
# Epoch 169/1000  Train NLL: -3.6616e+01  Test NLL: -3.6849e+01
# Epoch 170/1000  Train NLL: -3.6596e+01  Test NLL: -3.6926e+01
# Epoch 171/1000  Train NLL: -3.6652e+01  Test NLL: -3.6890e+01
# Epoch 172/1000  Train NLL: -3.6714e+01  Test NLL: -3.6713e+01
# Epoch 173/1000  Train NLL: -3.6687e+01  Test NLL: -3.6970e+01
# Epoch 174/1000  Train NLL: -3.6831e+01  Test NLL: -3.7106e+01
# Epoch 175/1000  Train NLL: -3.6864e+01  Test NLL: -3.6928e+01
# Epoch 176/1000  Train NLL: -3.6817e+01  Test NLL: -3.7153e+01
# Epoch 177/1000  Train NLL: -3.6856e+01  Test NLL: -3.7013e+01
# Epoch 178/1000  Train NLL: -3.7056e+01  Test NLL: -3.6590e+01
# Epoch 179/1000  Train NLL: -3.6886e+01  Test NLL: -3.7152e+01
# Epoch 180/1000  Train NLL: -3.7054e+01  Test NLL: -3.7212e+01
# Epoch 181/1000  Train NLL: -3.7082e+01  Test NLL: -3.7335e+01
# Epoch 182/1000  Train NLL: -3.7086e+01  Test NLL: -3.7496e+01
# Epoch 183/1000  Train NLL: -3.7185e+01  Test NLL: -3.7406e+01
# Epoch 184/1000  Train NLL: -3.7192e+01  Test NLL: -3.7287e+01
# Epoch 185/1000  Train NLL: -3.7322e+01  Test NLL: -3.7594e+01
# Epoch 186/1000  Train NLL: -3.7443e+01  Test NLL: -3.7653e+01
# Epoch 187/1000  Train NLL: -3.7460e+01  Test NLL: -3.7749e+01
# Epoch 188/1000  Train NLL: -3.7550e+01  Test NLL: -3.7761e+01
# Epoch 189/1000  Train NLL: -3.7610e+01  Test NLL: -3.7699e+01
# Epoch 190/1000  Train NLL: -3.7654e+01  Test NLL: -3.7963e+01
# Epoch 191/1000  Train NLL: -3.7702e+01  Test NLL: -3.7948e+01
# Epoch 192/1000  Train NLL: -3.7718e+01  Test NLL: -3.7983e+01
# Epoch 193/1000  Train NLL: -3.7728e+01  Test NLL: -3.7951e+01
# Epoch 194/1000  Train NLL: -3.7596e+01  Test NLL: -3.8285e+01
# Epoch 195/1000  Train NLL: -3.8073e+01  Test NLL: -3.8241e+01
# Epoch 196/1000  Train NLL: -3.8135e+01  Test NLL: -3.8430e+01
# Epoch 197/1000  Train NLL: -3.8160e+01  Test NLL: -3.8419e+01
# Epoch 198/1000  Train NLL: -3.8292e+01  Test NLL: -3.8491e+01
# Epoch 199/1000  Train NLL: -3.8339e+01  Test NLL: -3.8535e+01
# Epoch 200/1000  Train NLL: -3.8405e+01  Test NLL: -3.8534e+01
# Epoch 201/1000  Train NLL: -3.8442e+01  Test NLL: -3.8705e+01
# Epoch 202/1000  Train NLL: -3.8524e+01  Test NLL: -3.8766e+01
# Epoch 203/1000  Train NLL: -3.8618e+01  Test NLL: -3.8754e+01
# Epoch 204/1000  Train NLL: -3.8635e+01  Test NLL: -3.8563e+01
# Epoch 205/1000  Train NLL: -3.8513e+01  Test NLL: -3.8717e+01
# Epoch 206/1000  Train NLL: -3.8686e+01  Test NLL: -3.9104e+01
# Epoch 207/1000  Train NLL: -3.8648e+01  Test NLL: -3.9043e+01
# Epoch 208/1000  Train NLL: -3.8746e+01  Test NLL: -3.9023e+01
# Epoch 209/1000  Train NLL: -3.8605e+01  Test NLL: -3.8971e+01
# Epoch 210/1000  Train NLL: -3.8918e+01  Test NLL: -3.9055e+01
# Epoch 211/1000  Train NLL: -3.9032e+01  Test NLL: -3.9107e+01
# Epoch 212/1000  Train NLL: -3.8792e+01  Test NLL: -3.8480e+01
# Epoch 213/1000  Train NLL: -3.8243e+01  Test NLL: -3.8829e+01
# Epoch 214/1000  Train NLL: -3.8872e+01  Test NLL: -3.8932e+01
# Epoch 215/1000  Train NLL: -3.8744e+01  Test NLL: -3.9084e+01
# Epoch 216/1000  Train NLL: -3.9111e+01  Test NLL: -3.9130e+01
# Epoch 217/1000  Train NLL: -3.9054e+01  Test NLL: -3.9292e+01
# Epoch 218/1000  Train NLL: -3.9190e+01  Test NLL: -3.9519e+01
# Epoch 219/1000  Train NLL: -3.9337e+01  Test NLL: -3.9259e+01
# Epoch 220/1000  Train NLL: -3.9344e+01  Test NLL: -3.9628e+01
# Epoch 221/1000  Train NLL: -3.9409e+01  Test NLL: -3.9746e+01
# Epoch 222/1000  Train NLL: -3.9493e+01  Test NLL: -3.9821e+01
# Epoch 223/1000  Train NLL: -3.9515e+01  Test NLL: -3.9657e+01
# Epoch 224/1000  Train NLL: -3.9571e+01  Test NLL: -3.9807e+01
# Epoch 225/1000  Train NLL: -3.9684e+01  Test NLL: -3.9782e+01
# Epoch 226/1000  Train NLL: -3.9547e+01  Test NLL: -3.9930e+01
# Epoch 227/1000  Train NLL: -3.9757e+01  Test NLL: -4.0021e+01
# Epoch 228/1000  Train NLL: -3.9795e+01  Test NLL: -4.0162e+01
# Epoch 229/1000  Train NLL: -3.9846e+01  Test NLL: -3.9666e+01
# Epoch 230/1000  Train NLL: -3.9898e+01  Test NLL: -4.0137e+01
# Epoch 231/1000  Train NLL: -4.0040e+01  Test NLL: -4.0334e+01
# Epoch 232/1000  Train NLL: -4.0121e+01  Test NLL: -4.0299e+01
# Epoch 233/1000  Train NLL: -4.0139e+01  Test NLL: -4.0447e+01
# Epoch 234/1000  Train NLL: -4.0229e+01  Test NLL: -4.0533e+01
# Epoch 235/1000  Train NLL: -4.0271e+01  Test NLL: -4.0606e+01
# Epoch 236/1000  Train NLL: -4.0363e+01  Test NLL: -4.0578e+01
# Epoch 237/1000  Train NLL: -4.0423e+01  Test NLL: -4.0665e+01
# Epoch 238/1000  Train NLL: -4.0491e+01  Test NLL: -4.0816e+01
# Epoch 239/1000  Train NLL: -4.0476e+01  Test NLL: -4.0897e+01
# Epoch 240/1000  Train NLL: -4.0567e+01  Test NLL: -4.0909e+01
# Epoch 241/1000  Train NLL: -4.0722e+01  Test NLL: -4.1052e+01
# Epoch 242/1000  Train NLL: -4.0737e+01  Test NLL: -4.0820e+01
# Epoch 243/1000  Train NLL: -4.0806e+01  Test NLL: -4.0983e+01
# Epoch 244/1000  Train NLL: -4.0906e+01  Test NLL: -4.1198e+01
# Epoch 245/1000  Train NLL: -4.0960e+01  Test NLL: -4.1284e+01
# Epoch 246/1000  Train NLL: -4.1004e+01  Test NLL: -4.1097e+01
# Epoch 247/1000  Train NLL: -4.1034e+01  Test NLL: -4.1217e+01
# Epoch 248/1000  Train NLL: -4.1107e+01  Test NLL: -4.1428e+01
# Epoch 249/1000  Train NLL: -4.1180e+01  Test NLL: -4.1291e+01
# Epoch 250/1000  Train NLL: -4.1214e+01  Test NLL: -4.1078e+01
# Epoch 251/1000  Train NLL: -4.1010e+01  Test NLL: -4.0767e+01
# Epoch 252/1000  Train NLL: -4.0896e+01  Test NLL: -4.1283e+01
# Epoch 253/1000  Train NLL: -4.1064e+01  Test NLL: -4.1402e+01
# Epoch 254/1000  Train NLL: -4.1119e+01  Test NLL: -4.1254e+01
# Epoch 255/1000  Train NLL: -4.0928e+01  Test NLL: -4.1383e+01
# Epoch 256/1000  Train NLL: -4.1327e+01  Test NLL: -4.1329e+01
# Epoch 257/1000  Train NLL: -4.1224e+01  Test NLL: -4.0863e+01
# Epoch 258/1000  Train NLL: -4.1150e+01  Test NLL: -4.1408e+01
# Epoch 259/1000  Train NLL: -4.1229e+01  Test NLL: -4.1755e+01
# Epoch 260/1000  Train NLL: -4.1288e+01  Test NLL: -4.1532e+01
# Epoch 261/1000  Train NLL: -4.1201e+01  Test NLL: -4.1927e+01
# Epoch 262/1000  Train NLL: -4.1555e+01  Test NLL: -4.1573e+01
# Epoch 263/1000  Train NLL: -4.1535e+01  Test NLL: -4.1634e+01
# Epoch 264/1000  Train NLL: -4.1564e+01  Test NLL: -4.1420e+01
# Epoch 265/1000  Train NLL: -4.1531e+01  Test NLL: -4.2085e+01
# Epoch 266/1000  Train NLL: -4.1709e+01  Test NLL: -4.1926e+01
# Epoch 267/1000  Train NLL: -4.1795e+01  Test NLL: -4.2174e+01
# Epoch 268/1000  Train NLL: -4.1845e+01  Test NLL: -4.2237e+01
# Epoch 269/1000  Train NLL: -4.1964e+01  Test NLL: -4.1986e+01
# Epoch 270/1000  Train NLL: -4.1308e+01  Test NLL: -4.2202e+01
# Epoch 271/1000  Train NLL: -4.1013e+01  Test NLL: -4.1933e+01
# Epoch 272/1000  Train NLL: -4.1949e+01  Test NLL: -4.2163e+01
# Epoch 273/1000  Train NLL: -4.1840e+01  Test NLL: -4.2507e+01
# Epoch 274/1000  Train NLL: -4.2054e+01  Test NLL: -4.2292e+01
# Epoch 275/1000  Train NLL: -4.2004e+01  Test NLL: -4.2293e+01
# Epoch 276/1000  Train NLL: -4.2297e+01  Test NLL: -4.2309e+01
# Epoch 277/1000  Train NLL: -4.2198e+01  Test NLL: -4.2423e+01
# Epoch 278/1000  Train NLL: -4.2269e+01  Test NLL: -4.2462e+01
# Epoch 279/1000  Train NLL: -4.2342e+01  Test NLL: -4.2504e+01
# Epoch 280/1000  Train NLL: -4.2284e+01  Test NLL: -4.2036e+01
# Epoch 281/1000  Train NLL: -4.2081e+01  Test NLL: -4.2783e+01
# Epoch 282/1000  Train NLL: -4.2232e+01  Test NLL: -4.2546e+01
# Epoch 283/1000  Train NLL: -4.2431e+01  Test NLL: -4.2952e+01
# Epoch 284/1000  Train NLL: -4.2025e+01  Test NLL: -4.2131e+01
# Epoch 285/1000  Train NLL: -4.2367e+01  Test NLL: -4.2585e+01
# Epoch 286/1000  Train NLL: -4.2492e+01  Test NLL: -4.1896e+01
# Epoch 287/1000  Train NLL: -4.2128e+01  Test NLL: -4.2894e+01
# Epoch 288/1000  Train NLL: -4.2624e+01  Test NLL: -4.3189e+01
# Epoch 289/1000  Train NLL: -4.2026e+01  Test NLL: -4.2610e+01
# Epoch 290/1000  Train NLL: -4.2345e+01  Test NLL: -4.2623e+01
# Epoch 291/1000  Train NLL: -4.2437e+01  Test NLL: -4.3104e+01
# Epoch 292/1000  Train NLL: -4.2665e+01  Test NLL: -4.2524e+01
# Epoch 293/1000  Train NLL: -4.2418e+01  Test NLL: -4.3097e+01
# Epoch 294/1000  Train NLL: -4.2723e+01  Test NLL: -4.2938e+01
# Epoch 295/1000  Train NLL: -4.2475e+01  Test NLL: -4.2403e+01
# Epoch 296/1000  Train NLL: -4.2829e+01  Test NLL: -4.3143e+01
# Epoch 297/1000  Train NLL: -4.2849e+01  Test NLL: -4.0973e+01
# Epoch 298/1000  Train NLL: -4.2402e+01  Test NLL: -4.2970e+01
# Epoch 299/1000  Train NLL: -4.3001e+01  Test NLL: -4.3178e+01
# Epoch 300/1000  Train NLL: -4.3154e+01  Test NLL: -4.3573e+01
# Epoch 301/1000  Train NLL: -4.3050e+01  Test NLL: -4.3035e+01
# Epoch 302/1000  Train NLL: -4.3181e+01  Test NLL: -4.3555e+01
# Epoch 303/1000  Train NLL: -4.3248e+01  Test NLL: -4.3394e+01
# Epoch 304/1000  Train NLL: -4.3170e+01  Test NLL: -4.3515e+01
# Epoch 305/1000  Train NLL: -4.3199e+01  Test NLL: -4.3407e+01
# Epoch 306/1000  Train NLL: -4.3243e+01  Test NLL: -4.3606e+01
# Epoch 307/1000  Train NLL: -4.3076e+01  Test NLL: -4.2740e+01
# Epoch 308/1000  Train NLL: -4.2863e+01  Test NLL: -4.3568e+01
# Epoch 309/1000  Train NLL: -4.2755e+01  Test NLL: -4.3781e+01
# Epoch 310/1000  Train NLL: -4.2945e+01  Test NLL: -4.3282e+01
# Epoch 311/1000  Train NLL: -4.3197e+01  Test NLL: -4.2639e+01
# Epoch 312/1000  Train NLL: -4.2839e+01  Test NLL: -4.2745e+01
# Epoch 313/1000  Train NLL: -4.2288e+01  Test NLL: -4.2171e+01
# Epoch 314/1000  Train NLL: -4.2447e+01  Test NLL: -4.2501e+01
# Epoch 315/1000  Train NLL: -4.2525e+01  Test NLL: -4.3280e+01
# Epoch 316/1000  Train NLL: -4.3161e+01  Test NLL: -4.3655e+01
# Epoch 317/1000  Train NLL: -4.3219e+01  Test NLL: -4.2625e+01
# Epoch 318/1000  Train NLL: -4.2054e+01  Test NLL: -4.3362e+01
# Epoch 319/1000  Train NLL: -4.2705e+01  Test NLL: -4.3939e+01
# Epoch 320/1000  Train NLL: -4.3603e+01  Test NLL: -4.2865e+01
# Epoch 321/1000  Train NLL: -4.3356e+01  Test NLL: -4.4099e+01
# Epoch 322/1000  Train NLL: -4.3811e+01  Test NLL: -4.4366e+01
# Epoch 323/1000  Train NLL: -4.4022e+01  Test NLL: -4.4317e+01
# Epoch 324/1000  Train NLL: -4.4003e+01  Test NLL: -4.4027e+01
# Epoch 325/1000  Train NLL: -4.3912e+01  Test NLL: -4.4575e+01
# Epoch 326/1000  Train NLL: -4.4178e+01  Test NLL: -4.3382e+01
# Epoch 327/1000  Train NLL: -4.3503e+01  Test NLL: -4.3452e+01
# Epoch 328/1000  Train NLL: -4.3650e+01  Test NLL: -4.3704e+01
# Epoch 329/1000  Train NLL: -4.3560e+01  Test NLL: -4.4190e+01
# Epoch 330/1000  Train NLL: -4.3817e+01  Test NLL: -4.3139e+01
# Epoch 331/1000  Train NLL: -4.4229e+01  Test NLL: -4.4464e+01
# Epoch 332/1000  Train NLL: -4.4399e+01  Test NLL: -4.4521e+01
# Epoch 333/1000  Train NLL: -4.4294e+01  Test NLL: -4.4623e+01
# Epoch 334/1000  Train NLL: -4.4417e+01  Test NLL: -4.3931e+01
# Epoch 335/1000  Train NLL: -4.4132e+01  Test NLL: -4.4023e+01
# Epoch 336/1000  Train NLL: -4.3514e+01  Test NLL: -4.4447e+01
# Epoch 337/1000  Train NLL: -4.4229e+01  Test NLL: -4.4553e+01
# Epoch 338/1000  Train NLL: -4.4425e+01  Test NLL: -4.4772e+01
# Epoch 339/1000  Train NLL: -4.4582e+01  Test NLL: -4.4838e+01
# Epoch 340/1000  Train NLL: -4.4558e+01  Test NLL: -4.4812e+01
# Epoch 341/1000  Train NLL: -4.4710e+01  Test NLL: -4.4830e+01
# Epoch 342/1000  Train NLL: -4.4689e+01  Test NLL: -4.4606e+01
# Epoch 343/1000  Train NLL: -4.4789e+01  Test NLL: -4.4533e+01
# Epoch 344/1000  Train NLL: -4.4713e+01  Test NLL: -4.4988e+01
# Epoch 345/1000  Train NLL: -4.4723e+01  Test NLL: -4.5227e+01
# Epoch 346/1000  Train NLL: -4.4826e+01  Test NLL: -4.4977e+01
# Epoch 347/1000  Train NLL: -4.4690e+01  Test NLL: -4.4869e+01
# Epoch 348/1000  Train NLL: -4.4914e+01  Test NLL: -4.4607e+01
# Epoch 349/1000  Train NLL: -4.4902e+01  Test NLL: -4.5080e+01
# Epoch 350/1000  Train NLL: -4.5024e+01  Test NLL: -4.5113e+01
# Epoch 351/1000  Train NLL: -4.5055e+01  Test NLL: -4.5177e+01
# Epoch 352/1000  Train NLL: -4.5102e+01  Test NLL: -4.5271e+01
# Epoch 353/1000  Train NLL: -4.5129e+01  Test NLL: -4.5603e+01
# Epoch 354/1000  Train NLL: -4.5178e+01  Test NLL: -4.5321e+01
# Epoch 355/1000  Train NLL: -4.5222e+01  Test NLL: -4.5623e+01
# Epoch 356/1000  Train NLL: -4.5208e+01  Test NLL: -4.5734e+01
# Epoch 357/1000  Train NLL: -4.5256e+01  Test NLL: -4.5331e+01
# Epoch 358/1000  Train NLL: -4.4628e+01  Test NLL: -4.4737e+01
# Epoch 359/1000  Train NLL: -4.4655e+01  Test NLL: -4.3953e+01
# Epoch 360/1000  Train NLL: -4.4802e+01  Test NLL: -4.4760e+01
# Epoch 361/1000  Train NLL: -4.4934e+01  Test NLL: -4.5674e+01
# Epoch 362/1000  Train NLL: -4.5194e+01  Test NLL: -4.4752e+01
# Epoch 363/1000  Train NLL: -4.4928e+01  Test NLL: -4.5448e+01
# Epoch 364/1000  Train NLL: -4.4947e+01  Test NLL: -4.5498e+01
# Epoch 365/1000  Train NLL: -4.5076e+01  Test NLL: -4.4506e+01
# Epoch 366/1000  Train NLL: -4.4586e+01  Test NLL: -4.5380e+01
# Epoch 367/1000  Train NLL: -4.5204e+01  Test NLL: -4.5665e+01
# Epoch 368/1000  Train NLL: -4.5170e+01  Test NLL: -4.4714e+01
# Epoch 369/1000  Train NLL: -4.4947e+01  Test NLL: -4.5522e+01
# Epoch 370/1000  Train NLL: -4.5056e+01  Test NLL: -4.5481e+01
# Epoch 371/1000  Train NLL: -4.4944e+01  Test NLL: -4.4243e+01
# Epoch 372/1000  Train NLL: -4.4964e+01  Test NLL: -4.5173e+01
# Epoch 373/1000  Train NLL: -4.5201e+01  Test NLL: -4.5872e+01
# Epoch 374/1000  Train NLL: -4.5191e+01  Test NLL: -4.4965e+01
# Epoch 375/1000  Train NLL: -4.5216e+01  Test NLL: -4.5650e+01
# Epoch 376/1000  Train NLL: -4.4952e+01  Test NLL: -4.5827e+01
# Epoch 377/1000  Train NLL: -4.5067e+01  Test NLL: -4.4792e+01
# Epoch 378/1000  Train NLL: -4.5077e+01  Test NLL: -4.5520e+01
# Epoch 379/1000  Train NLL: -4.5258e+01  Test NLL: -4.5944e+01
# Epoch 380/1000  Train NLL: -4.5440e+01  Test NLL: -4.4903e+01
# Epoch 381/1000  Train NLL: -4.5255e+01  Test NLL: -4.5580e+01
# Epoch 382/1000  Train NLL: -4.5004e+01  Test NLL: -4.5942e+01
# Epoch 383/1000  Train NLL: -4.5200e+01  Test NLL: -4.4595e+01
# Epoch 384/1000  Train NLL: -4.5212e+01  Test NLL: -4.5366e+01
# Epoch 385/1000  Train NLL: -4.5388e+01  Test NLL: -4.6187e+01
# Epoch 386/1000  Train NLL: -4.5682e+01  Test NLL: -4.5148e+01
# Epoch 387/1000  Train NLL: -4.5136e+01  Test NLL: -4.5823e+01
# Epoch 388/1000  Train NLL: -4.5357e+01  Test NLL: -4.5917e+01
# Epoch 389/1000  Train NLL: -4.5425e+01  Test NLL: -4.4327e+01
# Epoch 390/1000  Train NLL: -4.5243e+01  Test NLL: -4.5267e+01
# Epoch 391/1000  Train NLL: -4.5296e+01  Test NLL: -4.6366e+01
# Epoch 392/1000  Train NLL: -4.5553e+01  Test NLL: -4.5644e+01
# Epoch 393/1000  Train NLL: -4.5326e+01  Test NLL: -4.6249e+01
# Epoch 394/1000  Train NLL: -4.5726e+01  Test NLL: -4.5749e+01
# Epoch 395/1000  Train NLL: -4.5686e+01  Test NLL: -4.4446e+01
# Epoch 396/1000  Train NLL: -4.5550e+01  Test NLL: -4.5543e+01
# Epoch 397/1000  Train NLL: -4.5743e+01  Test NLL: -4.6494e+01
# Epoch 398/1000  Train NLL: -4.5786e+01  Test NLL: -4.5714e+01
# Epoch 399/1000  Train NLL: -4.5491e+01  Test NLL: -4.6321e+01
# Epoch 400/1000  Train NLL: -4.5549e+01  Test NLL: -4.5672e+01
# Epoch 401/1000  Train NLL: -4.5914e+01  Test NLL: -4.4240e+01
# Epoch 402/1000  Train NLL: -4.5464e+01  Test NLL: -4.5333e+01
# Epoch 403/1000  Train NLL: -4.5064e+01  Test NLL: -4.6675e+01
# Epoch 404/1000  Train NLL: -4.5557e+01  Test NLL: -4.5775e+01
# Epoch 405/1000  Train NLL: -4.5568e+01  Test NLL: -4.6432e+01
# Epoch 406/1000  Train NLL: -4.5847e+01  Test NLL: -4.6071e+01
# Epoch 407/1000  Train NLL: -4.6134e+01  Test NLL: -4.4735e+01
# Epoch 408/1000  Train NLL: -4.5830e+01  Test NLL: -4.5801e+01
# Epoch 409/1000  Train NLL: -4.5819e+01  Test NLL: -4.6677e+01
# Epoch 410/1000  Train NLL: -4.6015e+01  Test NLL: -4.5729e+01
# Epoch 411/1000  Train NLL: -4.5626e+01  Test NLL: -4.6470e+01
# Epoch 412/1000  Train NLL: -4.5974e+01  Test NLL: -4.6104e+01
# Epoch 413/1000  Train NLL: -4.6216e+01  Test NLL: -4.4985e+01
# Epoch 414/1000  Train NLL: -4.5735e+01  Test NLL: -4.6239e+01
# Epoch 415/1000  Train NLL: -4.5948e+01  Test NLL: -4.6051e+01
# Epoch 416/1000  Train NLL: -4.6177e+01  Test NLL: -4.6477e+01
# Epoch 417/1000  Train NLL: -4.6624e+01  Test NLL: -4.6610e+01
# Epoch 418/1000  Train NLL: -4.6604e+01  Test NLL: -4.6777e+01
# Epoch 419/1000  Train NLL: -4.6454e+01  Test NLL: -4.6959e+01
# Epoch 420/1000  Train NLL: -4.6579e+01  Test NLL: -4.7027e+01
# Epoch 421/1000  Train NLL: -4.6657e+01  Test NLL: -4.7061e+01
# Epoch 422/1000  Train NLL: -4.6336e+01  Test NLL: -4.5455e+01
# Epoch 423/1000  Train NLL: -4.5874e+01  Test NLL: -4.6743e+01
# Epoch 424/1000  Train NLL: -4.6399e+01  Test NLL: -4.7290e+01
# Epoch 425/1000  Train NLL: -4.5645e+01  Test NLL: -4.6094e+01
# Epoch 426/1000  Train NLL: -4.5108e+01  Test NLL: -4.5116e+01
# Epoch 427/1000  Train NLL: -4.5867e+01  Test NLL: -4.6992e+01
# Epoch 428/1000  Train NLL: -4.6790e+01  Test NLL: -4.6979e+01
# Epoch 429/1000  Train NLL: -4.7021e+01  Test NLL: -4.5841e+01
# Epoch 430/1000  Train NLL: -4.5457e+01  Test NLL: -4.7310e+01
# Epoch 431/1000  Train NLL: -4.5196e+01  Test NLL: -4.6460e+01
# Epoch 432/1000  Train NLL: -4.5086e+01  Test NLL: -4.6244e+01
# Epoch 433/1000  Train NLL: -4.5703e+01  Test NLL: -4.4713e+01
# Epoch 434/1000  Train NLL: -4.6386e+01  Test NLL: -4.6469e+01
# Epoch 435/1000  Train NLL: -4.6436e+01  Test NLL: -4.6948e+01
# Epoch 436/1000  Train NLL: -4.6784e+01  Test NLL: -4.6243e+01
# Epoch 437/1000  Train NLL: -4.5920e+01  Test NLL: -4.6035e+01
# Epoch 438/1000  Train NLL: -4.6156e+01  Test NLL: -4.6859e+01
# Epoch 439/1000  Train NLL: -4.6813e+01  Test NLL: -4.5803e+01
# Epoch 440/1000  Train NLL: -4.6468e+01  Test NLL: -4.6456e+01
# Epoch 441/1000  Train NLL: -4.7170e+01  Test NLL: -4.7015e+01
# Epoch 442/1000  Train NLL: -4.6653e+01  Test NLL: -4.7583e+01
# Epoch 443/1000  Train NLL: -4.7110e+01  Test NLL: -4.7937e+01
# Epoch 444/1000  Train NLL: -4.7472e+01  Test NLL: -4.7382e+01
# Epoch 445/1000  Train NLL: -4.7428e+01  Test NLL: -4.7106e+01
# Epoch 446/1000  Train NLL: -4.7358e+01  Test NLL: -4.6888e+01
# Epoch 447/1000  Train NLL: -4.7493e+01  Test NLL: -4.7841e+01
# Epoch 448/1000  Train NLL: -4.7622e+01  Test NLL: -4.7434e+01
# Epoch 449/1000  Train NLL: -4.7451e+01  Test NLL: -4.8060e+01
# Epoch 450/1000  Train NLL: -4.7746e+01  Test NLL: -4.7353e+01
# Epoch 451/1000  Train NLL: -4.7519e+01  Test NLL: -4.8250e+01
# Epoch 452/1000  Train NLL: -4.7538e+01  Test NLL: -4.7500e+01
# Epoch 453/1000  Train NLL: -4.6948e+01  Test NLL: -4.7225e+01
# Epoch 454/1000  Train NLL: -4.7251e+01  Test NLL: -4.7656e+01
# Epoch 455/1000  Train NLL: -4.6371e+01  Test NLL: -4.6667e+01
# Epoch 456/1000  Train NLL: -4.7381e+01  Test NLL: -4.6022e+01
# Epoch 457/1000  Train NLL: -4.6944e+01  Test NLL: -4.7854e+01
# Epoch 458/1000  Train NLL: -4.7463e+01  Test NLL: -4.8173e+01
# Epoch 459/1000  Train NLL: -4.7144e+01  Test NLL: -4.7043e+01
# Epoch 460/1000  Train NLL: -4.6522e+01  Test NLL: -4.7969e+01
# Epoch 461/1000  Train NLL: -4.7589e+01  Test NLL: -4.8201e+01
# Epoch 462/1000  Train NLL: -4.6728e+01  Test NLL: -4.7094e+01
# Epoch 463/1000  Train NLL: -4.7036e+01  Test NLL: -4.7413e+01
# Epoch 464/1000  Train NLL: -4.7273e+01  Test NLL: -4.8582e+01
# Epoch 465/1000  Train NLL: -4.7452e+01  Test NLL: -4.7542e+01
# Epoch 466/1000  Train NLL: -4.7174e+01  Test NLL: -4.8422e+01
# Epoch 467/1000  Train NLL: -4.7499e+01  Test NLL: -4.7517e+01
# Epoch 468/1000  Train NLL: -4.7722e+01  Test NLL: -4.5636e+01
# Epoch 469/1000  Train NLL: -4.7134e+01  Test NLL: -4.7488e+01
# Epoch 470/1000  Train NLL: -4.7407e+01  Test NLL: -4.8288e+01
# Epoch 471/1000  Train NLL: -4.7513e+01  Test NLL: -4.7732e+01
# Epoch 472/1000  Train NLL: -4.7322e+01  Test NLL: -4.8182e+01
# Epoch 473/1000  Train NLL: -4.7537e+01  Test NLL: -4.8316e+01
# Epoch 474/1000  Train NLL: -4.7672e+01  Test NLL: -4.6651e+01
# Epoch 475/1000  Train NLL: -4.7410e+01  Test NLL: -4.7579e+01
# Epoch 476/1000  Train NLL: -4.7155e+01  Test NLL: -4.8695e+01
# Epoch 477/1000  Train NLL: -4.7366e+01  Test NLL: -4.7308e+01
# Epoch 478/1000  Train NLL: -4.7184e+01  Test NLL: -4.8147e+01
# Epoch 479/1000  Train NLL: -4.7439e+01  Test NLL: -4.7644e+01
# Epoch 480/1000  Train NLL: -4.8031e+01  Test NLL: -4.8570e+01
# Epoch 481/1000  Train NLL: -4.8334e+01  Test NLL: -4.8752e+01
# Epoch 482/1000  Train NLL: -4.8423e+01  Test NLL: -4.8584e+01
# Epoch 483/1000  Train NLL: -4.8394e+01  Test NLL: -4.7554e+01
# Epoch 484/1000  Train NLL: -4.6821e+01  Test NLL: -4.8240e+01
# Epoch 485/1000  Train NLL: -4.7986e+01  Test NLL: -4.8514e+01
# Epoch 486/1000  Train NLL: -4.8363e+01  Test NLL: -4.9072e+01
# Epoch 487/1000  Train NLL: -4.8425e+01  Test NLL: -4.8359e+01
# Epoch 488/1000  Train NLL: -4.7750e+01  Test NLL: -4.8216e+01
# Epoch 489/1000  Train NLL: -4.7334e+01  Test NLL: -4.7331e+01
# Epoch 490/1000  Train NLL: -4.7925e+01  Test NLL: -4.9187e+01
# Epoch 491/1000  Train NLL: -4.7803e+01  Test NLL: -4.7970e+01
# Epoch 492/1000  Train NLL: -4.6799e+01  Test NLL: -4.8865e+01
# Epoch 493/1000  Train NLL: -4.7785e+01  Test NLL: -4.6032e+01
# Epoch 494/1000  Train NLL: -4.6615e+01  Test NLL: -4.5639e+01
# Epoch 495/1000  Train NLL: -4.7180e+01  Test NLL: -4.7947e+01
# Epoch 496/1000  Train NLL: -4.8326e+01  Test NLL: -4.8675e+01
# Epoch 497/1000  Train NLL: -4.8826e+01  Test NLL: -4.8546e+01
# Epoch 498/1000  Train NLL: -4.8755e+01  Test NLL: -4.8642e+01
# Epoch 499/1000  Train NLL: -4.8827e+01  Test NLL: -4.8377e+01
# Epoch 500/1000  Train NLL: -4.8895e+01  Test NLL: -4.8850e+01
# Epoch 501/1000  Train NLL: -4.8927e+01  Test NLL: -4.8030e+01
# Epoch 502/1000  Train NLL: -4.7803e+01  Test NLL: -4.6818e+01
# Epoch 503/1000  Train NLL: -4.7437e+01  Test NLL: -4.8024e+01
# Epoch 504/1000  Train NLL: -4.8129e+01  Test NLL: -4.8588e+01
# Epoch 505/1000  Train NLL: -4.8561e+01  Test NLL: -4.8607e+01
# Epoch 506/1000  Train NLL: -4.8114e+01  Test NLL: -4.6908e+01
# Epoch 507/1000  Train NLL: -4.6249e+01  Test NLL: -4.3196e+01
# Epoch 508/1000  Train NLL: -4.6020e+01  Test NLL: -4.7499e+01
# Epoch 509/1000  Train NLL: -4.7620e+01  Test NLL: -4.9250e+01
# Epoch 510/1000  Train NLL: -4.8215e+01  Test NLL: -4.9125e+01
# Epoch 511/1000  Train NLL: -4.8806e+01  Test NLL: -4.9819e+01
# Epoch 512/1000  Train NLL: -4.9255e+01  Test NLL: -4.8887e+01
# Epoch 513/1000  Train NLL: -4.9348e+01  Test NLL: -4.9878e+01
# Epoch 514/1000  Train NLL: -4.9183e+01  Test NLL: -4.9807e+01
# Epoch 515/1000  Train NLL: -4.9032e+01  Test NLL: -4.9694e+01
# Epoch 516/1000  Train NLL: -4.9211e+01  Test NLL: -5.0006e+01
# Epoch 517/1000  Train NLL: -4.9378e+01  Test NLL: -4.9469e+01
# Epoch 518/1000  Train NLL: -4.9562e+01  Test NLL: -4.9157e+01
# Epoch 519/1000  Train NLL: -4.9621e+01  Test NLL: -5.0332e+01
# Epoch 520/1000  Train NLL: -4.9427e+01  Test NLL: -4.9878e+01
# Epoch 521/1000  Train NLL: -4.9618e+01  Test NLL: -4.9358e+01
# Epoch 522/1000  Train NLL: -4.9611e+01  Test NLL: -5.0110e+01
# Epoch 523/1000  Train NLL: -4.9758e+01  Test NLL: -4.9479e+01
# Epoch 524/1000  Train NLL: -4.9583e+01  Test NLL: -4.9758e+01
# Epoch 525/1000  Train NLL: -4.9628e+01  Test NLL: -4.9845e+01
# Epoch 526/1000  Train NLL: -4.9833e+01  Test NLL: -5.0160e+01
# Epoch 527/1000  Train NLL: -4.9525e+01  Test NLL: -5.0567e+01
# Epoch 528/1000  Train NLL: -5.0156e+01  Test NLL: -5.0337e+01
# Epoch 529/1000  Train NLL: -5.0086e+01  Test NLL: -5.0214e+01
# Epoch 530/1000  Train NLL: -4.9609e+01  Test NLL: -4.9682e+01
# Epoch 531/1000  Train NLL: -4.9591e+01  Test NLL: -5.0244e+01
# Epoch 532/1000  Train NLL: -5.0027e+01  Test NLL: -5.0699e+01
# Epoch 533/1000  Train NLL: -4.9907e+01  Test NLL: -4.8631e+01
# Epoch 534/1000  Train NLL: -4.9524e+01  Test NLL: -4.9868e+01
# Epoch 535/1000  Train NLL: -4.9352e+01  Test NLL: -4.9698e+01
# Epoch 536/1000  Train NLL: -4.8349e+01  Test NLL: -4.8077e+01
# Epoch 537/1000  Train NLL: -4.8442e+01  Test NLL: -4.7617e+01
# Epoch 538/1000  Train NLL: -4.8056e+01  Test NLL: -5.0424e+01
# Epoch 539/1000  Train NLL: -5.0032e+01  Test NLL: -5.0183e+01
# Epoch 540/1000  Train NLL: -5.0168e+01  Test NLL: -4.9875e+01
# Epoch 541/1000  Train NLL: -4.9979e+01  Test NLL: -5.0947e+01
# Epoch 542/1000  Train NLL: -4.8642e+01  Test NLL: -4.8799e+01
# Epoch 543/1000  Train NLL: -4.9047e+01  Test NLL: -4.9359e+01
# Epoch 544/1000  Train NLL: -4.8909e+01  Test NLL: -5.0419e+01
# Epoch 545/1000  Train NLL: -4.8805e+01  Test NLL: -4.9680e+01
# Epoch 546/1000  Train NLL: -4.9102e+01  Test NLL: -4.8816e+01
# Epoch 547/1000  Train NLL: -4.8606e+01  Test NLL: -5.0734e+01
# Epoch 548/1000  Train NLL: -4.9577e+01  Test NLL: -4.7701e+01
# Epoch 549/1000  Train NLL: -4.9029e+01  Test NLL: -4.9040e+01
# Epoch 550/1000  Train NLL: -4.8650e+01  Test NLL: -5.0366e+01
# Epoch 551/1000  Train NLL: -4.8938e+01  Test NLL: -4.7602e+01
# Epoch 552/1000  Train NLL: -4.8515e+01  Test NLL: -4.9840e+01
# Epoch 553/1000  Train NLL: -4.9101e+01  Test NLL: -5.0282e+01
# Epoch 554/1000  Train NLL: -4.8704e+01  Test NLL: -4.9525e+01
# Epoch 555/1000  Train NLL: -5.0033e+01  Test NLL: -5.0793e+01
# Epoch 556/1000  Train NLL: -5.0123e+01  Test NLL: -4.7493e+01
# Epoch 557/1000  Train NLL: -4.8390e+01  Test NLL: -4.9669e+01
# Epoch 558/1000  Train NLL: -4.9255e+01  Test NLL: -5.0142e+01
# Epoch 559/1000  Train NLL: -4.9299e+01  Test NLL: -4.6209e+01
# Epoch 560/1000  Train NLL: -4.9171e+01  Test NLL: -4.9923e+01
# Epoch 561/1000  Train NLL: -5.0285e+01  Test NLL: -5.0264e+01
# Epoch 562/1000  Train NLL: -4.9912e+01  Test NLL: -4.9561e+01
# Epoch 563/1000  Train NLL: -4.9609e+01  Test NLL: -4.8058e+01
# Epoch 564/1000  Train NLL: -4.8002e+01  Test NLL: -5.0997e+01
# Epoch 565/1000  Train NLL: -4.9313e+01  Test NLL: -4.8715e+01
# Epoch 566/1000  Train NLL: -4.9601e+01  Test NLL: -5.0391e+01
# Epoch 567/1000  Train NLL: -4.9824e+01  Test NLL: -4.7930e+01
# Epoch 568/1000  Train NLL: -4.7728e+01  Test NLL: -5.0244e+01
# Epoch 569/1000  Train NLL: -4.7731e+01  Test NLL: -5.1487e+01
# Epoch 570/1000  Train NLL: -4.9654e+01  Test NLL: -4.7801e+01
# Epoch 571/1000  Train NLL: -4.8492e+01  Test NLL: -4.8158e+01
# Epoch 572/1000  Train NLL: -4.8911e+01  Test NLL: -5.1216e+01
# Epoch 573/1000  Train NLL: -5.0362e+01  Test NLL: -5.1416e+01
# Epoch 574/1000  Train NLL: -4.9760e+01  Test NLL: -4.5966e+01
# Epoch 575/1000  Train NLL: -4.9177e+01  Test NLL: -4.9434e+01
# Epoch 576/1000  Train NLL: -4.8739e+01  Test NLL: -5.0561e+01
# Epoch 577/1000  Train NLL: -4.9942e+01  Test NLL: -4.6482e+01
# Epoch 578/1000  Train NLL: -4.8949e+01  Test NLL: -4.9896e+01
# Epoch 579/1000  Train NLL: -4.8837e+01  Test NLL: -4.8930e+01
# Epoch 580/1000  Train NLL: -5.0531e+01  Test NLL: -4.7811e+01
# Epoch 581/1000  Train NLL: -4.8474e+01  Test NLL: -5.1260e+01
# Epoch 582/1000  Train NLL: -5.0546e+01  Test NLL: -5.1378e+01
# Epoch 583/1000  Train NLL: -5.0824e+01  Test NLL: -5.0626e+01
# Epoch 584/1000  Train NLL: -5.0953e+01  Test NLL: -5.1637e+01
# Epoch 585/1000  Train NLL: -5.0491e+01  Test NLL: -4.7315e+01
# Epoch 586/1000  Train NLL: -4.9534e+01  Test NLL: -4.9491e+01
# Epoch 587/1000  Train NLL: -4.9351e+01  Test NLL: -5.0219e+01
# Epoch 588/1000  Train NLL: -4.9005e+01  Test NLL: -4.9618e+01
# Epoch 589/1000  Train NLL: -4.9618e+01  Test NLL: -5.0471e+01
# Epoch 590/1000  Train NLL: -4.9779e+01  Test NLL: -5.1571e+01
# Epoch 591/1000  Train NLL: -4.9172e+01  Test NLL: -5.0598e+01
# Epoch 592/1000  Train NLL: -4.9965e+01  Test NLL: -4.9888e+01
# Epoch 593/1000  Train NLL: -4.9948e+01  Test NLL: -5.0260e+01
# Epoch 594/1000  Train NLL: -4.9851e+01  Test NLL: -4.8771e+01
# Epoch 595/1000  Train NLL: -4.7156e+01  Test NLL: -4.7063e+01
# Epoch 596/1000  Train NLL: -4.8517e+01  Test NLL: -5.0290e+01
# Epoch 597/1000  Train NLL: -4.9570e+01  Test NLL: -5.0368e+01
# Epoch 598/1000  Train NLL: -4.9340e+01  Test NLL: -5.1614e+01
# Epoch 599/1000  Train NLL: -4.9001e+01  Test NLL: -4.7575e+01
# Epoch 600/1000  Train NLL: -4.9213e+01  Test NLL: -5.1469e+01
# Epoch 601/1000  Train NLL: -5.0283e+01  Test NLL: -5.0191e+01
# Epoch 602/1000  Train NLL: -4.9168e+01  Test NLL: -4.8547e+01
# Epoch 603/1000  Train NLL: -4.9942e+01  Test NLL: -4.8894e+01
# Epoch 604/1000  Train NLL: -4.8708e+01  Test NLL: -5.1319e+01
# Epoch 605/1000  Train NLL: -5.0404e+01  Test NLL: -5.1896e+01
# Epoch 606/1000  Train NLL: -5.1274e+01  Test NLL: -5.1474e+01
# Epoch 607/1000  Train NLL: -5.0903e+01  Test NLL: -4.9764e+01
# Epoch 608/1000  Train NLL: -5.0615e+01  Test NLL: -5.1467e+01
# Epoch 609/1000  Train NLL: -5.1545e+01  Test NLL: -5.1864e+01
# Epoch 610/1000  Train NLL: -5.1273e+01  Test NLL: -5.1429e+01
# Epoch 611/1000  Train NLL: -5.0883e+01  Test NLL: -4.9675e+01
# Epoch 612/1000  Train NLL: -4.9246e+01  Test NLL: -4.6099e+01
# Epoch 613/1000  Train NLL: -4.8975e+01  Test NLL: -5.1321e+01
# Epoch 614/1000  Train NLL: -4.9860e+01  Test NLL: -4.8925e+01
# Epoch 615/1000  Train NLL: -4.9040e+01  Test NLL: -4.9398e+01
# Epoch 616/1000  Train NLL: -4.8091e+01  Test NLL: -4.9315e+01
# Epoch 617/1000  Train NLL: -4.9790e+01  Test NLL: -5.1226e+01
# Epoch 618/1000  Train NLL: -5.0334e+01  Test NLL: -5.1189e+01
# Epoch 619/1000  Train NLL: -5.0810e+01  Test NLL: -5.2604e+01
# Epoch 620/1000  Train NLL: -5.1925e+01  Test NLL: -5.0853e+01
# Epoch 621/1000  Train NLL: -5.1225e+01  Test NLL: -5.1449e+01
# Epoch 622/1000  Train NLL: -5.1536e+01  Test NLL: -5.1278e+01
# Epoch 623/1000  Train NLL: -5.1740e+01  Test NLL: -5.2331e+01
# Epoch 624/1000  Train NLL: -5.1230e+01  Test NLL: -5.1466e+01
# Epoch 625/1000  Train NLL: -5.1265e+01  Test NLL: -4.9461e+01
# Epoch 626/1000  Train NLL: -4.7485e+01  Test NLL: -5.0901e+01
# Epoch 627/1000  Train NLL: -4.5018e+01  Test NLL: -4.8886e+01
# Epoch 628/1000  Train NLL: -4.7225e+01  Test NLL: -4.9477e+01
# Epoch 629/1000  Train NLL: -5.0127e+01  Test NLL: -5.2361e+01
# Epoch 630/1000  Train NLL: -4.9253e+01  Test NLL: -5.0738e+01
# Epoch 631/1000  Train NLL: -4.9774e+01  Test NLL: -5.1191e+01
# Epoch 632/1000  Train NLL: -5.0193e+01  Test NLL: -4.6091e+01
# Epoch 633/1000  Train NLL: -4.9544e+01  Test NLL: -4.9378e+01
# Epoch 634/1000  Train NLL: -4.9971e+01  Test NLL: -5.2062e+01
# Epoch 635/1000  Train NLL: -5.0239e+01  Test NLL: -4.9585e+01
# Epoch 636/1000  Train NLL: -4.9895e+01  Test NLL: -5.2298e+01
# Epoch 637/1000  Train NLL: -5.1099e+01  Test NLL: -5.2865e+01
# Epoch 638/1000  Train NLL: -5.2207e+01  Test NLL: -4.9502e+01
# Epoch 639/1000  Train NLL: -5.1345e+01  Test NLL: -5.1012e+01
# Epoch 640/1000  Train NLL: -5.0331e+01  Test NLL: -5.1987e+01
# Epoch 641/1000  Train NLL: -5.1745e+01  Test NLL: -5.1915e+01
# Epoch 642/1000  Train NLL: -5.2059e+01  Test NLL: -5.0655e+01
# Epoch 643/1000  Train NLL: -5.1636e+01  Test NLL: -5.1982e+01
# Epoch 644/1000  Train NLL: -5.1166e+01  Test NLL: -5.2238e+01
# Epoch 645/1000  Train NLL: -5.0180e+01  Test NLL: -4.8070e+01
# Epoch 646/1000  Train NLL: -4.9722e+01  Test NLL: -5.1780e+01
# Epoch 647/1000  Train NLL: -5.0719e+01  Test NLL: -5.0996e+01
# Epoch 648/1000  Train NLL: -5.0986e+01  Test NLL: -5.2306e+01
# Epoch 649/1000  Train NLL: -5.0745e+01  Test NLL: -5.2505e+01
# Epoch 650/1000  Train NLL: -5.1510e+01  Test NLL: -4.8278e+01
# Epoch 651/1000  Train NLL: -4.9658e+01  Test NLL: -5.2231e+01
# Epoch 652/1000  Train NLL: -5.1012e+01  Test NLL: -5.1492e+01
# Epoch 653/1000  Train NLL: -5.1788e+01  Test NLL: -5.1899e+01
# Epoch 654/1000  Train NLL: -5.1805e+01  Test NLL: -5.2367e+01
# Epoch 655/1000  Train NLL: -5.2211e+01  Test NLL: -5.1393e+01
# Epoch 656/1000  Train NLL: -5.1221e+01  Test NLL: -5.2958e+01
# Epoch 657/1000  Train NLL: -4.9779e+01  Test NLL: -5.0342e+01
# Epoch 658/1000  Train NLL: -4.8888e+01  Test NLL: -5.1008e+01
# Epoch 659/1000  Train NLL: -5.1322e+01  Test NLL: -5.0314e+01
# Epoch 660/1000  Train NLL: -5.1871e+01  Test NLL: -5.2778e+01
# Epoch 661/1000  Train NLL: -5.2306e+01  Test NLL: -5.1701e+01
# Epoch 662/1000  Train NLL: -5.2365e+01  Test NLL: -5.1914e+01
# Epoch 663/1000  Train NLL: -5.1897e+01  Test NLL: -5.0287e+01
# Epoch 664/1000  Train NLL: -4.9176e+01  Test NLL: -5.1945e+01
# Epoch 665/1000  Train NLL: -5.0423e+01  Test NLL: -5.1923e+01
# Epoch 666/1000  Train NLL: -5.0072e+01  Test NLL: -4.7032e+01
# Epoch 667/1000  Train NLL: -5.0378e+01  Test NLL: -4.9546e+01
# Epoch 668/1000  Train NLL: -4.9533e+01  Test NLL: -5.2758e+01
# Epoch 669/1000  Train NLL: -5.1309e+01  Test NLL: -4.9546e+01
# Epoch 670/1000  Train NLL: -5.0118e+01  Test NLL: -5.1155e+01
# Epoch 671/1000  Train NLL: -4.9903e+01  Test NLL: -5.2537e+01
# Epoch 672/1000  Train NLL: -5.0994e+01  Test NLL: -4.8960e+01
# Epoch 673/1000  Train NLL: -4.9991e+01  Test NLL: -5.1743e+01
# Epoch 674/1000  Train NLL: -5.0978e+01  Test NLL: -5.1474e+01
# Epoch 675/1000  Train NLL: -5.1464e+01  Test NLL: -4.7643e+01
# Epoch 676/1000  Train NLL: -4.9802e+01  Test NLL: -5.0968e+01
# Epoch 677/1000  Train NLL: -5.0753e+01  Test NLL: -5.2472e+01
# Epoch 678/1000  Train NLL: -5.0149e+01  Test NLL: -4.8869e+01
# Epoch 679/1000  Train NLL: -5.0625e+01  Test NLL: -5.1019e+01
# Epoch 680/1000  Train NLL: -5.1127e+01  Test NLL: -5.2667e+01
# Epoch 681/1000  Train NLL: -5.0677e+01  Test NLL: -5.0020e+01
# Epoch 682/1000  Train NLL: -5.0060e+01  Test NLL: -5.1916e+01
# Epoch 683/1000  Train NLL: -5.1154e+01  Test NLL: -5.2181e+01
# Epoch 684/1000  Train NLL: -5.1095e+01  Test NLL: -4.8799e+01
# Epoch 685/1000  Train NLL: -5.0250e+01  Test NLL: -5.1026e+01
# Epoch 686/1000  Train NLL: -5.0360e+01  Test NLL: -5.2120e+01
# Epoch 687/1000  Train NLL: -5.1522e+01  Test NLL: -4.8367e+01
# Epoch 688/1000  Train NLL: -5.0326e+01  Test NLL: -5.1287e+01
# Epoch 689/1000  Train NLL: -5.0617e+01  Test NLL: -5.2402e+01
# Epoch 690/1000  Train NLL: -5.1003e+01  Test NLL: -4.6140e+01
# Epoch 691/1000  Train NLL: -4.9999e+01  Test NLL: -5.1388e+01
# Epoch 692/1000  Train NLL: -5.0595e+01  Test NLL: -4.9860e+01
# Epoch 693/1000  Train NLL: -5.1695e+01  Test NLL: -5.2260e+01
# Epoch 694/1000  Train NLL: -5.1982e+01  Test NLL: -5.3100e+01
# Epoch 695/1000  Train NLL: -5.2420e+01  Test NLL: -5.1139e+01
# Epoch 696/1000  Train NLL: -5.1936e+01  Test NLL: -5.3484e+01
# Epoch 697/1000  Train NLL: -5.2649e+01  Test NLL: -5.1799e+01
# Epoch 698/1000  Train NLL: -5.2075e+01  Test NLL: -5.2917e+01
# Epoch 699/1000  Train NLL: -5.3094e+01  Test NLL: -5.3414e+01
# Epoch 700/1000  Train NLL: -5.2292e+01  Test NLL: -5.3658e+01
# Epoch 701/1000  Train NLL: -5.3177e+01  Test NLL: -5.2548e+01
# Epoch 702/1000  Train NLL: -5.0887e+01  Test NLL: -4.8141e+01
# Epoch 703/1000  Train NLL: -4.9084e+01  Test NLL: -5.2221e+01
# Epoch 704/1000  Train NLL: -5.1162e+01  Test NLL: -5.0894e+01
# Epoch 705/1000  Train NLL: -4.9331e+01  Test NLL: -5.1520e+01
# Epoch 706/1000  Train NLL: -5.1745e+01  Test NLL: -5.2567e+01
# Epoch 707/1000  Train NLL: -5.2992e+01  Test NLL: -4.9822e+01
# Epoch 708/1000  Train NLL: -5.1432e+01  Test NLL: -5.4073e+01
# Epoch 709/1000  Train NLL: -5.2722e+01  Test NLL: -5.1822e+01
# Epoch 710/1000  Train NLL: -5.1862e+01  Test NLL: -5.0820e+01
# Epoch 711/1000  Train NLL: -5.0775e+01  Test NLL: -5.3490e+01
# Epoch 712/1000  Train NLL: -5.2951e+01  Test NLL: -5.3719e+01
# Epoch 713/1000  Train NLL: -5.3541e+01  Test NLL: -5.3066e+01
# Epoch 714/1000  Train NLL: -5.2974e+01  Test NLL: -5.2232e+01
# Epoch 715/1000  Train NLL: -5.1877e+01  Test NLL: -5.2895e+01
# Epoch 716/1000  Train NLL: -5.2047e+01  Test NLL: -5.2886e+01
# Epoch 717/1000  Train NLL: -5.2644e+01  Test NLL: -5.2971e+01
# Epoch 718/1000  Train NLL: -5.2327e+01  Test NLL: -4.6737e+01
# Epoch 719/1000  Train NLL: -5.0246e+01  Test NLL: -5.2701e+01
# Epoch 720/1000  Train NLL: -5.2480e+01  Test NLL: -5.2713e+01
# Epoch 721/1000  Train NLL: -5.2895e+01  Test NLL: -5.3387e+01
# Epoch 722/1000  Train NLL: -5.2881e+01  Test NLL: -5.4487e+01
# Epoch 723/1000  Train NLL: -4.9798e+01  Test NLL: -5.1177e+01
# Epoch 724/1000  Train NLL: -4.9602e+01  Test NLL: -4.4109e+01
# Epoch 725/1000  Train NLL: -4.8082e+01  Test NLL: -5.0738e+01
# Epoch 726/1000  Train NLL: -4.9124e+01  Test NLL: -5.1231e+01
# Epoch 727/1000  Train NLL: -5.0377e+01  Test NLL: -5.3052e+01
# Epoch 728/1000  Train NLL: -5.2261e+01  Test NLL: -5.4015e+01
# Epoch 729/1000  Train NLL: -5.2235e+01  Test NLL: -5.3024e+01
# Epoch 730/1000  Train NLL: -5.3273e+01  Test NLL: -5.4585e+01
# Epoch 731/1000  Train NLL: -5.4085e+01  Test NLL: -5.4723e+01
# Epoch 732/1000  Train NLL: -5.1684e+01  Test NLL: -4.2217e+01
# Epoch 733/1000  Train NLL: -4.7217e+01  Test NLL: -5.1910e+01
# Epoch 734/1000  Train NLL: -5.0404e+01  Test NLL: -4.4348e+01
# Epoch 735/1000  Train NLL: -4.9788e+01  Test NLL: -5.3201e+01
# Epoch 736/1000  Train NLL: -5.2848e+01  Test NLL: -5.1545e+01
# Epoch 737/1000  Train NLL: -5.0719e+01  Test NLL: -5.0309e+01
# Epoch 738/1000  Train NLL: -5.0526e+01  Test NLL: -5.2157e+01
# Epoch 739/1000  Train NLL: -5.1884e+01  Test NLL: -5.2960e+01
# Epoch 740/1000  Train NLL: -5.2010e+01  Test NLL: -5.3307e+01
# Epoch 741/1000  Train NLL: -5.3604e+01  Test NLL: -5.2558e+01
# Epoch 742/1000  Train NLL: -5.3144e+01  Test NLL: -5.2750e+01
# Epoch 743/1000  Train NLL: -5.3324e+01  Test NLL: -5.3439e+01
# Epoch 744/1000  Train NLL: -5.3171e+01  Test NLL: -5.2677e+01
# Epoch 745/1000  Train NLL: -5.2714e+01  Test NLL: -5.4770e+01
# Epoch 746/1000  Train NLL: -4.4845e+01  Test NLL: -4.8977e+01
# Epoch 747/1000  Train NLL: -4.7820e+01  Test NLL: -4.8690e+01
# Epoch 748/1000  Train NLL: -4.9561e+01  Test NLL: -4.8515e+01
# Epoch 749/1000  Train NLL: -4.9106e+01  Test NLL: -5.3860e+01
# Epoch 750/1000  Train NLL: -5.1482e+01  Test NLL: -4.8472e+01
# Epoch 751/1000  Train NLL: -4.9937e+01  Test NLL: -5.3638e+01
# Epoch 752/1000  Train NLL: -5.2339e+01  Test NLL: -5.4657e+01
# Epoch 753/1000  Train NLL: -5.4202e+01  Test NLL: -5.3751e+01
# Epoch 754/1000  Train NLL: -5.2726e+01  Test NLL: -5.2338e+01
# Epoch 755/1000  Train NLL: -5.3090e+01  Test NLL: -5.3388e+01
# Epoch 756/1000  Train NLL: -5.3129e+01  Test NLL: -5.4451e+01
# Epoch 757/1000  Train NLL: -5.2676e+01  Test NLL: -4.0077e+01
# Epoch 758/1000  Train NLL: -3.7860e+01  Test NLL: -1.6429e+01
# Epoch 759/1000  Train NLL: -3.8215e+01  Test NLL: -2.0212e+01
# Epoch 760/1000  Train NLL: -3.5980e+01  Test NLL: -3.8391e+01
# Epoch 761/1000  Train NLL: -4.5700e+01  Test NLL: -4.2401e+01
# Epoch 762/1000  Train NLL: -4.5804e+01  Test NLL: -4.1253e+01
# Epoch 763/1000  Train NLL: -4.1638e+01  Test NLL: -4.4758e+01
# Epoch 764/1000  Train NLL: -4.4274e+01  Test NLL: -4.7126e+01
# Epoch 765/1000  Train NLL: -4.7462e+01  Test NLL: -5.3081e+01
# Epoch 766/1000  Train NLL: -5.1000e+01  Test NLL: -5.1486e+01
# Epoch 767/1000  Train NLL: -5.1675e+01  Test NLL: -5.2760e+01
# Epoch 768/1000  Train NLL: -5.2618e+01  Test NLL: -5.4119e+01
# Epoch 769/1000  Train NLL: -5.3795e+01  Test NLL: -5.4065e+01
# Epoch 770/1000  Train NLL: -5.3555e+01  Test NLL: -5.3326e+01
# Epoch 771/1000  Train NLL: -5.3418e+01  Test NLL: -5.3804e+01
# Epoch 772/1000  Train NLL: -5.3975e+01  Test NLL: -5.0149e+01
# Epoch 773/1000  Train NLL: -5.2170e+01  Test NLL: -5.5068e+01
# Epoch 774/1000  Train NLL: -5.2613e+01  Test NLL: -5.4079e+01
# Epoch 775/1000  Train NLL: -5.3565e+01  Test NLL: -5.4719e+01
# Epoch 776/1000  Train NLL: -5.3632e+01  Test NLL: -5.2554e+01
# Epoch 777/1000  Train NLL: -5.3837e+01  Test NLL: -5.3770e+01
# Epoch 778/1000  Train NLL: -5.3978e+01  Test NLL: -5.4544e+01
# Epoch 779/1000  Train NLL: -5.4123e+01  Test NLL: -5.4526e+01
# Epoch 780/1000  Train NLL: -5.4089e+01  Test NLL: -5.4592e+01
# Epoch 781/1000  Train NLL: -5.4114e+01  Test NLL: -5.4887e+01
# Epoch 782/1000  Train NLL: -5.4019e+01  Test NLL: -5.4147e+01
# Epoch 783/1000  Train NLL: -5.3976e+01  Test NLL: -5.4529e+01
# Epoch 784/1000  Train NLL: -5.3808e+01  Test NLL: -5.5006e+01
# Epoch 785/1000  Train NLL: -5.4178e+01  Test NLL: -5.5100e+01
# Epoch 786/1000  Train NLL: -5.3731e+01  Test NLL: -5.4495e+01
# Epoch 787/1000  Train NLL: -5.4019e+01  Test NLL: -5.5272e+01
# Epoch 788/1000  Train NLL: -5.3812e+01  Test NLL: -5.5411e+01
# Epoch 789/1000  Train NLL: -4.7918e+01  Test NLL: -4.7939e+01
# Epoch 790/1000  Train NLL: -4.6041e+01  Test NLL: -4.4065e+01
# Epoch 791/1000  Train NLL: -4.6046e+01  Test NLL: -4.9484e+01
# Epoch 792/1000  Train NLL: -5.1921e+01  Test NLL: -5.4893e+01
# Epoch 793/1000  Train NLL: -5.3642e+01  Test NLL: -5.5559e+01
# Epoch 794/1000  Train NLL: -5.4182e+01  Test NLL: -5.5530e+01
# Epoch 795/1000  Train NLL: -5.4046e+01  Test NLL: -5.3940e+01
# Epoch 796/1000  Train NLL: -5.4448e+01  Test NLL: -5.5201e+01
# Epoch 797/1000  Train NLL: -5.3579e+01  Test NLL: -5.3007e+01
# Epoch 798/1000  Train NLL: -5.1680e+01  Test NLL: -5.3092e+01
# Epoch 799/1000  Train NLL: -5.2628e+01  Test NLL: -5.3811e+01
# Epoch 800/1000  Train NLL: -5.3185e+01  Test NLL: -4.9941e+01
# Epoch 801/1000  Train NLL: -5.2404e+01  Test NLL: -5.5451e+01
# Epoch 802/1000  Train NLL: -5.4898e+01  Test NLL: -5.3448e+01
# Epoch 803/1000  Train NLL: -5.3850e+01  Test NLL: -5.1957e+01
# Epoch 804/1000  Train NLL: -5.3707e+01  Test NLL: -5.1498e+01
# Epoch 805/1000  Train NLL: -5.3428e+01  Test NLL: -5.3929e+01
# Epoch 806/1000  Train NLL: -5.3861e+01  Test NLL: -5.3073e+01
# Epoch 807/1000  Train NLL: -5.4169e+01  Test NLL: -5.4596e+01
# Epoch 808/1000  Train NLL: -5.3953e+01  Test NLL: -5.3613e+01
# Epoch 809/1000  Train NLL: -5.2557e+01  Test NLL: -5.0658e+01
# Epoch 810/1000  Train NLL: -5.1329e+01  Test NLL: -5.2311e+01
# Epoch 811/1000  Train NLL: -5.2176e+01  Test NLL: -5.5469e+01
# Epoch 812/1000  Train NLL: -5.3871e+01  Test NLL: -5.3565e+01
# Epoch 813/1000  Train NLL: -5.4851e+01  Test NLL: -5.4819e+01
# Epoch 814/1000  Train NLL: -5.4370e+01  Test NLL: -5.5366e+01
# Epoch 815/1000  Train NLL: -5.4358e+01  Test NLL: -5.5227e+01
# Epoch 816/1000  Train NLL: -5.4053e+01  Test NLL: -5.6129e+01
# Epoch 817/1000  Train NLL: -5.4452e+01  Test NLL: -5.4544e+01
# Epoch 818/1000  Train NLL: -5.2800e+01  Test NLL: -5.5248e+01
# Epoch 819/1000  Train NLL: -5.4183e+01  Test NLL: -5.1999e+01
# Epoch 820/1000  Train NLL: -5.2638e+01  Test NLL: -5.2081e+01
# Epoch 821/1000  Train NLL: -5.2398e+01  Test NLL: -5.6270e+01
# Epoch 822/1000  Train NLL: -5.4095e+01  Test NLL: -5.4863e+01
# Epoch 823/1000  Train NLL: -5.4786e+01  Test NLL: -5.5166e+01
# Epoch 824/1000  Train NLL: -5.3629e+01  Test NLL: -5.6032e+01
# Epoch 825/1000  Train NLL: -5.3976e+01  Test NLL: -5.4136e+01
# Epoch 826/1000  Train NLL: -5.4035e+01  Test NLL: -5.6126e+01
# Epoch 827/1000  Train NLL: -5.4508e+01  Test NLL: -5.4737e+01
# Epoch 828/1000  Train NLL: -5.4866e+01  Test NLL: -5.4666e+01
# Epoch 829/1000  Train NLL: -5.4900e+01  Test NLL: -5.4368e+01
# Epoch 830/1000  Train NLL: -5.4617e+01  Test NLL: -5.4832e+01
# Epoch 831/1000  Train NLL: -5.4643e+01  Test NLL: -5.4111e+01
# Epoch 832/1000  Train NLL: -5.4402e+01  Test NLL: -5.4520e+01
# Epoch 833/1000  Train NLL: -5.4970e+01  Test NLL: -5.6023e+01
# Epoch 834/1000  Train NLL: -5.5057e+01  Test NLL: -5.5944e+01
# Epoch 835/1000  Train NLL: -5.5088e+01  Test NLL: -5.4407e+01
# Epoch 836/1000  Train NLL: -5.4540e+01  Test NLL: -5.6133e+01
# Epoch 837/1000  Train NLL: -5.4942e+01  Test NLL: -5.6694e+01
# Epoch 838/1000  Train NLL: -5.3614e+01  Test NLL: -5.1047e+01
# Epoch 839/1000  Train NLL: -5.1767e+01  Test NLL: -5.3094e+01
# Epoch 840/1000  Train NLL: -5.0191e+01  Test NLL: -5.4104e+01
# Epoch 841/1000  Train NLL: -4.8233e+01  Test NLL: -5.3582e+01
# Epoch 842/1000  Train NLL: -5.0410e+01  Test NLL: -5.0080e+01
# Epoch 843/1000  Train NLL: -5.1126e+01  Test NLL: -5.4244e+01
# Epoch 844/1000  Train NLL: -5.1143e+01  Test NLL: -4.4394e+01
# Epoch 845/1000  Train NLL: -4.0386e+01  Test NLL: -4.7801e+01
# Epoch 846/1000  Train NLL: -4.1828e+01  Test NLL: -4.1990e+01
# Epoch 847/1000  Train NLL: -3.4846e+01  Test NLL: -4.2748e+01
# Epoch 848/1000  Train NLL: -4.7969e+01  Test NLL: -4.9846e+01
# Epoch 849/1000  Train NLL: -5.0463e+01  Test NLL: -5.0647e+01
# Epoch 850/1000  Train NLL: -5.1767e+01  Test NLL: -5.5848e+01
# Epoch 851/1000  Train NLL: -5.4815e+01  Test NLL: -4.9215e+01
# Epoch 852/1000  Train NLL: -5.1500e+01  Test NLL: -5.0655e+01
# Epoch 853/1000  Train NLL: -4.8991e+01  Test NLL: -5.2909e+01
# Epoch 854/1000  Train NLL: -4.9068e+01  Test NLL: -5.1767e+01
# Epoch 855/1000  Train NLL: -5.1021e+01  Test NLL: -4.9218e+01
# Epoch 856/1000  Train NLL: -5.2247e+01  Test NLL: -5.5927e+01
# Epoch 857/1000  Train NLL: -5.4918e+01  Test NLL: -5.5243e+01
# Epoch 858/1000  Train NLL: -5.4922e+01  Test NLL: -5.6408e+01
# Epoch 859/1000  Train NLL: -5.4859e+01  Test NLL: -5.5416e+01
# Epoch 860/1000  Train NLL: -5.4903e+01  Test NLL: -5.6565e+01
# Epoch 861/1000  Train NLL: -5.5029e+01  Test NLL: -5.7129e+01
# Epoch 862/1000  Train NLL: -5.4845e+01  Test NLL: -5.3521e+01
# Epoch 863/1000  Train NLL: -5.4815e+01  Test NLL: -5.3026e+01
# Epoch 864/1000  Train NLL: -5.3990e+01  Test NLL: -5.5562e+01
# Epoch 865/1000  Train NLL: -5.4405e+01  Test NLL: -5.6262e+01
# Epoch 866/1000  Train NLL: -5.5492e+01  Test NLL: -5.5777e+01
# Epoch 867/1000  Train NLL: -5.4655e+01  Test NLL: -5.5854e+01
# Epoch 868/1000  Train NLL: -5.5107e+01  Test NLL: -5.6501e+01
# Epoch 869/1000  Train NLL: -5.4955e+01  Test NLL: -5.4488e+01
# Epoch 870/1000  Train NLL: -5.4081e+01  Test NLL: -5.5290e+01
# Epoch 871/1000  Train NLL: -5.4578e+01  Test NLL: -4.9964e+01
# Epoch 872/1000  Train NLL: -5.1061e+01  Test NLL: -5.0689e+01
# Epoch 873/1000  Train NLL: -5.0659e+01  Test NLL: -5.0946e+01
# Epoch 874/1000  Train NLL: -4.9922e+01  Test NLL: -5.2678e+01
# Epoch 875/1000  Train NLL: -5.3670e+01  Test NLL: -5.1049e+01
# Epoch 876/1000  Train NLL: -5.1219e+01  Test NLL: -5.6034e+01
# Epoch 877/1000  Train NLL: -5.4181e+01  Test NLL: -5.4287e+01
# Epoch 878/1000  Train NLL: -5.1013e+01  Test NLL: -5.5104e+01
# Epoch 879/1000  Train NLL: -5.0768e+01  Test NLL: -5.0118e+01
# Epoch 880/1000  Train NLL: -5.0558e+01  Test NLL: -5.0259e+01
# Epoch 881/1000  Train NLL: -5.0592e+01  Test NLL: -5.6911e+01
# Epoch 882/1000  Train NLL: -5.0694e+01  Test NLL: -5.3234e+01
# Epoch 883/1000  Train NLL: -4.9972e+01  Test NLL: -5.4870e+01
# Epoch 884/1000  Train NLL: -5.2977e+01  Test NLL: -5.3790e+01
# Epoch 885/1000  Train NLL: -5.1429e+01  Test NLL: -5.4543e+01
# Epoch 886/1000  Train NLL: -5.0386e+01  Test NLL: -4.6271e+01
# Epoch 887/1000  Train NLL: -5.1488e+01  Test NLL: -5.3429e+01
# Epoch 888/1000  Train NLL: -5.3740e+01  Test NLL: -5.4409e+01
# Epoch 889/1000  Train NLL: -5.2649e+01  Test NLL: -5.2073e+01
# Epoch 890/1000  Train NLL: -5.3349e+01  Test NLL: -5.5384e+01
# Epoch 891/1000  Train NLL: -5.4774e+01  Test NLL: -5.6249e+01
# Epoch 892/1000  Train NLL: -5.4808e+01  Test NLL: -5.5584e+01
# Epoch 893/1000  Train NLL: -5.4993e+01  Test NLL: -5.5327e+01
# Epoch 894/1000  Train NLL: -5.4312e+01  Test NLL: -5.1008e+01
# Epoch 895/1000  Train NLL: -5.1435e+01  Test NLL: -4.8786e+01
# Epoch 896/1000  Train NLL: -5.0841e+01  Test NLL: -5.5244e+01
# Epoch 897/1000  Train NLL: -5.4064e+01  Test NLL: -5.0387e+01
# Epoch 898/1000  Train NLL: -5.3251e+01  Test NLL: -5.6517e+01
# Epoch 899/1000  Train NLL: -4.7885e+01  Test NLL: -4.8686e+01
# Epoch 900/1000  Train NLL: -4.6258e+01  Test NLL: -5.5259e+01
# Epoch 901/1000  Train NLL: -5.0820e+01  Test NLL: -4.8465e+01
# Epoch 902/1000  Train NLL: -5.1578e+01  Test NLL: -5.3218e+01
# Epoch 903/1000  Train NLL: -5.3288e+01  Test NLL: -5.5790e+01
# Epoch 904/1000  Train NLL: -5.5306e+01  Test NLL: -5.5490e+01
# Epoch 905/1000  Train NLL: -5.4487e+01  Test NLL: -5.4973e+01
# Epoch 906/1000  Train NLL: -5.5625e+01  Test NLL: -5.3969e+01
# Epoch 907/1000  Train NLL: -5.4249e+01  Test NLL: -5.6027e+01
# Epoch 908/1000  Train NLL: -5.5645e+01  Test NLL: -5.5733e+01
# Epoch 909/1000  Train NLL: -5.5838e+01  Test NLL: -5.5162e+01
# Epoch 910/1000  Train NLL: -5.5461e+01  Test NLL: -5.1832e+01
# Epoch 911/1000  Train NLL: -5.2301e+01  Test NLL: -5.6807e+01
# Epoch 912/1000  Train NLL: -5.4431e+01  Test NLL: -4.8931e+01
# Epoch 913/1000  Train NLL: -5.2583e+01  Test NLL: -5.6405e+01
# Epoch 914/1000  Train NLL: -5.2045e+01  Test NLL: -4.1179e+01
# Epoch 915/1000  Train NLL: -4.6763e+01  Test NLL: -5.4892e+01
# Epoch 916/1000  Train NLL: -5.3207e+01  Test NLL: -5.4028e+01
# Epoch 917/1000  Train NLL: -5.1255e+01  Test NLL: -4.4099e+01
# Epoch 918/1000  Train NLL: -5.0761e+01  Test NLL: -4.7780e+01
# Epoch 919/1000  Train NLL: -4.7902e+01  Test NLL: -5.1768e+01
# Epoch 920/1000  Train NLL: -5.1980e+01  Test NLL: -3.7319e+01
# Epoch 921/1000  Train NLL: -4.9706e+01  Test NLL: -5.1301e+01
# Epoch 922/1000  Train NLL: -5.0092e+01  Test NLL: -4.9772e+01
# Epoch 923/1000  Train NLL: -4.7205e+01  Test NLL: -4.2621e+01
# Epoch 924/1000  Train NLL: -4.5099e+01  Test NLL: -4.6178e+01
# Epoch 925/1000  Train NLL: -5.0253e+01  Test NLL: -5.1758e+01
# Epoch 926/1000  Train NLL: -5.2765e+01  Test NLL: -5.4301e+01
# Epoch 927/1000  Train NLL: -5.5732e+01  Test NLL: -5.5212e+01
# Epoch 928/1000  Train NLL: -5.5715e+01  Test NLL: -5.5176e+01
# Epoch 929/1000  Train NLL: -5.5473e+01  Test NLL: -5.5702e+01
# Epoch 930/1000  Train NLL: -5.5838e+01  Test NLL: -5.5492e+01
# Epoch 931/1000  Train NLL: -5.5323e+01  Test NLL: -5.5816e+01
# Epoch 932/1000  Train NLL: -5.5622e+01  Test NLL: -5.6827e+01
# Epoch 933/1000  Train NLL: -5.5723e+01  Test NLL: -5.4733e+01
# Epoch 934/1000  Train NLL: -5.5759e+01  Test NLL: -5.7099e+01
# Epoch 935/1000  Train NLL: -5.5775e+01  Test NLL: -5.5418e+01
# Epoch 936/1000  Train NLL: -5.5638e+01  Test NLL: -5.6574e+01
# Epoch 937/1000  Train NLL: -5.6240e+01  Test NLL: -5.5159e+01
# Epoch 938/1000  Train NLL: -5.5824e+01  Test NLL: -5.4598e+01
# Epoch 939/1000  Train NLL: -5.4783e+01  Test NLL: -5.7172e+01
# Epoch 940/1000  Train NLL: -5.5332e+01  Test NLL: -5.5766e+01
# Epoch 941/1000  Train NLL: -5.5534e+01  Test NLL: -5.5934e+01
# Epoch 942/1000  Train NLL: -5.4434e+01  Test NLL: -4.4537e+01
# Epoch 943/1000  Train NLL: -5.0411e+01  Test NLL: -5.6311e+01
# Epoch 944/1000  Train NLL: -5.1992e+01  Test NLL: -5.4867e+01
# Epoch 945/1000  Train NLL: -5.4496e+01  Test NLL: -5.4094e+01
# Epoch 946/1000  Train NLL: -5.2561e+01  Test NLL: -4.6838e+01
# Epoch 947/1000  Train NLL: -4.7912e+01  Test NLL: -5.3518e+01
# Epoch 948/1000  Train NLL: -4.8414e+01  Test NLL: -5.7246e+01
# Epoch 949/1000  Train NLL: -5.4775e+01  Test NLL: -5.4657e+01
# Epoch 950/1000  Train NLL: -5.3671e+01  Test NLL: -5.6334e+01
# Epoch 951/1000  Train NLL: -5.4840e+01  Test NLL: -5.2621e+01
# Epoch 952/1000  Train NLL: -4.7717e+01  Test NLL: -5.7342e+01
# Epoch 953/1000  Train NLL: -5.1995e+01  Test NLL: -5.4261e+01
# Epoch 954/1000  Train NLL: -5.2518e+01  Test NLL: -5.5545e+01
# Epoch 955/1000  Train NLL: -5.1076e+01  Test NLL: -5.0775e+01
# Epoch 956/1000  Train NLL: -4.3759e+01  Test NLL: -4.5359e+01
# Epoch 957/1000  Train NLL: -4.6514e+01  Test NLL: -5.2631e+01
# Epoch 958/1000  Train NLL: -5.2736e+01  Test NLL: -5.7682e+01
# Epoch 959/1000  Train NLL: -5.3439e+01  Test NLL: -5.4294e+01
# Epoch 960/1000  Train NLL: -5.4040e+01  Test NLL: -5.6095e+01
# Epoch 961/1000  Train NLL: -5.5480e+01  Test NLL: -5.2960e+01
# Epoch 962/1000  Train NLL: -5.3859e+01  Test NLL: -5.7991e+01
# Epoch 963/1000  Train NLL: -5.6369e+01  Test NLL: -5.6607e+01
# Epoch 964/1000  Train NLL: -5.4740e+01  Test NLL: -5.3280e+01
# Epoch 965/1000  Train NLL: -5.4617e+01  Test NLL: -5.2771e+01
# Epoch 966/1000  Train NLL: -5.2017e+01  Test NLL: -5.4389e+01
# Epoch 967/1000  Train NLL: -5.2942e+01  Test NLL: -5.4402e+01
# Epoch 968/1000  Train NLL: -5.3194e+01  Test NLL: -5.6635e+01
# Epoch 969/1000  Train NLL: -5.5967e+01  Test NLL: -5.6540e+01
# Epoch 970/1000  Train NLL: -5.5436e+01  Test NLL: -5.4222e+01
# Epoch 971/1000  Train NLL: -5.5738e+01  Test NLL: -5.6209e+01
# Epoch 972/1000  Train NLL: -5.6089e+01  Test NLL: -5.5202e+01
# Epoch 973/1000  Train NLL: -5.6342e+01  Test NLL: -5.4870e+01
# Epoch 974/1000  Train NLL: -5.5459e+01  Test NLL: -5.7783e+01
# Epoch 975/1000  Train NLL: -5.5875e+01  Test NLL: -5.7912e+01
# Epoch 976/1000  Train NLL: -5.6034e+01  Test NLL: -5.7169e+01
# Epoch 977/1000  Train NLL: -5.5767e+01  Test NLL: -5.8000e+01
# Epoch 978/1000  Train NLL: -5.6401e+01  Test NLL: -5.4591e+01
# Epoch 979/1000  Train NLL: -5.5891e+01  Test NLL: -5.6588e+01
# Epoch 980/1000  Train NLL: -5.6675e+01  Test NLL: -5.6031e+01
# Epoch 981/1000  Train NLL: -5.6354e+01  Test NLL: -5.5405e+01
# Epoch 982/1000  Train NLL: -5.6583e+01  Test NLL: -5.7502e+01
# Epoch 983/1000  Train NLL: -5.6450e+01  Test NLL: -5.8026e+01
# Epoch 984/1000  Train NLL: -5.6116e+01  Test NLL: -5.7160e+01
# Epoch 985/1000  Train NLL: -5.6024e+01  Test NLL: -5.7838e+01
# Epoch 986/1000  Train NLL: -5.6501e+01  Test NLL: -5.6950e+01
# Epoch 987/1000  Train NLL: -5.5485e+01  Test NLL: -5.3742e+01
# Epoch 988/1000  Train NLL: -5.4646e+01  Test NLL: -5.3731e+01
# Epoch 989/1000  Train NLL: -5.4926e+01  Test NLL: -5.8698e+01
# Epoch 990/1000  Train NLL: -5.6016e+01  Test NLL: -5.8090e+01
# Epoch 991/1000  Train NLL: -5.7022e+01  Test NLL: -5.6436e+01
# Epoch 992/1000  Train NLL: -5.4231e+01  Test NLL: -5.4118e+01
# Epoch 993/1000  Train NLL: -5.3259e+01  Test NLL: -5.8159e+01
# Epoch 994/1000  Train NLL: -5.5154e+01  Test NLL: -5.6422e+01
# Epoch 995/1000  Train NLL: -5.3299e+01  Test NLL: -5.4685e+01
# Epoch 996/1000  Train NLL: -5.3076e+01  Test NLL: -5.4060e+01
# Epoch 997/1000  Train NLL: -5.4383e+01  Test NLL: -4.4576e+01
# Epoch 998/1000  Train NLL: -4.3699e+01  Test NLL: -4.7301e+01
# Epoch 999/1000  Train NLL: -4.9793e+01  Test NLL: -4.6339e+01
# Epoch 1000/1000  Train NLL: -5.1071e+01  Test NLL: -5.8927e+01

# %%
# In your neural_sde.ipynb after training
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
from scipy import stats
from neural_sde.loss import build_xi_training_data  # -> [`neural_sde.loss.build_xi_training_data`](neural_sde/loss.py)

sde_model = model

# 1) In-sample factor matrix (columns = factors: dyn | stat | sa)
X_train, _, names = build_xi_training_data(outs)  # names like ["dyn0","dyn1",...,"stat0",...,"sa0",...]

sec_per_year = 365*24*60*60

# 2) Compute dt in years from training timestamps (align lengths)
tt = pd.to_datetime(outs.C_train.index.values)
# sec_per_year = 1
dt = np.asarray((tt[1:] - tt[:-1]).total_seconds(), dtype=np.float64) / sec_per_year

L = min(len(dt), X_train.shape[0]-1)

device = next(sde_model.parameters()).device
Y0 = torch.from_numpy(X_train[:L]).float().to(device)
Y1 = torch.from_numpy(X_train[1:L+1]).float().to(device)
dt_t = torch.from_numpy(dt[:L].copy()).float().unsqueeze(1).clamp_min(1e-12).to(device)

with torch.no_grad():
    mu  = sde_model.f(0.0, Y0)
    sig = sde_model.g(0.0, Y0).clamp_min(1e-9)
    eps = (Y1 - Y0 - mu*dt_t) / (sig * torch.sqrt(dt_t))
resid = eps.cpu().numpy()

# 3) One-step standardized residuals under the trained SDE
#    ε_t = (x_{t+1} - x_t - f(x_t)Δt) / (g(x_t)√Δt)
with torch.no_grad():
    mu = sde_model.f(0.0, Y0)                        # [`neural_sde.nets.NeuralSDE.f`](neural_sde/nets.py)
    sig = sde_model.g(0.0, Y0).clamp_min(1e-9)       # [`neural_sde.nets.NeuralSDE.g`](neural_sde/nets.py)
    eps = (Y1 - Y0 - mu*dt_t) / (sig * torch.sqrt(dt_t))
resid = eps.cpu().numpy()

# 4) QQ plots per factor
d = resid.shape[1]
cols = 3
rows = int(np.ceil(d/cols))
fig, axes = plt.subplots(rows, cols, figsize=(cols*3.2, rows*3.2))
axes = axes.ravel()

for j in range(d):
    stats.probplot(resid[:, j], dist="norm", plot=axes[j])
    axes[j].set_title(names[j] if names else f"factor {j}")

for k in range(d, len(axes)):
    axes[k].axis("off")

plt.tight_layout()
plt.show()

# %%
# Pairwise scatter plots of residuals
import numpy as np
import matplotlib.pyplot as plt
from itertools import combinations
import math

R = np.asarray(resid, float)  # shape (T-1, d)
d = R.shape[1]
labels = names if (isinstance(names, (list, tuple)) and len(names)==d) else [f"f{j}" for j in range(d)]

pairs = list(combinations(range(d), 2))
cols = min(3, len(pairs))
rows = math.ceil(len(pairs) / cols)
fig, axes = plt.subplots(rows, cols, figsize=(cols*4.2, rows*3.8), squeeze=False)

for ax, (i, j) in zip(axes.ravel(), pairs):
    x, y = R[:, i], R[:, j]
    rho = np.corrcoef(x, y)[0, 1]
    ax.scatter(x, y, s=10, alpha=0.4, edgecolors="none")
    ax.axhline(0, color="k", lw=0.5, alpha=0.6)
    ax.axvline(0, color="k", lw=0.5, alpha=0.6)
    ax.set_xlabel(labels[i]); ax.set_ylabel(labels[j])
    ax.set_title(f"{labels[i]} vs {labels[j]}  (ρ={rho:.2f})")
    ax.grid(alpha=0.15)

# hide any unused axes
for k in range(len(pairs), rows*cols):
    fig.delaxes(axes.ravel()[k])

plt.tight_layout()
plt.show()

# %%
# Requires:
# - outs from decoding (Algo1Outputs, e.g. from decoding_aggre.ipynb)
# - model from neural_sde training (e.g. likelihood_training)
# Optional:
# - mu, sd returned by likelihood_training if standardisation was used

import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt
from neural_sde.loss import build_xi_training_data  # -> [`neural_sde.loss.build_xi_training_data`](neural_sde/loss.py)

device = next(model.parameters()).device

# 1) Factor dimension and helper to split [dyn|stat|sa] blocks (order matches build_xi_training_data)
k_dyn  = outs.G_dyn.shape[0] if getattr(outs, "G_dyn", None) is not None and outs.G_dyn.size else 0
k_stat = outs.G_stat.shape[0] if getattr(outs, "G_stat", None) is not None and outs.G_stat.size else 0
k_sa   = outs.G_sa.shape[0]   if getattr(outs, "G_sa",   None) is not None and outs.G_sa.size   else 0
p = k_dyn + k_stat + k_sa
N = outs.G0.shape[0]  # number of nodes

def split_blocks(x):
    """x: (..., p) -> (xd, xs, xa)"""
    i = 0
    xd = x[..., i:i+k_dyn];  i += k_dyn
    xs = x[..., i:i+k_stat]; i += k_stat
    xa = x[..., i:i+k_sa] if k_sa>0 else x[..., :0]
    return xd, xs, xa

# 2) Build train factors (for x0) and dt (years)
X_tr, _, names = build_xi_training_data(outs)
x0_raw = X_tr[-1].astype(np.float64)  # last observed state as start

sec_per_year = 365.0*24*3600
tt_tr = pd.to_datetime(outs.C_train.index.values)
dt_tr = np.asarray((tt_tr[1:] - tt_tr[:-1]).total_seconds(), dtype=np.float64) / sec_per_year
dt = float(np.median(dt_tr)) if len(dt_tr) else (1.0/365/24/60)  # ~1 minute fallback

# 3) Prepare standardisation if available (depends on your likelihood_training return)
def to_model_space(x):
    if 'mu' in globals() and 'sd' in globals() and (mu is not None) and (sd is not None):
        mu_np = mu.detach().cpu().numpy() if torch.is_tensor(mu) else np.asarray(mu)
        sd_np = sd.detach().cpu().numpy() if torch.is_tensor(sd) else np.asarray(sd)
        return (x - mu_np.ravel()) / (sd_np.ravel() + 1e-9)
    return x

def from_model_space(x):
    if 'mu' in globals() and 'sd' in globals() and (mu is not None) and (sd is not None):
        mu_np = mu.detach().cpu().numpy() if torch.is_tensor(mu) else np.asarray(mu)
        sd_np = sd.detach().cpu().numpy() if torch.is_tensor(sd) else np.asarray(sd)
        return x * sd_np.ravel() + mu_np.ravel()
    return x

# 4) Euler–Maruyama simulation for factors under [`neural_sde.nets.NeuralSDE`](neural_sde/nets.py)
@torch.no_grad()
def simulate_factors(model, x0_raw, n_steps=60, n_paths=256, dt_years=dt, clamp_sig=1e-9):
    x0 = to_model_space(x0_raw.astype(np.float64))
    x  = torch.from_numpy(np.tile(x0, (n_paths, 1))).float().to(device)  # (B, p)
    out = [x.clone()]
    DT = torch.tensor(dt_years, dtype=torch.float32, device=device).view(1,1)
    for _ in range(n_steps):
        mu  = model.f(0.0, x)
        sig = model.g(0.0, x).clamp_min(clamp_sig)        # diagonal diffusion per-dim
        eps = torch.randn_like(x)
        x   = x + mu*DT + sig*torch.sqrt(DT)*eps
        out.append(x.clone())
    X_std = torch.stack(out, dim=1)  # (B, T+1, p)
    X_raw = from_model_space(X_std.cpu().numpy())
    return X_raw  # numpy (n_paths, n_steps+1, p)

# 5) Map factors -> normalized option prices at each lattice node
#    C = G0 + Xi_dyn·G_dyn + Xi_stat·G_stat + Xi_sa·G_sa  (see [`factors.decode.reconstruct_prices`](factors/decode.py))
def factors_to_prices(X):
    """
    X: (B, T+1, p) in raw Xi space
    Returns: C: (B, T+1, N) normalized prices per node
    """
    B, T1, _ = X.shape
    C = np.empty((B, T1, N), dtype=np.float64)
    G0 = outs.G0.astype(np.float64)
    Gd = outs.G_dyn.astype(np.float64) if k_dyn>0 else np.zeros((0, N))
    Gs = outs.G_stat.astype(np.float64) if k_stat>0 else np.zeros((0, N))
    Ga = outs.G_sa.astype(np.float64)   if k_sa>0   else np.zeros((0, N))
    for t in range(T1):
        xt = X[:, t, :]                    # (B, p)
        xd, xs, xa = split_blocks(xt)      # (B,k_*)
        C[:, t, :] = (G0[None, :]
                      + (xd @ Gd) if k_dyn>0 else 0.0
                      + (xs @ Gs) if k_stat>0 else 0.0
                      + (xa @ Ga) if k_sa>0   else 0.0)
    # Optional no‑arb clipping to [max(1-exp(m),0), 1]
    m = outs.nodes_sub[:, 1].astype(np.float64)
    lb = np.maximum(1.0 - np.exp(m), 0.0)
    C = np.clip(C, lb[None, None, :], 1.0)
    return C

# 6) Run simulation and get price distribution at horizon
n_paths = 256
n_steps = 60   # horizon steps (~60 minutes if dt is 1 minute)
X_sim = simulate_factors(model, x0_raw, n_steps=n_steps, n_paths=n_paths, dt_years=dt)
C_sim = factors_to_prices(X_sim)   # (B, T+1, N)

# Choose horizon snapshot (final time)
C_T = C_sim[:, -1, :]              # (B, N)

from matplotlib.ticker import ScalarFormatter, FormatStrFormatter

def tidy_x_axis(ax, data):
    # turn off offset/scientific notation
    ax.ticklabel_format(axis="x", style="plain", useOffset=False)
    ax.get_xaxis().get_offset_text().set_visible(False)
    # choose a readable fixed-decimal formatter based on range
    rng = float(np.ptp(data))
    if rng < 0.02:
        fmt = FormatStrFormatter('%.4f')
    elif rng < 0.2:
        fmt = FormatStrFormatter('%.3f')
    else:
        fmt = FormatStrFormatter('%.2f')
    ax.xaxis.set_major_formatter(fmt)

# 7) Visualise: histograms for first 12 nodes and a violin summary
n_show = min(12, C_T.shape[1])
fig, axes = plt.subplots(int(np.ceil(n_show/4)), 4, figsize=(12, 2.2*np.ceil(n_show/4)), squeeze=False)
axes = axes.ravel()
for j in range(n_show):
    ax = axes[j]
    ax.hist(C_T[:, j], bins=40, alpha=0.8, color="#3a78b4")
    τ, m = outs.nodes_sub[j, 0], outs.nodes_sub[j, 1]
    tidy_x_axis(ax, C_T[:, j])
    ax.set_title(f"node {j}\nτ={τ:.2f}, m={m:.2f}", fontsize=9)
    ax.grid(alpha=0.2)
for k in range(n_show, len(axes)):
    fig.delaxes(axes[k])
fig.suptitle("Simulated normalized call price distributions at horizon", y=0.98)
plt.tight_layout(); plt.show()

# Violin summary: also remove offset on y (prices)
plt.figure(figsize=(10,3))
q_lo, q_md, q_hi = np.quantile(C_T, [0.1, 0.5, 0.9], axis=0)
plt.fill_between(np.arange(N), q_lo, q_hi, color="#c7dcef", alpha=0.9, label="10–90%")
plt.plot(q_md, color="#2c5d8a", lw=1.5, label="median")
ax = plt.gca()
ax.ticklabel_format(axis="y", style="plain", useOffset=False)
ax.get_yaxis().get_offset_text().set_visible(False)
ax.yaxis.set_major_formatter(FormatStrFormatter('%.3f'))
plt.title("Across-node distribution summary (horizon)"); plt.xlabel("node index"); plt.ylabel("C/F")
plt.legend(); plt.tight_layout(); plt.show()

# %%
def portfolio_var_from_C(C_sim, q, F0=1.0, multipliers=None, alpha=0.99):
    """
    C_sim: (B, T+1, N) normalized prices C/F
    q:     (N,) portfolio holdings per node
    F0:    scalar forward at t0 to convert to dollars (use 1.0 to stay normalized)
    multipliers: (N,) contract multipliers (default 1.0)
    """
    C_sim = np.asarray(C_sim)
    q = np.asarray(q).reshape(-1)
    B, T1, N = C_sim.shape
    assert q.shape[0] == N, "q must match number of nodes"

    w = np.ones(N) if multipliers is None else np.asarray(multipliers).reshape(-1)
    notional = q * F0 * w  # (N,)

    V0 = C_sim[:, 0, :] @ notional      # (B,)
    VT = C_sim[:, -1, :] @ notional     # (B,)
    dV = VT - V0                        # (B,)

    qtile = np.quantile(dV, 1 - alpha)
    var   = -qtile
    cvar  = -dV[dV <= qtile].mean()
    return var, cvar, dV


# ------------------------------------------------------------
# Helpers: map specs -> q vectors
# ------------------------------------------------------------
def nearest_node_index(tau, m, nodes):
    """
    nodes: array of shape (N,2) with columns [tau, m]
    returns index j of the nearest node by Euclidean distance in (tau, m).
    """
    diffs = nodes - np.array([tau, m])[None, :]
    j = np.argmin(np.sum(diffs*diffs, axis=1))
    return int(j)

def make_q_from_spec(spec, nodes):
    """
    Build q vector (N,) from a portfolio spec.
    spec can be:
      - dict {int_node_index: qty, ...}
      - list of (tau, m, qty) tuples (mapped to nearest node)
    """
    N = nodes.shape[0]
    q = np.zeros(N, dtype=float)
    if isinstance(spec, dict):
        for j, qty in spec.items():
            q[int(j)] += float(qty)
        return q

    # assume iterable of (tau, m, qty)
    for tau, m, qty in spec:
        j = nearest_node_index(float(tau), float(m), nodes)
        q[j] += float(qty)
    return q

# ------------------------------------------------------------
# Bulk evaluation
# ------------------------------------------------------------
def evaluate_var_for_portfolios(C_sim, portfolios, nodes, F0=1.0, multipliers=None, alphas=(0.99,)):
    """
    portfolios: dict name -> spec (dict of {node_index: qty} OR list of (tau, m, qty))
    returns: (summary_df, details) where:
      - summary_df: tidy table with VaR/CVaR per portfolio & alpha
      - details: dict name -> dict { 'q': q, 'PnL': dV }
    """
    results = []
    details = {}
    for name, spec in portfolios.items():
        q = make_q_from_spec(spec, nodes)
        # compute once, then grab for all alphas
        _, _, dV = portfolio_var_from_C(C_sim, q, F0=F0, multipliers=multipliers, alpha=alphas[0])
        details[name] = {'q': q, 'PnL': dV}

        for a in alphas:
            var_a, cvar_a, _ = portfolio_var_from_C(C_sim, q, F0=F0, multipliers=multipliers, alpha=a)
            results.append({
                'portfolio': name,
                'alpha': a,
                'VaR': var_a,
                'CVaR': cvar_a,
                'mean_PnL': float(np.mean(dV)),
                'std_PnL': float(np.std(dV, ddof=1)),
                'notional_abs_sum': float(np.sum(np.abs(q)))  # in normalized units unless F0/multipliers used
            })

    summary = pd.DataFrame(results).sort_values(['alpha','VaR'], ascending=[True, False]).reset_index(drop=True)
    return summary, details

# ------------------------------------------------------------
# Example portfolio set
# nodes_2d should be your (tau, m) for each lattice node.
# Prefer outs.nodes_sub if present, else outs.nodes.
# ------------------------------------------------------------
nodes_2d = getattr(outs, 'nodes_sub', getattr(outs, 'nodes_sub'))
assert nodes_2d.shape[1] == 2, "nodes must have shape (N,2) with [tau, m]"

# Build a few example portfolios (edit to your needs):
tau_near_1d = 1.0/365.0
tau_near_3d = 3.0/365.0
m_atm       = 0.0
m_otm_up    = +0.10
m_otm_dn    = -0.10

portfolios = {
    # 1) Long single near-ATM call (by (tau,m))
    "Long ATM ~1d": [
        (tau_near_1d, m_atm, +1.0)
    ],

    # 2) Short OTM ~1d
    "Short OTM +0.10 ~1d": [
        (tau_near_1d, m_otm_up, -1.0)
    ],

    # 3) Call butterfly around ATM at ~1d: +1 at m=-0.10, -2 at m=0, +1 at m=+0.10
    "1x2x1 Call Fly ~1d": [
        (tau_near_1d, m_otm_dn, +1.0),
        (tau_near_1d, m_atm,    -2.0),
        (tau_near_1d, m_otm_up, +1.0)
    ],
}


# ------------------------------------------------------------
# Run VaR evaluation
# ------------------------------------------------------------
# Choose your conversion to dollars if you want absolute VaR:
# - F0: current forward/spot at t0 (e.g., BTCUSD price)
# - multipliers: contract sizes per node (vector length N) if needed
F0 = 1.0
multipliers = None
alphas = (0.95, 0.99)

summary_df, details = evaluate_var_for_portfolios(
    C_sim=C_sim,
    portfolios=portfolios,
    nodes=nodes_2d,
    F0=F0,
    multipliers=multipliers,
    alphas=alphas
)

print(summary_df)

# ------------------------------------------------------------
# (Optional) quick P&L histogram per portfolio
# ------------------------------------------------------------
import matplotlib.pyplot as plt
cols = len(portfolios)
fig, axes = plt.subplots(1, cols, figsize=(4.2*cols, 3.2), squeeze=False)
for ax, (name, info) in zip(axes.ravel(), details.items()):
    dV = info['PnL']
    ax.hist(dV, bins=40, alpha=0.85)
    ax.set_title(name)
    ax.set_xlabel("PnL")
    ax.set_ylabel("count")
    ax.grid(alpha=0.2)
plt.tight_layout(); plt.show()
# Out:
#              portfolio  alpha           VaR      CVaR      mean_PnL  \
# 0   1x2x1 Call Fly ~1d   0.95  1.185968e-05  0.000017  7.221352e-07
# 1         Long ATM ~1d   0.95  1.489687e-06  0.000002 -8.121588e-08
# 2  Short OTM +0.10 ~1d   0.95  8.787825e-07  0.000001  5.350901e-08
# 3   1x2x1 Call Fly ~1d   0.99  1.824258e-05  0.000020  7.221352e-07
# 4         Long ATM ~1d   0.99  1.760780e-06  0.000002 -8.121588e-08
# 5  Short OTM +0.10 ~1d   0.99  1.351745e-06  0.000002  5.350901e-08
#
#         std_PnL  notional_abs_sum
# 0  8.090758e-06               4.0
# 1  9.099377e-07               1.0
# 2  5.995116e-07               1.0
# 3  8.090758e-06               4.0
# 4  9.099377e-07               1.0
# 5  5.995116e-07               1.0

# %%
import numpy as np
import pandas as pd
import torch
import matplotlib.pyplot as plt

device = next(model.parameters()).device

# ---------------------------
# 1) Factors & dt (TEST SET)
# ---------------------------
# Build test factors in the SAME order as training
_, X_te, names = build_xi_training_data(outs)  # shape (T_test, p)
X_te = X_te.astype(np.float64)
T_test, p = X_te.shape

# Test dt in years from test index
sec_per_year = 1
tt_te = pd.to_datetime(outs.C_test.index.values)
dt_te = np.asarray((tt_te[1:] - tt_te[:-1]).astype('timedelta64[s]'), dtype=np.int64) / sec_per_year
assert len(dt_te) == T_test 

# ---------------------------
# 2) Standardisation hooks
# ---------------------------
def to_model_space(x):
    # if 'mu' in globals() and 'sd' in globals() and (mu is not None) and (sd is not None):
    #     mu_np = mu.detach().cpu().numpy() if torch.is_tensor(mu) else np.asarray(mu)
    #     sd_np = sd.detach().cpu().numpy() if torch.is_tensor(sd) else np.asarray(sd)
    #     return (x - mu_np.ravel()) / (sd_np.ravel() + 1e-9)
    return x

def from_model_space(x):
    # if 'mu' in globals() and 'sd' in globals() and (mu is not None) and (sd is not None):
    #     mu_np = mu.detach().cpu().numpy() if torch.is_tensor(mu) else np.asarray(mu)
    #     sd_np = sd.detach().cpu().numpy() if torch.is_tensor(sd) else np.asarray(sd)
    #     return x * sd_np.ravel() + mu_np.ravel()
    return x

# ---------------------------
# 3) Factors → prices (batch)
# ---------------------------
k_dyn  = outs.G_dyn.shape[0] if getattr(outs, "G_dyn", None) is not None and outs.G_dyn.size else 0
k_stat = outs.G_stat.shape[0] if getattr(outs, "G_stat", None) is not None and outs.G_stat.size else 0
k_sa   = outs.G_sa.shape[0]   if getattr(outs, "G_sa",   None) is not None and outs.G_sa.size   else 0
N = outs.G0.shape[0]

G0 = outs.G0.astype(np.float64)
Gd = outs.G_dyn.astype(np.float64) if k_dyn  > 0 else np.zeros((0, N))
Gs = outs.G_stat.astype(np.float64) if k_stat > 0 else np.zeros((0, N))
Ga = outs.G_sa.astype(np.float64)   if k_sa   > 0 else np.zeros((0, N))

def split_blocks(x):
    i = 0
    xd = x[..., i:i+k_dyn];  i += k_dyn
    xs = x[..., i:i+k_stat]; i += k_stat
    xa = x[..., i:i+k_sa] if k_sa>0 else x[..., :0]
    return xd, xs, xa

def x_to_prices_batch(X_batch):
    """
    X_batch: (B, p) raw Xi → returns (B, N) normalized prices
    """
    xd, xs, xa = split_blocks(X_batch)
    term = np.broadcast_to(G0, (X_batch.shape[0], N)).copy()
    if k_dyn  > 0: term += xd @ Gd
    if k_stat > 0: term += xs @ Gs
    if k_sa   > 0: term += xa @ Ga
    # No-arb clipping
    m = outs.nodes_sub[:, 1].astype(np.float64) if hasattr(outs, 'nodes_sub') else outs.nodes[:,1].astype(np.float64)
    lb = np.maximum(1.0 - np.exp(m), 0.0)
    return np.clip(term, lb[None, :], 1.0)

# ---------------------------
# 4) One-step predictive draw
# ---------------------------
@torch.no_grad()
def one_step_draw_C(model, x0_raw, dt_years, n_paths=512, clamp_sig=1e-9):
    """
    x0_raw: (p,) raw Xi at time t
    dt_years: scalar
    returns: C_{t+1} draws as (n_paths, N)
    """
    x0 = to_model_space(x0_raw.astype(np.float64))
    x  = torch.from_numpy(np.tile(x0, (n_paths, 1))).float().to(device)  # (B, p)
    DT = torch.tensor(dt_years, dtype=torch.float32, device=device).view(1,1)

    mu  = model.f(0.0, x)
    sig = model.g(0.0, x).clamp_min(clamp_sig)   # diagonal diffusion per dim
    eps = torch.randn_like(x)
    x1  = x + mu*DT + sig*torch.sqrt(DT)*eps     # Euler one-step

    X1_raw = from_model_space(x1.detach().cpu().numpy())
    C1     = x_to_prices_batch(X1_raw)           # (n_paths, N)
    return C1

# ---------------------------
# 5) Roll through test set:
#    node overlay and histogram
# ---------------------------
node_idx   = 40              # <- choose the lattice node to evaluate/plot
alpha_band = (0.05, 0.95)   # predictive band

C_actual = outs.C_test.values.astype(np.float64)  # (T_test, N) normalized
assert C_actual.shape[0] == T_test + 1

n_paths = 512
q_lo_series, q_md_series, q_hi_series = [], [], []
actual_series = []
time_index = tt_te[1:]  # we predict t+1

# collect also PIT values if you want calibration later
pit_vals = []

for t in range(T_test - 1):
    C1_draws = one_step_draw_C(model, X_te[t], dt_te[t], n_paths=n_paths)  # (B, N)
    # predictive stats for chosen node
    draws_node = C1_draws[:, node_idx]
    q_lo, q_md, q_hi = np.quantile(draws_node, [alpha_band[0], 0.5, alpha_band[1]])
    q_lo_series.append(q_lo); q_md_series.append(q_md); q_hi_series.append(q_hi)
    actual = C_actual[t+1, node_idx]
    actual_series.append(actual)
    # PIT
    pit_vals.append((draws_node <= actual).mean())

q_lo_series = np.array(q_lo_series)
q_md_series = np.array(q_md_series)
q_hi_series = np.array(q_hi_series)
actual_series = np.array(actual_series)
pit_vals = np.array(pit_vals)

# ---------------------------
# 6) Plot: predictive band vs actual
# ---------------------------
steps = np.arange(q_lo_series.size)             # align x with computed series
# optional: keep a matching time index if you want to label dates later
time_index_plot = tt_te[1:][:q_lo_series.size]  # from [`pipeline.Algo1Outputs.C_test`](pipeline/algo1.py)

plt.figure(figsize=(11,3.6))
plt.fill_between(steps, q_lo_series, q_hi_series, alpha=0.25,
                 label=f'{int(100*(alpha_band[1]-alpha_band[0]))}% pred. band')
plt.plot(steps, q_md_series, lw=1.5, label='predictive median')
plt.plot(steps, actual_series, lw=1.2, label='actual', alpha=0.9)
plt.title(f"One-step predictive band vs actual  (node {node_idx})")
plt.xlabel("test step"); plt.ylabel("C/F (normalized)")
plt.legend(); plt.grid(alpha=0.2); plt.tight_layout(); plt.show()

# ---------------------------
# 7) One example step histogram with actual overlay
# ---------------------------
t_example = steps.size // 3                     # pick a valid step
C1_draws = one_step_draw_C(model, X_te[t_example], dt_te[t_example], n_paths=n_paths)
draws_node = C1_draws[:, node_idx]
plt.figure(figsize=(6,3))
plt.hist(draws_node, bins=50, alpha=0.85)
plt.axvline(C_actual[t_example+1, node_idx], color='k', ls='--', lw=1.5, label='actual next price')
plt.title(f"Predictive C_(t+1) distribution @ step {t_example}, node {node_idx}")
plt.xlabel("C/F"); plt.ylabel("count"); plt.legend(); plt.tight_layout(); plt.show()

# (Optional) PIT quick check
print("PIT mean (should be ~0.5 if calibrated):", pit_vals.mean())
# Out:
# PIT mean (should be ~0.5 if calibrated): 0.34091854659763315

# %%
# ---------- align once ----------
sec_per_year = 1  
C_test = outs.C_test.values.astype(np.float64)           # (T_c, N)
idx_c  = pd.to_datetime(outs.C_test.index.values)
dt_years = np.asarray((idx_c[1:] - idx_c[:-1]).astype('timedelta64[s]'),
                      dtype=np.int64) / sec_per_year     # (T_c-1,)

_, X_te, _ = build_xi_training_data(outs)                # (T_x, p)
X_te = X_te.astype(np.float64)

steps = min(len(dt_years), X_te.shape[0], C_test.shape[0]-1)
N = outs.G0.shape[0]

# ---------- compute bands for ALL nodes ----------
def one_step_bands_all_nodes(model, X_te, dt_years, C_next, n_paths=1024, band=(0.06,0.94)):
    T = min(len(dt_years), X_te.shape[0], C_next.shape[0])
    q_lo = np.empty((T, N)); q_md = np.empty((T, N)); q_hi = np.empty((T, N))
    pits = np.empty((T, N))
    for t in range(T):
        C1_draws = one_step_draw_C(model, X_te[t], dt_years[t], n_paths=n_paths)  # (B, N)
        qs = np.quantile(C1_draws, [band[0], 0.5, band[1]], axis=0)               # (3, N)
        q_lo[t], q_md[t], q_hi[t] = qs[0], qs[1], qs[2]
        pits[t] = (C1_draws <= C_next[t]).mean(axis=0)
    return q_lo, q_md, q_hi, pits

q_lo, q_md, q_hi, pits = one_step_bands_all_nodes(
    model,
    X_te[:steps],
    dt_years[:steps],
    C_test[1:steps+1],          # actual at t+1
    n_paths=1024,
    band=(0.05, 0.95)         # ~89% like your plot
)

# ---------- small-multiple plots over nodes ----------
nodes_2d = getattr(outs, 'nodes_sub', getattr(outs, 'nodes_sub'))  # (N,2) [tau, m]

def plot_bands_grid(q_lo, q_md, q_hi, actual, nodes_2d, cols=4, rows=3):
    T, N = q_lo.shape
    idx = np.arange(T)
    per_fig = cols*rows
    for start in range(0, N, per_fig):
        end = min(start+per_fig, N)
        m = end - start
        r = math.ceil(m/cols)
        fig, axes = plt.subplots(r, cols, figsize=(cols*4.0, r*2.6), squeeze=False)
        axes = axes.ravel()
        for k, j in enumerate(range(start, end)):
            ax = axes[k]
            ax.fill_between(idx, q_lo[:, j], q_hi[:, j], alpha=0.25, label='band' if k==0 else None)
            ax.plot(idx, q_md[:, j], lw=1.0, label='median' if k==0 else None)
            ax.plot(idx, actual[:, j], lw=1.0, label='actual' if k==0 else None)
            tau, moneyness = nodes_2d[j, 0], nodes_2d[j, 1]
            ax.set_title(f"node {j} (τ={tau:.2f}, m={moneyness:.2f})", fontsize=9)
            ax.grid(alpha=0.2)
        # remove empty axes
        for k in range(m, len(axes)):
            fig.delaxes(axes[k])
        handles, labels = axes[0].get_legend_handles_labels()
        if handles:
            fig.legend(handles, labels, loc='upper left', bbox_to_anchor=(0.01, 0.99))
        fig.suptitle(f"One-step predictive band vs actual (nodes {start}-{end-1})", y=0.99)
        plt.tight_layout(); plt.show()

plot_bands_grid(q_lo, q_md, q_hi, C_test[1:steps+1], nodes_2d, cols=4, rows=3)

# ---------- optional: per-node calibration summary ----------
coverage = ((C_test[1:steps+1] >= q_lo) & (C_test[1:steps+1] <= q_hi)).mean(axis=0)   # (N,)
pit_mean = pits.mean(axis=0)                                                          # (N,)
print("Mean coverage across nodes:", float(coverage.mean()))
print("Mean PIT mean across nodes:", float(pit_mean.mean()))
# Out:
# Mean coverage across nodes: 0.9673058013765979
# Mean PIT mean across nodes: 0.48631342134878935
